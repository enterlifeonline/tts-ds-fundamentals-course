# %% [markdown]
# Data Science Fundamentals: Python |
# [Table of Contents](../index.ipynb)
# - - -
# <!--NAVIGATION-->
# Module 6. | [Generators](./01_generators.ipynb) | **[Regular Expressions](./02_regex.ipynb)** | [String Manipulation & Regular Expressions](03_str_manipulate.ipynb) | [Closures & Generators](./04_closures_generators.ipynb) | [Exercises](./05_gen_regex_exercises.ipynb)

# %% [markdown]
# ## Regular Expression Generators for Python

# %% [markdown]
# ### [Pyregex](http://www.pyregex.com/)

# %% [markdown]
# ### [Pythex](https://pythex.org/)
#
# - - -
#
# [Regular Expression Cheatsheet](https://learnbyexample.github.io/cheatsheet/python/python-regex-cheatsheet/)
# <br>
# [Regular Expression Operations Documentation](https://docs.python.org/2/library/re.html)

# %% [markdown]
# ## Regular Expressions

# %% [markdown]
# ### Examples
#
# We have already seen that we can ask from a string `str`
# whether it begins with some substring as follows:
# `str.startswith('Apple')`.
# If we would like to know whether it starts with `"Apple"` or
# `"apple"`, we would have to call `startswith` method twice.
# Regular expressions offer a simpler solution:
# `re.match(r"[Aa]pple", str)`.
# The bracket notation is one example of the special syntax of
# *regular expressions*. In this case it says that any of the
# characters inside brackets will do: either `"A"` or `"a"`. The other
# letters in `"pple"` will act normally. The string `r"[Aa]pple"` is
# called a *pattern*.
#
# A more complicated example asks whether the string `str`
# starts with either `apple` or `banana` (no matter if the first letter
# is capital or not):
# `re.match(r"[Aa]pple|[Bb]anana", str)`.
# In this example we saw a new special character `|` that denotes
# an alternative. On either side of the bar character we have a
# *subpattern*.
#
# A legal variable name in Python starts with a letter or an
# underline character and the following characters can also be
# digits.
# So legal names are, for instance: `_hidden`, `L_value`, `A123_`.
# But the name `2abc` is not a valid variable name.
# Let’s see what would be the regular expression pattern to
# recognise valid variable names:
# `r"[A-Za-z_][A-Za-z_0-9]*\Z"`.
# Here we have used a shorthand for character ranges: `A-Z`.
# This means all the characters from `A` to `Z`.
#
# The first character of the variable name is defined in the first
# brackets. The subsequent characters are defined in the second
# brackets.
# The special character `*` means that we allow any number
# (0,1,2, . . . ) of the previous subpattern. For example the
# pattern `r"ba*"` allows strings `"b"`, `"ba"`, `"baa"`, `"baaa"`, and
# so on.
# The special syntax `\Z` denotes the end of the string.
# Without it we would also accept `abc-` as a valid name since
# the `match` function normally checks only that a string starts with a pattern.
#
# The special notations, like `\Z`, also cause problems with string
# handling.
# Remember that normally in string literals we have some
# special notation: `\n` stands for newline, `\t` stands for tab, and
# so on.
# So, both string literals and regular expressions use similar
# looking notations, which can create serious confusion.
# This can be solved by using the so-called *raw strings*. We
# denote a raw string by having an `r` letter before the first
# quotation mark, for example `r"ab*\Z"`.
# When using raw strings, the newline (`\n`), tab (`\t`), and other
# special string literal notations aren’t interpreted. One should
# always use raw strings when defining regular expression
# patterns!

# %% [markdown]
# ### Patterns
#
# A pattern represents a set of strings. This set can even be
# potentially infinite.
# They can be used to describe a set of strings that have some
# commonality; some regular structure.
# Regular expressions (RE) are a classical computer science topic.
# They are very common in programming tasks. Scripting
# languages, like Python, are very fluent in regular expressions.
# Very complex text processing can be achieved using regular
# expressions.
#
# In patterns, normal characters (letters, numbers) just represent
# themselves, unless preceded by a backslash, which may trigger
# some special meaning.
# Punctuation characters have special meaning, unless preceded
# by backslash (`\`), which deprives their special meaning.
# Use `\\` to represent a backslash character without any special
# meaning.
# In the following slides we will go through some of the more
# common RE notations.
#
# ```
# . Matches any character
# [...] Matches any character contained within the brackets
# [^...] Matches any character not appearing after the hat (ˆ)
# ˆ Matches the start of the string
# $ Matches the end of the string
# * Matches zero or more previous RE
# + Matches one or more previous RE
# {m,n} Matches m to n occurences of previous RE
# ? Matches zero or one occurences of previous RE
# ```
#
# We have already seen that a `|` character denotes alternatives.
# For example, the pattern `r"Get (on|off|ready)"` matches
# the following strings: `"Get on"`, `"Get off"`, `"Get ready"`.
# We can use parentheses to create groupings inside a pattern:
# `r"(ab)+"` will match the strings `"ab"`, `"abab"`, `"ababab"`,
# and so on.
# These groups are also given a reference number starting from 1.
# We can refer to groups using backreferences: `\number`.
# For example, we can find separated patterns that get
# repeated: `r"([a-z]{3,}) \1 \1"`.
# This will recognise, for example, the following strings: `"aca
# aca aca"`, `"turn turn turn"`. But not the strings `"aca
# aba aca"` or `"ac ac ac"`.
#
#
# In the following, note that a hat (ˆ) as the first character
# inside brackets will create a complement set of characters:
#
# ```
# `\d` same as `[0-9]`, matches a digit
# `\D` same as `[ˆ0-9]`, matches anything but a digit
# `\s` matches a whitespace character (space, newline, tab, ... )
# `\S` matches a nonwhitespace character
# `\w` same as `[a-zA-Z0-9_]`, matches one alphanumeric character
# `\W` matches one non-alphanumeric character
# ```
#
# Using the above notation we can now shorten our previous
# variable name example to `r’[a-zA-Z_]\w*\Z’`
#
# The patterns `\A`, `\b`, `\B`, and `\Z` will all match an empty
# string, but in specific places.
# The patterns `\A` and `\Z` will recognise the beginning and end
# of the string, respectively.
# Note that the patterns `ˆ` and `$` can in some cases match also
# after a newline and before a newline, correspondingly.
# So, `\A` is distinct from `ˆ`, and `\Z` is distinct from `$`.
# The pattern `\b` matches at the start or end of a word. The
# pattern `\B` does the reverse.

# %% [markdown]
# ### Match and search functions
#
# We have so far only used the `re.match` function which tries
# to find a match at the beginning of a string
# The function `re.search` allows to match any substring of a
# string.
# Example: `re.search(r'\bback\b', s)` will match
# strings `"back"`, `"a back, is a body part"`, `"get back"`. But it
# will not match the strings `"backspace"` or `"comeback"`.
#
# The function `re.search` finds only the first occurence.
# We can use the `re.findall` function to find all occurences.
# Let’s say we want to find all present participle words in a
# string `s`. The present participle words have ending `'ing'`.
# The function call would look like this:
# `re.findall(r'\w+ing\b', s)`.
# Let’s try running this:

# %%
import re
s = "Doing things, going home, staying awake, sleeping later"
re.findall(r'\w+ing\b', s)
# Out:
# ['Doing', 'going', 'staying', 'sleeping']

# %% [markdown]
# Let’s say we want to pick up all the integers from a string.
# We can try that with the following function call:
# `re.findall(r'[+-]?\d+', s)`.
# An example run:

# %%
re.findall(r'[+-]?\d+', "23 + -24 = -1")
# Out:
# ['23', '-24', '-1']

# %% [markdown]
# Suppose we are given a string of if/then sentences, and we
# would like to extract the conditions from these sentences.
# Let’s try the following function call:
# `re.findall(r'[Ii]f (.*), then', s)`.
# An example run:

# %%
s = ("If I’m not in a hurry, then I should stay. " +
    "On the other hand, if I leave, then I can sleep.")
re.findall(r'[Ii]f (.*), then', s)
# Out:
# ['I’m not in a hurry, then I should stay. On the other hand, if I leave']

# %% [markdown]
# But I wanted a result: `["I'm not in a hurry", 'I leave']`. That
# is, the condition from both sentences. How can this be fixed?
#
# The problem is that the pattern `.*` tries to match as many
# characters as possible.
# This is called *greedy matching*.
# One way of solving this problem is to notice that the two
# sentences are separated by a full-stop (.).
# So, instead of matching all the characters, we need to match
# everything but the dot character.
# This can be achieved by using the complement character
# class: `[^.]`. The hat character (`ˆ`) in the beginning of a
# character class means the complement character class
#
# After the modification the function call looks like this:
# `re.findall(r'[Ii]f ([^.]*), then', s)`.
# Another way of solving this problem is to use a non-greedy
# matching.
# The repetition specifiers `+`, `*`, `?`, and `{m,n}` have
# corresponding non-greedy versions: `+?`, `*?`, `??`, and `{m,n}?`.
# These expressions use as few characters as possible to make
# the whole pattern match some substring.
# By using non-greedy version, the function call looks like this:
# `re.findall(r’[Ii]f (.*?), then’, s)`.

# %% [markdown]
# ### Functions in the `re` module
#
# Below is a list of the most common functions in the `re` module
#
# * `re.match(pattern, str)`
# * `re.search(pattern, str)`
# * `re.findall(pattern, str)`
# * `re.finditer(pattern, str)`
# * `re.sub(pattern, replacement, str, count=0)`
#
# Functions `match` and `search` return a *match object*.
# A match object describes the found occurence.
# The function `findall` returns a list of all the occurences of
# the pattern. The elements in the list are strings.
# The function `finditer` works like `findall` function except
# that instead of returning a list, it returns an iterator whose
# items are match objects.
# The function `sub` replaces all the occurences of the pattern in
# `str` with the string replacement and returns the new string.
#
# An example: The following program will replace all "she"
# words with "he"
#
# ```
# import re
# str = "She goes where she wants to, she's a sheriff."
# newstr = re.sub(r'\b[Ss]he\b', 'he', str)
# print newstr
# ```
#
# This will print `he goes where he wants to, he's a sheriff.`
#
# The `sub` function can also use backreferences to refer to the
# matched string. The backreferences \1, \2, and so on, refer
# to the groups of the pattern, in order.
# An example:
# ```
# import re
# str = """He is the president of Russia.
# He’s a powerful man."""
# newstr = re.sub(r'(\b[Hh]e\b)', r'\1 (Putin)', str, 1)
# print newstr
# ```
#
# This will print
# ```
# He (Putin) is the president of Russia.
# He’s a powerful man.
# ```

# %% [markdown]
# ### Match object
#
# Functions `match`, `search`, and `finditer` use `match` objects
# to describe the found occurence.
# The method `groups()` of the match object returns the tuple
# of all the substrings matched by the groups of the pattern.
# Each pair of parentheses in the pattern creates a new group.
# These groups are are referred to by indices 1, 2, ...
# The group 0 is a special one: it refers to the match created by
# the whole pattern.
#
# Let’s look at the match object returned by the call
#
# ```
# mo = re.search(r'\d+ (\d+) \d+ (\d+)',
# 'first 123 45 67 890 last')
# ```
#
# The call `mo.groups()` returns a tuple `(’45’, ’890’)`.
# We can access just some individual groups by using the
# method `group(gid, ...)`.
# For example, the call `mo.group(1)` will return `’45’`.
# The zeroth group will represent the whole match:
# `’123 45 67 890’`
#
# In addition to accessing the strings matched by the pattern
# and its groups, the corresponding indices of the original string
# can be accessed:
#
# * The `start(gid=0)` and `end(gid=0)` methods return the start
# and end indices of the matched group gid, correspondingly
# * The method `span(gid)` just returns the pair of these start
# and end indices
#
# The match object mo can also be used like a boolean value:
#
# ```python
# mo = re.search(...)
# if mo:
#     # do something
# ```
#
# will do something if a match was found.
# Alternatively, the match object can be converted to a boolean
# value by the call `found = bool(mo)`.

# %% [markdown]
# ### Miscellaneous stuff
#
# If the same pattern is used in many function calls, it may be
# wise to precompile the pattern, mainly for efficiency reasons.
# This can be done using the `compile(pattern, flags=0)` function
# in the `re` module. The function returns a so-called RE object.
# The RE object has method versions of the functions found in
# module `re`.
# The only difference is that the first parameter is not the
# pattern since the precompiled pattern is stored in the RE
# object.
#
# The details of matching operation can be specified using
# optional flags.
# These flags can be given either inside the pattern or as a
# parameter to the compile function.
# Some of the more common flags are given in the following
# table
#
# | x   | Flag |
# |-----|--------------|
# |`(?i)` | re.IGNORECASE|
# |`(?m)` | re.MULTILINE|
# |`(?s)` | re.DOTALL|
#
# The elements on the left can appear anywhere in the pattern
# but preferably in the beginning.
# On the right there are attributes of the re module that can be
# given to the compile function as the second parameter
#
# The `IGNORECASE` flag makes lower- and uppercase
# characters appear as equal.
# The `MULTILINE` flag makes the special characters `ˆ` and `$`
# match the beginning and end of each line in addition to the
# beginning and end of the whole string. These flags make `\A`
# differ from `ˆ`, and `\Z` differ from `$`.
# The `DOTALL` flag makes the character class `.` (dot) also
# accept the newline character, in addition to all the other
# letters.
#
# When giving multiple flags to the compile function, the flags
# can be separated with the `|` sign.
# For example, `re.compile(pattern, re.MULTILINE | re.DOTALL)`.
# This is equal to `re.compile('(?m)(?s)' + pattern)`.

# %% [markdown]
# #### <div class="alert alert-info">Group Exercise 1 (integers in brackets)</div>
#
# Write function `integers_in_brackets` that finds from a given string all integers that are enclosed in brackets.
#
# Example run:
# `integers_in_brackets("  afd [asd] [12 ] [a34]  [ -43 ]tt [+12]xxx")`
# returns
# `[12, -43, 12]`.
# So there can be whitespace between the number and the brackets, but no other character besides those that make up the integer.
#
# Test your function from the `main` function.
# <hr/>

# %% [raw]
# import re
#
# def integers_in_brackets(x):
#     y = re.findall("\[(.*?)\]", x)
#
#     for i in range(len(y)):
#         re.findall(r'[+-]\d+', y(i))
#
#       # print(y[i])
#       # print(z)
#   # for i in range(len(y)):
#   #     print(y[i].isdigit())
#   #.         print(y[i])
#   # z = re.findall('-?\d+', x)
#   # y = re.findall('\W', x)
#   # print(z)
#
# integers_in_brackets("  afd [asd] [12 ] [a34]  [ -43 ]tt [+12]xxx")

# %%
import re
re.findall(r'[+-]?\d+', "  afd [asd] [12 ] [a34]  [ -43 ]tt [+12]xxx")
# Out:
# ['12', '34', '-43', '+12']

# %% [markdown]
# ## Basic file processing

# %% [markdown]
# A file can be opened with the `open` function. The call `open(filename, mode="r")` will return a *file object*, whose type is `file`. This file object can be used to refer to a file on disk. For example, when we want to read from or write to a file, we can used the methods `read` and `write` of the file object. After the file object is no longer needed, a call to the `close` method should be made.
#
# We can control what kind of operations we can perform on a file with the *mode* parameter of the `open` function. Different options include opening a file for reading or writing,
# whether the file should exists already or be created with the
# call to open, etc. Here's a list of all the opening modes:
#
# | Mode | Description |
# | ---- | ----------- |
# | `r`  | read-only mode, file must exist |
# | `w`  | write-only mode, creates, or overwrites an existing file |
# | `a`  | write-only mode, write always appends to the end |
# | `r+` | read/write mode, file must already exist |
# | `w+` | read/write mode, creates, or overwrites an existing file |
# | `a+` | read/write mode, write will append to end |

# %% [markdown]
# In the end of the mode string either the letter `t` or `b` can be appended. These stand for text mode and binary mode. If this letter is not given, the file type is text mode by default.
#
# For binary mode the contents of the file are not interpreted in any way, and the read and write methods handle bytes. (A byte consists of 8 bits and can be used to represent a number in the range 0 to 255.)
#
# In the text mode two interpretations happen
#
# * On Windows operating system the end of line in files is encoded by two characters. When the file is read these two charactes are converted to `'\n'` character. During writes to a file this conversion happens in the opposite direction.
# * One character is encoded in the file as one or more bytes. This conversion happens automatically during read and write operations. One common encoding between bytes and characters is utf-8. In this encoding, the Finnish character `'ä'`, for example, is encoded as the following sequence of bytes:

# %%
"ä".encode("utf-8")
# Out:
# b'\xc3\xa4'

# %% [markdown]
# Above the two bytes were expressed as hexadecimals. In decimal notation they would be 195 and 164. (Both in the range from 0 to 255.)

# %%
list("ä".encode("utf-8"))              # Show as a list of integers
# Out:
# [195, 164]

# %% [markdown]
# What is the utf-8 encoding of the letter `'a'`?
#
# During this course we will only consider files containing text, so the default text mode is fine for us. But we might sometimes have to specify the encoding of a file, if it is not the usual utf-8.

# %% [markdown]
# ### Some common file object methods
# * `read(size)` will read size characters/bytes as a string
# * `write(string)` will write string/bytes to a file
# * `readline()` will read a string until and including the next newline character is met
# * `readlines()` will return a list of all lines of a file
# * `writelines()` will write a list of lines to a file
# * `flush()` will try to make sure that the changes made to a file are written to disk immediately

# %%
#f = open("../realworld/csv/04_rw_csv.ipynb", "r") # Let's open this notebook file,
f = open("02_regex.ipynb", "r")

                              # which is essentially a text file.
                              # So you can open it in a texteditor as well.
        
for i in range(1000):            # And read the first thosand lines
    line = f.readline()
    print(f"Line {i}: {line}", end="")
f.close()
# Out:
# Line 0: {
# Line 1:  "cells": [
# Line 2:   {
# Line 3:    "cell_type": "markdown",
# Line 4:    "metadata": {
# Line 5:     "colab_type": "text",
# Line 6:     "id": "ckl7mcSK4JJm"
# Line 7:    },
# Line 8:    "source": [
# Line 9:     "Data Science Fundamentals: Python |\n",
# Line 10:     "[Table of Contents](../index.ipynb)\n",
# Line 11:     "- - - \n",
# Line 12:     "<!--NAVIGATION-->\n",
# Line 13:     "Module 6. | [Generators](./01_generators.ipynb) | **[Regular Expressions](./02_regex.ipynb)** | [String Manipulation & Regular Expressions](03_str_manipulate.ipynb) | [Closures & Generators](./04_closures_generators.ipynb) | [Exercises](./05_gen_regex_exercises.ipynb)"
# Line 14:    ]
# Line 15:   },
# Line 16:   {
# Line 17:    "cell_type": "markdown",
# Line 18:    "metadata": {
# Line 19:     "colab_type": "text",
# Line 20:     "id": "CeDr6HXa4JJm"
# Line 21:    },
# Line 22:    "source": [
# Line 23:     "## Regular Expression Generators for Python"
# Line 24:    ]
# Line 25:   },
# Line 26:   {
# Line 27:    "cell_type": "markdown",
# Line 28:    "metadata": {},
# Line 29:    "source": [
# Line 30:     "### [Pyregex](http://www.pyregex.com/)"
# Line 31:    ]
# Line 32:   },
# Line 33:   {
# Line 34:    "cell_type": "markdown",
# Line 35:    "metadata": {},
# Line 36:    "source": [
# Line 37:     "### [Pythex](https://pythex.org/) \n",
# Line 38:     "\n",
# Line 39:     "- - -\n",
# Line 40:     "\n",
# Line 41:     "[Regular Expression Cheatsheet](https://learnbyexample.github.io/cheatsheet/python/python-regex-cheatsheet/)\n",
# Line 42:     "<br>\n",
# Line 43:     "[Regular Expression Operations Documentation](https://docs.python.org/2/library/re.html)"
# Line 44:    ]
# Line 45:   },
# Line 46:   {
# Line 47:    "cell_type": "markdown",
# Line 48:    "metadata": {},
# Line 49:    "source": [
# Line 50:     "## Regular Expressions"
# Line 51:    ]
# Line 52:   },
# Line 53:   {
# Line 54:    "cell_type": "markdown",
# Line 55:    "metadata": {
# Line 56:     "colab_type": "text",
# Line 57:     "id": "nAvFyyd64JJo"
# Line 58:    },
# Line 59:    "source": [
# Line 60:     "### Examples\n",
# Line 61:     "\n",
# Line 62:     "We have already seen that we can ask from a string `str`\n",
# Line 63:     "whether it begins with some substring as follows:\n",
# Line 64:     "`str.startswith('Apple')`.\n",
# Line 65:     "If we would like to know whether it starts with `\"Apple\"` or\n",
# Line 66:     "`\"apple\"`, we would have to call `startswith` method twice.\n",
# Line 67:     "Regular expressions offer a simpler solution:\n",
# Line 68:     "`re.match(r\"[Aa]pple\", str)`.\n",
# Line 69:     "The bracket notation is one example of the special syntax of\n",
# Line 70:     "*regular expressions*. In this case it says that any of the\n",
# Line 71:     "characters inside brackets will do: either `\"A\"` or `\"a\"`. The other\n",
# Line 72:     "letters in `\"pple\"` will act normally. The string `r\"[Aa]pple\"` is\n",
# Line 73:     "called a *pattern*.\n",
# Line 74:     "\n",
# Line 75:     "A more complicated example asks whether the string `str`\n",
# Line 76:     "starts with either `apple` or `banana` (no matter if the first letter\n",
# Line 77:     "is capital or not):\n",
# Line 78:     "`re.match(r\"[Aa]pple|[Bb]anana\", str)`.\n",
# Line 79:     "In this example we saw a new special character `|` that denotes\n",
# Line 80:     "an alternative. On either side of the bar character we have a\n",
# Line 81:     "*subpattern*.\n",
# Line 82:     "\n",
# Line 83:     "A legal variable name in Python starts with a letter or an\n",
# Line 84:     "underline character and the following characters can also be\n",
# Line 85:     "digits.\n",
# Line 86:     "So legal names are, for instance: `_hidden`, `L_value`, `A123_`.\n",
# Line 87:     "But the name `2abc` is not a valid variable name.\n",
# Line 88:     "Let’s see what would be the regular expression pattern to\n",
# Line 89:     "recognise valid variable names:\n",
# Line 90:     "`r\"[A-Za-z_][A-Za-z_0-9]*\\Z\"`.\n",
# Line 91:     "Here we have used a shorthand for character ranges: `A-Z`.\n",
# Line 92:     "This means all the characters from `A` to `Z`.\n",
# Line 93:     "\n",
# Line 94:     "The first character of the variable name is defined in the first\n",
# Line 95:     "brackets. The subsequent characters are defined in the second\n",
# Line 96:     "brackets.\n",
# Line 97:     "The special character `*` means that we allow any number\n",
# Line 98:     "(0,1,2, . . . ) of the previous subpattern. For example the\n",
# Line 99:     "pattern `r\"ba*\"` allows strings `\"b\"`, `\"ba\"`, `\"baa\"`, `\"baaa\"`, and\n",
# Line 100:     "so on.\n",
# Line 101:     "The special syntax `\\Z` denotes the end of the string.\n",
# Line 102:     "Without it we would also accept `abc-` as a valid name since\n",
# Line 103:     "the `match` function normally checks only that a string starts with a pattern.\n",
# Line 104:     "\n",
# Line 105:     "The special notations, like `\\Z`, also cause problems with string\n",
# Line 106:     "handling.\n",
# Line 107:     "Remember that normally in string literals we have some\n",
# Line 108:     "special notation: `\\n` stands for newline, `\\t` stands for tab, and\n",
# Line 109:     "so on.\n",
# Line 110:     "So, both string literals and regular expressions use similar\n",
# Line 111:     "looking notations, which can create serious confusion.\n",
# Line 112:     "This can be solved by using the so-called *raw strings*. We\n",
# Line 113:     "denote a raw string by having an `r` letter before the first\n",
# Line 114:     "quotation mark, for example `r\"ab*\\Z\"`.\n",
# Line 115:     "When using raw strings, the newline (`\\n`), tab (`\\t`), and other\n",
# Line 116:     "special string literal notations aren’t interpreted. One should\n",
# Line 117:     "always use raw strings when defining regular expression\n",
# Line 118:     "patterns!"
# Line 119:    ]
# Line 120:   },
# Line 121:   {
# Line 122:    "cell_type": "markdown",
# Line 123:    "metadata": {
# Line 124:     "colab_type": "text",
# Line 125:     "id": "WL-EXDRr4JJo"
# Line 126:    },
# Line 127:    "source": [
# Line 128:     "### Patterns\n",
# Line 129:     "\n",
# Line 130:     "A pattern represents a set of strings. This set can even be\n",
# Line 131:     "potentially infinite.\n",
# Line 132:     "They can be used to describe a set of strings that have some\n",
# Line 133:     "commonality; some regular structure.\n",
# Line 134:     "Regular expressions (RE) are a classical computer science topic.\n",
# Line 135:     "They are very common in programming tasks. Scripting\n",
# Line 136:     "languages, like Python, are very fluent in regular expressions.\n",
# Line 137:     "Very complex text processing can be achieved using regular\n",
# Line 138:     "expressions.\n",
# Line 139:     "\n",
# Line 140:     "In patterns, normal characters (letters, numbers) just represent\n",
# Line 141:     "themselves, unless preceded by a backslash, which may trigger\n",
# Line 142:     "some special meaning.\n",
# Line 143:     "Punctuation characters have special meaning, unless preceded\n",
# Line 144:     "by backslash (`\\`), which deprives their special meaning.\n",
# Line 145:     "Use `\\\\` to represent a backslash character without any special\n",
# Line 146:     "meaning.\n",
# Line 147:     "In the following slides we will go through some of the more\n",
# Line 148:     "common RE notations.\n",
# Line 149:     "\n",
# Line 150:     "```\n",
# Line 151:     ". Matches any character\n",
# Line 152:     "[...] Matches any character contained within the brackets\n",
# Line 153:     "[^...] Matches any character not appearing after the hat (ˆ)\n",
# Line 154:     "ˆ Matches the start of the string\n",
# Line 155:     "$ Matches the end of the string\n",
# Line 156:     "* Matches zero or more previous RE\n",
# Line 157:     "+ Matches one or more previous RE\n",
# Line 158:     "{m,n} Matches m to n occurences of previous RE\n",
# Line 159:     "? Matches zero or one occurences of previous RE\n",
# Line 160:     "```\n",
# Line 161:     "\n",
# Line 162:     "We have already seen that a `|` character denotes alternatives.\n",
# Line 163:     "For example, the pattern `r\"Get (on|off|ready)\"` matches\n",
# Line 164:     "the following strings: `\"Get on\"`, `\"Get off\"`, `\"Get ready\"`.\n",
# Line 165:     "We can use parentheses to create groupings inside a pattern:\n",
# Line 166:     "`r\"(ab)+\"` will match the strings `\"ab\"`, `\"abab\"`, `\"ababab\"`,\n",
# Line 167:     "and so on.\n",
# Line 168:     "These groups are also given a reference number starting from 1. \n",
# Line 169:     "We can refer to groups using backreferences: `\\number`.\n",
# Line 170:     "For example, we can find separated patterns that get\n",
# Line 171:     "repeated: `r\"([a-z]{3,}) \\1 \\1\"`.\n",
# Line 172:     "This will recognise, for example, the following strings: `\"aca\n",
# Line 173:     "aca aca\"`, `\"turn turn turn\"`. But not the strings `\"aca\n",
# Line 174:     "aba aca\"` or `\"ac ac ac\"`.\n",
# Line 175:     "\n",
# Line 176:     "\n",
# Line 177:     "In the following, note that a hat (ˆ) as the first character\n",
# Line 178:     "inside brackets will create a complement set of characters:\n",
# Line 179:     "\n",
# Line 180:     "```\n",
# Line 181:     "`\\d` same as `[0-9]`, matches a digit\n",
# Line 182:     "`\\D` same as `[ˆ0-9]`, matches anything but a digit\n",
# Line 183:     "`\\s` matches a whitespace character (space, newline, tab, ... )\n",
# Line 184:     "`\\S` matches a nonwhitespace character\n",
# Line 185:     "`\\w` same as `[a-zA-Z0-9_]`, matches one alphanumeric character\n",
# Line 186:     "`\\W` matches one non-alphanumeric character\n",
# Line 187:     "```\n",
# Line 188:     "\n",
# Line 189:     "Using the above notation we can now shorten our previous\n",
# Line 190:     "variable name example to `r’[a-zA-Z_]\\w*\\Z’`\n",
# Line 191:     "\n",
# Line 192:     "The patterns `\\A`, `\\b`, `\\B`, and `\\Z` will all match an empty\n",
# Line 193:     "string, but in specific places.\n",
# Line 194:     "The patterns `\\A` and `\\Z` will recognise the beginning and end\n",
# Line 195:     "of the string, respectively.\n",
# Line 196:     "Note that the patterns `ˆ` and `$` can in some cases match also\n",
# Line 197:     "after a newline and before a newline, correspondingly.\n",
# Line 198:     "So, `\\A` is distinct from `ˆ`, and `\\Z` is distinct from `$`.\n",
# Line 199:     "The pattern `\\b` matches at the start or end of a word. The\n",
# Line 200:     "pattern `\\B` does the reverse."
# Line 201:    ]
# Line 202:   },
# Line 203:   {
# Line 204:    "cell_type": "markdown",
# Line 205:    "metadata": {
# Line 206:     "colab_type": "text",
# Line 207:     "id": "m2XG2faQ4JJp"
# Line 208:    },
# Line 209:    "source": [
# Line 210:     "### Match and search functions\n",
# Line 211:     "\n",
# Line 212:     "We have so far only used the `re.match` function which tries\n",
# Line 213:     "to find a match at the beginning of a string\n",
# Line 214:     "The function `re.search` allows to match any substring of a\n",
# Line 215:     "string.\n",
# Line 216:     "Example: `re.search(r'\\bback\\b', s)` will match\n",
# Line 217:     "strings `\"back\"`, `\"a back, is a body part\"`, `\"get back\"`. But it\n",
# Line 218:     "will not match the strings `\"backspace\"` or `\"comeback\"`.\n",
# Line 219:     "\n",
# Line 220:     "The function `re.search` finds only the first occurence.\n",
# Line 221:     "We can use the `re.findall` function to find all occurences.\n",
# Line 222:     "Let’s say we want to find all present participle words in a\n",
# Line 223:     "string `s`. The present participle words have ending `'ing'`.\n",
# Line 224:     "The function call would look like this:\n",
# Line 225:     "`re.findall(r'\\w+ing\\b', s)`.\n",
# Line 226:     "Let’s try running this:"
# Line 227:    ]
# Line 228:   },
# Line 229:   {
# Line 230:    "cell_type": "code",
# Line 231:    "execution_count": 2,
# Line 232:    "metadata": {
# Line 233:     "colab": {},
# Line 234:     "colab_type": "code",
# Line 235:     "id": "AIsbkC0I4JJp",
# Line 236:     "outputId": "fc7e8c40-d29d-4225-80f3-9fae69b04aa0"
# Line 237:    },
# Line 238:    "outputs": [
# Line 239:     {
# Line 240:      "data": {
# Line 241:       "text/plain": [
# Line 242:        "['Doing', 'going', 'staying', 'sleeping']"
# Line 243:       ]
# Line 244:      },
# Line 245:      "execution_count": 2,
# Line 246:      "metadata": {},
# Line 247:      "output_type": "execute_result"
# Line 248:     }
# Line 249:    ],
# Line 250:    "source": [
# Line 251:     "import re\n",
# Line 252:     "s = \"Doing things, going home, staying awake, sleeping later\"\n",
# Line 253:     "re.findall(r'\\w+ing\\b', s)"
# Line 254:    ]
# Line 255:   },
# Line 256:   {
# Line 257:    "cell_type": "markdown",
# Line 258:    "metadata": {
# Line 259:     "colab_type": "text",
# Line 260:     "id": "lroKuJx94JJt"
# Line 261:    },
# Line 262:    "source": [
# Line 263:     "Let’s say we want to pick up all the integers from a string.\n",
# Line 264:     "We can try that with the following function call:\n",
# Line 265:     "`re.findall(r'[+-]?\\d+', s)`.\n",
# Line 266:     "An example run:"
# Line 267:    ]
# Line 268:   },
# Line 269:   {
# Line 270:    "cell_type": "code",
# Line 271:    "execution_count": 3,
# Line 272:    "metadata": {
# Line 273:     "colab": {},
# Line 274:     "colab_type": "code",
# Line 275:     "id": "5zGb2Mrs4JJu",
# Line 276:     "outputId": "b9fb7b25-e790-4e83-a564-cee5690d8a11"
# Line 277:    },
# Line 278:    "outputs": [
# Line 279:     {
# Line 280:      "data": {
# Line 281:       "text/plain": [
# Line 282:        "['23', '-24', '-1']"
# Line 283:       ]
# Line 284:      },
# Line 285:      "execution_count": 3,
# Line 286:      "metadata": {},
# Line 287:      "output_type": "execute_result"
# Line 288:     }
# Line 289:    ],
# Line 290:    "source": [
# Line 291:     "re.findall(r'[+-]?\\d+', \"23 + -24 = -1\")"
# Line 292:    ]
# Line 293:   },
# Line 294:   {
# Line 295:    "cell_type": "markdown",
# Line 296:    "metadata": {
# Line 297:     "colab_type": "text",
# Line 298:     "id": "hCTcaMnH4JJx"
# Line 299:    },
# Line 300:    "source": [
# Line 301:     "Suppose we are given a string of if/then sentences, and we\n",
# Line 302:     "would like to extract the conditions from these sentences.\n",
# Line 303:     "Let’s try the following function call:\n",
# Line 304:     "`re.findall(r'[Ii]f (.*), then', s)`.\n",
# Line 305:     "An example run:"
# Line 306:    ]
# Line 307:   },
# Line 308:   {
# Line 309:    "cell_type": "code",
# Line 310:    "execution_count": 5,
# Line 311:    "metadata": {
# Line 312:     "colab": {},
# Line 313:     "colab_type": "code",
# Line 314:     "id": "3JQGT5q74JJx",
# Line 315:     "outputId": "07fa024f-b1bd-4756-bbe1-d59b123a872c"
# Line 316:    },
# Line 317:    "outputs": [
# Line 318:     {
# Line 319:      "data": {
# Line 320:       "text/plain": [
# Line 321:        "['I’m not in a hurry, then I should stay. On the other hand, if I leave']"
# Line 322:       ]
# Line 323:      },
# Line 324:      "execution_count": 5,
# Line 325:      "metadata": {},
# Line 326:      "output_type": "execute_result"
# Line 327:     }
# Line 328:    ],
# Line 329:    "source": [
# Line 330:     "s = (\"If I’m not in a hurry, then I should stay. \" +\n",
# Line 331:     "    \"On the other hand, if I leave, then I can sleep.\")\n",
# Line 332:     "re.findall(r'[Ii]f (.*), then', s)"
# Line 333:    ]
# Line 334:   },
# Line 335:   {
# Line 336:    "cell_type": "markdown",
# Line 337:    "metadata": {
# Line 338:     "colab_type": "text",
# Line 339:     "id": "o83dBA3Q4JJ0"
# Line 340:    },
# Line 341:    "source": [
# Line 342:     "But I wanted a result: `[\"I'm not in a hurry\", 'I leave']`. That\n",
# Line 343:     "is, the condition from both sentences. How can this be fixed?\n",
# Line 344:     "\n",
# Line 345:     "The problem is that the pattern `.*` tries to match as many\n",
# Line 346:     "characters as possible.\n",
# Line 347:     "This is called *greedy matching*.\n",
# Line 348:     "One way of solving this problem is to notice that the two\n",
# Line 349:     "sentences are separated by a full-stop (.).\n",
# Line 350:     "So, instead of matching all the characters, we need to match\n",
# Line 351:     "everything but the dot character.\n",
# Line 352:     "This can be achieved by using the complement character\n",
# Line 353:     "class: `[^.]`. The hat character (`ˆ`) in the beginning of a\n",
# Line 354:     "character class means the complement character class\n",
# Line 355:     "\n",
# Line 356:     "After the modification the function call looks like this:\n",
# Line 357:     "`re.findall(r'[Ii]f ([^.]*), then', s)`.\n",
# Line 358:     "Another way of solving this problem is to use a non-greedy\n",
# Line 359:     "matching.\n",
# Line 360:     "The repetition specifiers `+`, `*`, `?`, and `{m,n}` have\n",
# Line 361:     "corresponding non-greedy versions: `+?`, `*?`, `??`, and `{m,n}?`.\n",
# Line 362:     "These expressions use as few characters as possible to make\n",
# Line 363:     "the whole pattern match some substring.\n",
# Line 364:     "By using non-greedy version, the function call looks like this:\n",
# Line 365:     "`re.findall(r’[Ii]f (.*?), then’, s)`.\n",
# Line 366:     "\n"
# Line 367:    ]
# Line 368:   },
# Line 369:   {
# Line 370:    "cell_type": "markdown",
# Line 371:    "metadata": {
# Line 372:     "colab_type": "text",
# Line 373:     "id": "5o6IDW0g4JJ1"
# Line 374:    },
# Line 375:    "source": [
# Line 376:     "### Functions in the `re` module\n",
# Line 377:     "\n",
# Line 378:     "Below is a list of the most common functions in the `re` module\n",
# Line 379:     "\n",
# Line 380:     "* `re.match(pattern, str)`\n",
# Line 381:     "* `re.search(pattern, str)`\n",
# Line 382:     "* `re.findall(pattern, str)`\n",
# Line 383:     "* `re.finditer(pattern, str)`\n",
# Line 384:     "* `re.sub(pattern, replacement, str, count=0)`\n",
# Line 385:     "\n",
# Line 386:     "Functions `match` and `search` return a *match object*.\n",
# Line 387:     "A match object describes the found occurence.\n",
# Line 388:     "The function `findall` returns a list of all the occurences of\n",
# Line 389:     "the pattern. The elements in the list are strings.\n",
# Line 390:     "The function `finditer` works like `findall` function except\n",
# Line 391:     "that instead of returning a list, it returns an iterator whose\n",
# Line 392:     "items are match objects.\n",
# Line 393:     "The function `sub` replaces all the occurences of the pattern in\n",
# Line 394:     "`str` with the string replacement and returns the new string.\n",
# Line 395:     "\n",
# Line 396:     "An example: The following program will replace all \"she\"\n",
# Line 397:     "words with \"he\"\n",
# Line 398:     "\n",
# Line 399:     "```\n",
# Line 400:     "import re\n",
# Line 401:     "str = \"She goes where she wants to, she's a sheriff.\"\n",
# Line 402:     "newstr = re.sub(r'\\b[Ss]he\\b', 'he', str)\n",
# Line 403:     "print newstr\n",
# Line 404:     "```\n",
# Line 405:     "\n",
# Line 406:     "This will print `he goes where he wants to, he's a sheriff.`\n",
# Line 407:     "\n",
# Line 408:     "The `sub` function can also use backreferences to refer to the\n",
# Line 409:     "matched string. The backreferences \\1, \\2, and so on, refer\n",
# Line 410:     "to the groups of the pattern, in order.\n",
# Line 411:     "An example:\n",
# Line 412:     "```\n",
# Line 413:     "import re\n",
# Line 414:     "str = \"\"\"He is the president of Russia.\n",
# Line 415:     "He’s a powerful man.\"\"\"\n",
# Line 416:     "newstr = re.sub(r'(\\b[Hh]e\\b)', r'\\1 (Putin)', str, 1)\n",
# Line 417:     "print newstr\n",
# Line 418:     "```\n",
# Line 419:     "\n",
# Line 420:     "This will print\n",
# Line 421:     "```\n",
# Line 422:     "He (Putin) is the president of Russia.\n",
# Line 423:     "He’s a powerful man.\n",
# Line 424:     "```"
# Line 425:    ]
# Line 426:   },
# Line 427:   {
# Line 428:    "cell_type": "markdown",
# Line 429:    "metadata": {
# Line 430:     "colab_type": "text",
# Line 431:     "id": "rXO76XTL4JJ1"
# Line 432:    },
# Line 433:    "source": [
# Line 434:     "### Match object\n",
# Line 435:     "\n",
# Line 436:     "Functions `match`, `search`, and `finditer` use `match` objects\n",
# Line 437:     "to describe the found occurence.\n",
# Line 438:     "The method `groups()` of the match object returns the tuple\n",
# Line 439:     "of all the substrings matched by the groups of the pattern.\n",
# Line 440:     "Each pair of parentheses in the pattern creates a new group.\n",
# Line 441:     "These groups are are referred to by indices 1, 2, ...\n",
# Line 442:     "The group 0 is a special one: it refers to the match created by\n",
# Line 443:     "the whole pattern.\n",
# Line 444:     "\n",
# Line 445:     "Let’s look at the match object returned by the call\n",
# Line 446:     "\n",
# Line 447:     "```\n",
# Line 448:     "mo = re.search(r'\\d+ (\\d+) \\d+ (\\d+)',\n",
# Line 449:     "'first 123 45 67 890 last')\n",
# Line 450:     "```\n",
# Line 451:     "\n",
# Line 452:     "The call `mo.groups()` returns a tuple `(’45’, ’890’)`.\n",
# Line 453:     "We can access just some individual groups by using the\n",
# Line 454:     "method `group(gid, ...)`.\n",
# Line 455:     "For example, the call `mo.group(1)` will return `’45’`.\n",
# Line 456:     "The zeroth group will represent the whole match:\n",
# Line 457:     "`’123 45 67 890’`\n",
# Line 458:     "\n",
# Line 459:     "In addition to accessing the strings matched by the pattern\n",
# Line 460:     "and its groups, the corresponding indices of the original string\n",
# Line 461:     "can be accessed:\n",
# Line 462:     "\n",
# Line 463:     "* The `start(gid=0)` and `end(gid=0)` methods return the start\n",
# Line 464:     "and end indices of the matched group gid, correspondingly\n",
# Line 465:     "* The method `span(gid)` just returns the pair of these start\n",
# Line 466:     "and end indices\n",
# Line 467:     "\n",
# Line 468:     "The match object mo can also be used like a boolean value:\n",
# Line 469:     "\n",
# Line 470:     "```python\n",
# Line 471:     "mo = re.search(...)\n",
# Line 472:     "if mo:\n",
# Line 473:     "    # do something\n",
# Line 474:     "```\n",
# Line 475:     "\n",
# Line 476:     "will do something if a match was found.\n",
# Line 477:     "Alternatively, the match object can be converted to a boolean\n",
# Line 478:     "value by the call `found = bool(mo)`."
# Line 479:    ]
# Line 480:   },
# Line 481:   {
# Line 482:    "cell_type": "markdown",
# Line 483:    "metadata": {
# Line 484:     "colab_type": "text",
# Line 485:     "id": "RkSvuBPH4JJ2"
# Line 486:    },
# Line 487:    "source": [
# Line 488:     "### Miscellaneous stuff\n",
# Line 489:     "\n",
# Line 490:     "If the same pattern is used in many function calls, it may be\n",
# Line 491:     "wise to precompile the pattern, mainly for efficiency reasons.\n",
# Line 492:     "This can be done using the `compile(pattern, flags=0)` function\n",
# Line 493:     "in the `re` module. The function returns a so-called RE object.\n",
# Line 494:     "The RE object has method versions of the functions found in\n",
# Line 495:     "module `re`.\n",
# Line 496:     "The only difference is that the first parameter is not the\n",
# Line 497:     "pattern since the precompiled pattern is stored in the RE\n",
# Line 498:     "object.\n",
# Line 499:     "\n",
# Line 500:     "The details of matching operation can be specified using\n",
# Line 501:     "optional flags.\n",
# Line 502:     "These flags can be given either inside the pattern or as a\n",
# Line 503:     "parameter to the compile function.\n",
# Line 504:     "Some of the more common flags are given in the following\n",
# Line 505:     "table\n",
# Line 506:     "\n",
# Line 507:     "| x   | Flag |\n",
# Line 508:     "|-----|--------------|\n",
# Line 509:     "|`(?i)` | re.IGNORECASE|\n",
# Line 510:     "|`(?m)` | re.MULTILINE|\n",
# Line 511:     "|`(?s)` | re.DOTALL|\n",
# Line 512:     "\n",
# Line 513:     "The elements on the left can appear anywhere in the pattern\n",
# Line 514:     "but preferably in the beginning.\n",
# Line 515:     "On the right there are attributes of the re module that can be\n",
# Line 516:     "given to the compile function as the second parameter\n",
# Line 517:     "\n",
# Line 518:     "The `IGNORECASE` flag makes lower- and uppercase\n",
# Line 519:     "characters appear as equal.\n",
# Line 520:     "The `MULTILINE` flag makes the special characters `ˆ` and `$`\n",
# Line 521:     "match the beginning and end of each line in addition to the\n",
# Line 522:     "beginning and end of the whole string. These flags make `\\A`\n",
# Line 523:     "differ from `ˆ`, and `\\Z` differ from `$`.\n",
# Line 524:     "The `DOTALL` flag makes the character class `.` (dot) also\n",
# Line 525:     "accept the newline character, in addition to all the other\n",
# Line 526:     "letters.\n",
# Line 527:     "\n",
# Line 528:     "When giving multiple flags to the compile function, the flags\n",
# Line 529:     "can be separated with the `|` sign.\n",
# Line 530:     "For example, `re.compile(pattern, re.MULTILINE | re.DOTALL)`.\n",
# Line 531:     "This is equal to `re.compile('(?m)(?s)' + pattern)`."
# Line 532:    ]
# Line 533:   },
# Line 534:   {
# Line 535:    "cell_type": "markdown",
# Line 536:    "metadata": {
# Line 537:     "colab_type": "text",
# Line 538:     "id": "BcogP4iR4JJ2"
# Line 539:    },
# Line 540:    "source": [
# Line 541:     "#### <div class=\"alert alert-info\">Group Exercise 1 (integers in brackets)</div>\n",
# Line 542:     "\n",
# Line 543:     "Write function `integers_in_brackets` that finds from a given string all integers that are enclosed in brackets.\n",
# Line 544:     "\n",
# Line 545:     "Example run:\n",
# Line 546:     "`integers_in_brackets(\"  afd [asd] [12 ] [a34]  [ -43 ]tt [+12]xxx\")`\n",
# Line 547:     "returns\n",
# Line 548:     "`[12, -43, 12]`.\n",
# Line 549:     "So there can be whitespace between the number and the brackets, but no other character besides those that make up the integer.\n",
# Line 550:     "\n",
# Line 551:     "Test your function from the `main` function.\n",
# Line 552:     "<hr/>"
# Line 553:    ]
# Line 554:   },
# Line 555:   {
# Line 556:    "cell_type": "raw",
# Line 557:    "metadata": {},
# Line 558:    "source": [
# Line 559:     "import re\n",
# Line 560:     "\n",
# Line 561:     "def integers_in_brackets(x):\n",
# Line 562:     "    y = re.findall(\"\\[(.*?)\\]\", x)\n",
# Line 563:     "\n",
# Line 564:     "    for i in range(len(y)):\n",
# Line 565:     "        re.findall(r'[+-]\\d+', y(i))\n",
# Line 566:     "        \n",
# Line 567:     "      # print(y[i])\n",
# Line 568:     "      # print(z)\n",
# Line 569:     "  # for i in range(len(y)):\n",
# Line 570:     "  #     print(y[i].isdigit())\n",
# Line 571:     "  #.         print(y[i])\n",
# Line 572:     "  # z = re.findall('-?\\d+', x)\n",
# Line 573:     "  # y = re.findall('\\W', x)\n",
# Line 574:     "  # print(z) \n",
# Line 575:     "    \n",
# Line 576:     "integers_in_brackets(\"  afd [asd] [12 ] [a34]  [ -43 ]tt [+12]xxx\")"
# Line 577:    ]
# Line 578:   },
# Line 579:   {
# Line 580:    "cell_type": "code",
# Line 581:    "execution_count": 3,
# Line 582:    "metadata": {},
# Line 583:    "outputs": [
# Line 584:     {
# Line 585:      "data": {
# Line 586:       "text/plain": [
# Line 587:        "['12', '34', '-43', '+12']"
# Line 588:       ]
# Line 589:      },
# Line 590:      "execution_count": 3,
# Line 591:      "metadata": {},
# Line 592:      "output_type": "execute_result"
# Line 593:     }
# Line 594:    ],
# Line 595:    "source": [
# Line 596:     "import re\n",
# Line 597:     "re.findall(r'[+-]?\\d+', \"  afd [asd] [12 ] [a34]  [ -43 ]tt [+12]xxx\")"
# Line 598:    ]
# Line 599:   },
# Line 600:   {
# Line 601:    "cell_type": "markdown",
# Line 602:    "metadata": {
# Line 603:     "colab_type": "text",
# Line 604:     "id": "YU7agwbW4JJ3"
# Line 605:    },
# Line 606:    "source": [
# Line 607:     "## Basic file processing"
# Line 608:    ]
# Line 609:   },
# Line 610:   {
# Line 611:    "cell_type": "markdown",
# Line 612:    "metadata": {
# Line 613:     "colab_type": "text",
# Line 614:     "id": "g3hx0Oo74JJ3"
# Line 615:    },
# Line 616:    "source": [
# Line 617:     "A file can be opened with the `open` function. The call `open(filename, mode=\"r\")` will return a *file object*, whose type is `file`. This file object can be used to refer to a file on disk. For example, when we want to read from or write to a file, we can used the methods `read` and `write` of the file object. After the file object is no longer needed, a call to the `close` method should be made.\n",
# Line 618:     "\n",
# Line 619:     "We can control what kind of operations we can perform on a file with the *mode* parameter of the `open` function. Different options include opening a file for reading or writing,\n",
# Line 620:     "whether the file should exists already or be created with the\n",
# Line 621:     "call to open, etc. Here's a list of all the opening modes:\n",
# Line 622:     "\n",
# Line 623:     "| Mode | Description |\n",
# Line 624:     "| ---- | ----------- |\n",
# Line 625:     "| `r`  | read-only mode, file must exist |\n",
# Line 626:     "| `w`  | write-only mode, creates, or overwrites an existing file |\n",
# Line 627:     "| `a`  | write-only mode, write always appends to the end |\n",
# Line 628:     "| `r+` | read/write mode, file must already exist |\n",
# Line 629:     "| `w+` | read/write mode, creates, or overwrites an existing file |\n",
# Line 630:     "| `a+` | read/write mode, write will append to end |"
# Line 631:    ]
# Line 632:   },
# Line 633:   {
# Line 634:    "cell_type": "markdown",
# Line 635:    "metadata": {
# Line 636:     "colab_type": "text",
# Line 637:     "id": "wfehRCcU4JJ4"
# Line 638:    },
# Line 639:    "source": [
# Line 640:     "In the end of the mode string either the letter `t` or `b` can be appended. These stand for text mode and binary mode. If this letter is not given, the file type is text mode by default. \n",
# Line 641:     "\n",
# Line 642:     "For binary mode the contents of the file are not interpreted in any way, and the read and write methods handle bytes. (A byte consists of 8 bits and can be used to represent a number in the range 0 to 255.)\n",
# Line 643:     "\n",
# Line 644:     "In the text mode two interpretations happen\n",
# Line 645:     "\n",
# Line 646:     "* On Windows operating system the end of line in files is encoded by two characters. When the file is read these two charactes are converted to `'\\n'` character. During writes to a file this conversion happens in the opposite direction.\n",
# Line 647:     "* One character is encoded in the file as one or more bytes. This conversion happens automatically during read and write operations. One common encoding between bytes and characters is utf-8. In this encoding, the Finnish character `'ä'`, for example, is encoded as the following sequence of bytes:"
# Line 648:    ]
# Line 649:   },
# Line 650:   {
# Line 651:    "cell_type": "code",
# Line 652:    "execution_count": 0,
# Line 653:    "metadata": {
# Line 654:     "colab": {},
# Line 655:     "colab_type": "code",
# Line 656:     "id": "bi7G-bfk4JJ4",
# Line 657:     "outputId": "5a7f59ef-5b46-4135-9014-7827ad71992e"
# Line 658:    },
# Line 659:    "outputs": [
# Line 660:     {
# Line 661:      "data": {
# Line 662:       "text/plain": [
# Line 663:        "b'\\xc3\\xa4'"
# Line 664:       ]
# Line 665:      },
# Line 666:      "execution_count": 4,
# Line 667:      "metadata": {
# Line 668:       "tags": []
# Line 669:      },
# Line 670:      "output_type": "execute_result"
# Line 671:     }
# Line 672:    ],
# Line 673:    "source": [
# Line 674:     "\"ä\".encode(\"utf-8\")"
# Line 675:    ]
# Line 676:   },
# Line 677:   {
# Line 678:    "cell_type": "markdown",
# Line 679:    "metadata": {
# Line 680:     "colab_type": "text",
# Line 681:     "id": "E653sxG-4JJ7"
# Line 682:    },
# Line 683:    "source": [
# Line 684:     "Above the two bytes were expressed as hexadecimals. In decimal notation they would be 195 and 164. (Both in the range from 0 to 255.)"
# Line 685:    ]
# Line 686:   },
# Line 687:   {
# Line 688:    "cell_type": "code",
# Line 689:    "execution_count": 0,
# Line 690:    "metadata": {
# Line 691:     "colab": {},
# Line 692:     "colab_type": "code",
# Line 693:     "id": "ebnUZrf14JJ8",
# Line 694:     "outputId": "ef90dff5-2432-453b-aa2b-c05afacdb09f"
# Line 695:    },
# Line 696:    "outputs": [
# Line 697:     {
# Line 698:      "data": {
# Line 699:       "text/plain": [
# Line 700:        "[195, 164]"
# Line 701:       ]
# Line 702:      },
# Line 703:      "execution_count": 5,
# Line 704:      "metadata": {
# Line 705:       "tags": []
# Line 706:      },
# Line 707:      "output_type": "execute_result"
# Line 708:     }
# Line 709:    ],
# Line 710:    "source": [
# Line 711:     "list(\"ä\".encode(\"utf-8\"))              # Show as a list of integers"
# Line 712:    ]
# Line 713:   },
# Line 714:   {
# Line 715:    "cell_type": "markdown",
# Line 716:    "metadata": {
# Line 717:     "colab_type": "text",
# Line 718:     "id": "cEIpbwTJ4JJ_"
# Line 719:    },
# Line 720:    "source": [
# Line 721:     "What is the utf-8 encoding of the letter `'a'`?\n",
# Line 722:     "\n",
# Line 723:     "During this course we will only consider files containing text, so the default text mode is fine for us. But we might sometimes have to specify the encoding of a file, if it is not the usual utf-8."
# Line 724:    ]
# Line 725:   },
# Line 726:   {
# Line 727:    "cell_type": "markdown",
# Line 728:    "metadata": {
# Line 729:     "colab_type": "text",
# Line 730:     "id": "b0ED6foV4JJ_"
# Line 731:    },
# Line 732:    "source": [
# Line 733:     "### Some common file object methods\n",
# Line 734:     "* `read(size)` will read size characters/bytes as a string\n",
# Line 735:     "* `write(string)` will write string/bytes to a file\n",
# Line 736:     "* `readline()` will read a string until and including the next newline character is met\n",
# Line 737:     "* `readlines()` will return a list of all lines of a file\n",
# Line 738:     "* `writelines()` will write a list of lines to a file\n",
# Line 739:     "* `flush()` will try to make sure that the changes made to a file are written to disk immediately"
# Line 740:    ]
# Line 741:   },
# Line 742:   {
# Line 743:    "cell_type": "code",
# Line 744:    "execution_count": 2,
# Line 745:    "metadata": {
# Line 746:     "ExecuteTime": {
# Line 747:      "end_time": "2019-06-13T14:52:31.003612Z",
# Line 748:      "start_time": "2019-06-13T14:52:30.995901Z"
# Line 749:     },
# Line 750:     "colab": {},
# Line 751:     "colab_type": "code",
# Line 752:     "id": "P3tBv6Ln4JJ_",
# Line 753:     "outputId": "ea9275f3-1a01-4670-d34b-a18a9f811284"
# Line 754:    },
# Line 755:    "outputs": [
# Line 756:     {
# Line 757:      "name": "stdout",
# Line 758:      "output_type": "stream",
# Line 759:      "text": [
# Line 760:       "Line 0: {\n",
# Line 761:       "Line 1:  \"cells\": [\n",
# Line 762:       "Line 2:   {\n",
# Line 763:       "Line 3:    \"cell_type\": \"markdown\",\n",
# Line 764:       "Line 4:    \"metadata\": {\n",
# Line 765:       "Line 5:     \"colab_type\": \"text\",\n",
# Line 766:       "Line 6:     \"id\": \"ckl7mcSK4JJm\"\n",
# Line 767:       "Line 7:    },\n",
# Line 768:       "Line 8:    \"source\": [\n",
# Line 769:       "Line 9:     \"Data Science Fundamentals: Python |\\n\",\n",
# Line 770:       "Line 10:     \"[Table of Contents](../index.ipynb)\\n\",\n",
# Line 771:       "Line 11:     \"- - - \\n\",\n",
# Line 772:       "Line 12:     \"<!--NAVIGATION-->\\n\",\n",
# Line 773:       "Line 13:     \"Module 6. | [Generators](./01_generators.ipynb) | **[Regular Expressions](./02_regex.ipynb)** | [String Manipulation & Regular Expressions](03_str_manipulate.ipynb) | [Closures & Generators](./04_closures_generators.ipynb) | [Exercises](./05_gen_regex_exercises.ipynb)\"\n",
# Line 774:       "Line 14:    ]\n",
# Line 775:       "Line 15:   },\n",
# Line 776:       "Line 16:   {\n",
# Line 777:       "Line 17:    \"cell_type\": \"markdown\",\n",
# Line 778:       "Line 18:    \"metadata\": {\n",
# Line 779:       "Line 19:     \"colab_type\": \"text\",\n",
# Line 780:       "Line 20:     \"id\": \"CeDr6HXa4JJm\"\n",
# Line 781:       "Line 21:    },\n",
# Line 782:       "Line 22:    \"source\": [\n",
# Line 783:       "Line 23:     \"## Regular Expression Generators for Python\"\n",
# Line 784:       "Line 24:    ]\n",
# Line 785:       "Line 25:   },\n",
# Line 786:       "Line 26:   {\n",
# Line 787:       "Line 27:    \"cell_type\": \"markdown\",\n",
# Line 788:       "Line 28:    \"metadata\": {},\n",
# Line 789:       "Line 29:    \"source\": [\n",
# Line 790:       "Line 30:     \"### [Pyregex](http://www.pyregex.com/)\"\n",
# Line 791:       "Line 31:    ]\n",
# Line 792:       "Line 32:   },\n",
# Line 793:       "Line 33:   {\n",
# Line 794:       "Line 34:    \"cell_type\": \"markdown\",\n",
# Line 795:       "Line 35:    \"metadata\": {},\n",
# Line 796:       "Line 36:    \"source\": [\n",
# Line 797:       "Line 37:     \"### [Pythex](https://pythex.org/) \\n\",\n",
# Line 798:       "Line 38:     \"\\n\",\n",
# Line 799:       "Line 39:     \"- - -\\n\",\n",
# Line 800:       "Line 40:     \"\\n\",\n",
# Line 801:       "Line 41:     \"[Regular Expression Cheatsheet](https://learnbyexample.github.io/cheatsheet/python/python-regex-cheatsheet/)\\n\",\n",
# Line 802:       "Line 42:     \"<br>\\n\",\n",
# Line 803:       "Line 43:     \"[Regular Expression Operations Documentation](https://docs.python.org/2/library/re.html)\"\n",
# Line 804:       "Line 44:    ]\n",
# Line 805:       "Line 45:   },\n",
# Line 806:       "Line 46:   {\n",
# Line 807:       "Line 47:    \"cell_type\": \"markdown\",\n",
# Line 808:       "Line 48:    \"metadata\": {},\n",
# Line 809:       "Line 49:    \"source\": [\n",
# Line 810:       "Line 50:     \"## Regular Expressions\"\n",
# Line 811:       "Line 51:    ]\n",
# Line 812:       "Line 52:   },\n",
# Line 813:       "Line 53:   {\n",
# Line 814:       "Line 54:    \"cell_type\": \"markdown\",\n",
# Line 815:       "Line 55:    \"metadata\": {\n",
# Line 816:       "Line 56:     \"colab_type\": \"text\",\n",
# Line 817:       "Line 57:     \"id\": \"nAvFyyd64JJo\"\n",
# Line 818:       "Line 58:    },\n",
# Line 819:       "Line 59:    \"source\": [\n",
# Line 820:       "Line 60:     \"### Examples\\n\",\n",
# Line 821:       "Line 61:     \"\\n\",\n",
# Line 822:       "Line 62:     \"We have already seen that we can ask from a string `str`\\n\",\n",
# Line 823:       "Line 63:     \"whether it begins with some substring as follows:\\n\",\n",
# Line 824:       "Line 64:     \"`str.startswith('Apple')`.\\n\",\n",
# Line 825:       "Line 65:     \"If we would like to know whether it starts with `\\\"Apple\\\"` or\\n\",\n",
# Line 826:       "Line 66:     \"`\\\"apple\\\"`, we would have to call `startswith` method twice.\\n\",\n",
# Line 827:       "Line 67:     \"Regular expressions offer a simpler solution:\\n\",\n",
# Line 828:       "Line 68:     \"`re.match(r\\\"[Aa]pple\\\", str)`.\\n\",\n",
# Line 829:       "Line 69:     \"The bracket notation is one example of the special syntax of\\n\",\n",
# Line 830:       "Line 70:     \"*regular expressions*. In this case it says that any of the\\n\",\n",
# Line 831:       "Line 71:     \"characters inside brackets will do: either `\\\"A\\\"` or `\\\"a\\\"`. The other\\n\",\n",
# Line 832:       "Line 72:     \"letters in `\\\"pple\\\"` will act normally. The string `r\\\"[Aa]pple\\\"` is\\n\",\n",
# Line 833:       "Line 73:     \"called a *pattern*.\\n\",\n",
# Line 834:       "Line 74:     \"\\n\",\n",
# Line 835:       "Line 75:     \"A more complicated example asks whether the string `str`\\n\",\n",
# Line 836:       "Line 76:     \"starts with either `apple` or `banana` (no matter if the first letter\\n\",\n",
# Line 837:       "Line 77:     \"is capital or not):\\n\",\n",
# Line 838:       "Line 78:     \"`re.match(r\\\"[Aa]pple|[Bb]anana\\\", str)`.\\n\",\n",
# Line 839:       "Line 79:     \"In this example we saw a new special character `|` that denotes\\n\",\n",
# Line 840:       "Line 80:     \"an alternative. On either side of the bar character we have a\\n\",\n",
# Line 841:       "Line 81:     \"*subpattern*.\\n\",\n",
# Line 842:       "Line 82:     \"\\n\",\n",
# Line 843:       "Line 83:     \"A legal variable name in Python starts with a letter or an\\n\",\n",
# Line 844:       "Line 84:     \"underline character and the following characters can also be\\n\",\n",
# Line 845:       "Line 85:     \"digits.\\n\",\n",
# Line 846:       "Line 86:     \"So legal names are, for instance: `_hidden`, `L_value`, `A123_`.\\n\",\n",
# Line 847:       "Line 87:     \"But the name `2abc` is not a valid variable name.\\n\",\n",
# Line 848:       "Line 88:     \"Let’s see what would be the regular expression pattern to\\n\",\n",
# Line 849:       "Line 89:     \"recognise valid variable names:\\n\",\n",
# Line 850:       "Line 90:     \"`r\\\"[A-Za-z_][A-Za-z_0-9]*\\\\Z\\\"`.\\n\",\n",
# Line 851:       "Line 91:     \"Here we have used a shorthand for character ranges: `A-Z`.\\n\",\n",
# Line 852:       "Line 92:     \"This means all the characters from `A` to `Z`.\\n\",\n",
# Line 853:       "Line 93:     \"\\n\",\n",
# Line 854:       "Line 94:     \"The first character of the variable name is defined in the first\\n\",\n",
# Line 855:       "Line 95:     \"brackets. The subsequent characters are defined in the second\\n\",\n",
# Line 856:       "Line 96:     \"brackets.\\n\",\n",
# Line 857:       "Line 97:     \"The special character `*` means that we allow any number\\n\",\n",
# Line 858:       "Line 98:     \"(0,1,2, . . . ) of the previous subpattern. For example the\\n\",\n",
# Line 859:       "Line 99:     \"pattern `r\\\"ba*\\\"` allows strings `\\\"b\\\"`, `\\\"ba\\\"`, `\\\"baa\\\"`, `\\\"baaa\\\"`, and\\n\",\n",
# Line 860:       "Line 100:     \"so on.\\n\",\n",
# Line 861:       "Line 101:     \"The special syntax `\\\\Z` denotes the end of the string.\\n\",\n",
# Line 862:       "Line 102:     \"Without it we would also accept `abc-` as a valid name since\\n\",\n",
# Line 863:       "Line 103:     \"the `match` function normally checks only that a string starts with a pattern.\\n\",\n",
# Line 864:       "Line 104:     \"\\n\",\n",
# Line 865:       "Line 105:     \"The special notations, like `\\\\Z`, also cause problems with string\\n\",\n",
# Line 866:       "Line 106:     \"handling.\\n\",\n",
# Line 867:       "Line 107:     \"Remember that normally in string literals we have some\\n\",\n",
# Line 868:       "Line 108:     \"special notation: `\\\\n` stands for newline, `\\\\t` stands for tab, and\\n\",\n",
# Line 869:       "Line 109:     \"so on.\\n\",\n",
# Line 870:       "Line 110:     \"So, both string literals and regular expressions use similar\\n\",\n",
# Line 871:       "Line 111:     \"looking notations, which can create serious confusion.\\n\",\n",
# Line 872:       "Line 112:     \"This can be solved by using the so-called *raw strings*. We\\n\",\n",
# Line 873:       "Line 113:     \"denote a raw string by having an `r` letter before the first\\n\",\n",
# Line 874:       "Line 114:     \"quotation mark, for example `r\\\"ab*\\\\Z\\\"`.\\n\",\n",
# Line 875:       "Line 115:     \"When using raw strings, the newline (`\\\\n`), tab (`\\\\t`), and other\\n\",\n",
# Line 876:       "Line 116:     \"special string literal notations aren’t interpreted. One should\\n\",\n",
# Line 877:       "Line 117:     \"always use raw strings when defining regular expression\\n\",\n",
# Line 878:       "Line 118:     \"patterns!\"\n",
# Line 879:       "Line 119:    ]\n",
# Line 880:       "Line 120:   },\n",
# Line 881:       "Line 121:   {\n",
# Line 882:       "Line 122:    \"cell_type\": \"markdown\",\n",
# Line 883:       "Line 123:    \"metadata\": {\n",
# Line 884:       "Line 124:     \"colab_type\": \"text\",\n",
# Line 885:       "Line 125:     \"id\": \"WL-EXDRr4JJo\"\n",
# Line 886:       "Line 126:    },\n",
# Line 887:       "Line 127:    \"source\": [\n",
# Line 888:       "Line 128:     \"### Patterns\\n\",\n",
# Line 889:       "Line 129:     \"\\n\",\n",
# Line 890:       "Line 130:     \"A pattern represents a set of strings. This set can even be\\n\",\n",
# Line 891:       "Line 131:     \"potentially infinite.\\n\",\n",
# Line 892:       "Line 132:     \"They can be used to describe a set of strings that have some\\n\",\n",
# Line 893:       "Line 133:     \"commonality; some regular structure.\\n\",\n",
# Line 894:       "Line 134:     \"Regular expressions (RE) are a classical computer science topic.\\n\",\n",
# Line 895:       "Line 135:     \"They are very common in programming tasks. Scripting\\n\",\n",
# Line 896:       "Line 136:     \"languages, like Python, are very fluent in regular expressions.\\n\",\n",
# Line 897:       "Line 137:     \"Very complex text processing can be achieved using regular\\n\",\n",
# Line 898:       "Line 138:     \"expressions.\\n\",\n",
# Line 899:       "Line 139:     \"\\n\",\n",
# Line 900:       "Line 140:     \"In patterns, normal characters (letters, numbers) just represent\\n\",\n",
# Line 901:       "Line 141:     \"themselves, unless preceded by a backslash, which may trigger\\n\",\n",
# Line 902:       "Line 142:     \"some special meaning.\\n\",\n",
# Line 903:       "Line 143:     \"Punctuation characters have special meaning, unless preceded\\n\",\n",
# Line 904:       "Line 144:     \"by backslash (`\\\\`), which deprives their special meaning.\\n\",\n",
# Line 905:       "Line 145:     \"Use `\\\\\\\\` to represent a backslash character without any special\\n\",\n",
# Line 906:       "Line 146:     \"meaning.\\n\",\n",
# Line 907:       "Line 147:     \"In the following slides we will go through some of the more\\n\",\n",
# Line 908:       "Line 148:     \"common RE notations.\\n\",\n",
# Line 909:       "Line 149:     \"\\n\",\n",
# Line 910:       "Line 150:     \"```\\n\",\n",
# Line 911:       "Line 151:     \". Matches any character\\n\",\n",
# Line 912:       "Line 152:     \"[...] Matches any character contained within the brackets\\n\",\n",
# Line 913:       "Line 153:     \"[^...] Matches any character not appearing after the hat (ˆ)\\n\",\n",
# Line 914:       "Line 154:     \"ˆ Matches the start of the string\\n\",\n",
# Line 915:       "Line 155:     \"$ Matches the end of the string\\n\",\n",
# Line 916:       "Line 156:     \"* Matches zero or more previous RE\\n\",\n",
# Line 917:       "Line 157:     \"+ Matches one or more previous RE\\n\",\n",
# Line 918:       "Line 158:     \"{m,n} Matches m to n occurences of previous RE\\n\",\n",
# Line 919:       "Line 159:     \"? Matches zero or one occurences of previous RE\\n\",\n",
# Line 920:       "Line 160:     \"```\\n\",\n",
# Line 921:       "Line 161:     \"\\n\",\n",
# Line 922:       "Line 162:     \"We have already seen that a `|` character denotes alternatives.\\n\",\n",
# Line 923:       "Line 163:     \"For example, the pattern `r\\\"Get (on|off|ready)\\\"` matches\\n\",\n",
# Line 924:       "Line 164:     \"the following strings: `\\\"Get on\\\"`, `\\\"Get off\\\"`, `\\\"Get ready\\\"`.\\n\",\n",
# Line 925:       "Line 165:     \"We can use parentheses to create groupings inside a pattern:\\n\",\n",
# Line 926:       "Line 166:     \"`r\\\"(ab)+\\\"` will match the strings `\\\"ab\\\"`, `\\\"abab\\\"`, `\\\"ababab\\\"`,\\n\",\n",
# Line 927:       "Line 167:     \"and so on.\\n\",\n",
# Line 928:       "Line 168:     \"These groups are also given a reference number starting from 1. \\n\",\n",
# Line 929:       "Line 169:     \"We can refer to groups using backreferences: `\\\\number`.\\n\",\n",
# Line 930:       "Line 170:     \"For example, we can find separated patterns that get\\n\",\n",
# Line 931:       "Line 171:     \"repeated: `r\\\"([a-z]{3,}) \\\\1 \\\\1\\\"`.\\n\",\n",
# Line 932:       "Line 172:     \"This will recognise, for example, the following strings: `\\\"aca\\n\",\n",
# Line 933:       "Line 173:     \"aca aca\\\"`, `\\\"turn turn turn\\\"`. But not the strings `\\\"aca\\n\",\n",
# Line 934:       "Line 174:     \"aba aca\\\"` or `\\\"ac ac ac\\\"`.\\n\",\n",
# Line 935:       "Line 175:     \"\\n\",\n",
# Line 936:       "Line 176:     \"\\n\",\n",
# Line 937:       "Line 177:     \"In the following, note that a hat (ˆ) as the first character\\n\",\n",
# Line 938:       "Line 178:     \"inside brackets will create a complement set of characters:\\n\",\n",
# Line 939:       "Line 179:     \"\\n\",\n",
# Line 940:       "Line 180:     \"```\\n\",\n",
# Line 941:       "Line 181:     \"`\\\\d` same as `[0-9]`, matches a digit\\n\",\n",
# Line 942:       "Line 182:     \"`\\\\D` same as `[ˆ0-9]`, matches anything but a digit\\n\",\n",
# Line 943:       "Line 183:     \"`\\\\s` matches a whitespace character (space, newline, tab, ... )\\n\",\n",
# Line 944:       "Line 184:     \"`\\\\S` matches a nonwhitespace character\\n\",\n",
# Line 945:       "Line 185:     \"`\\\\w` same as `[a-zA-Z0-9_]`, matches one alphanumeric character\\n\",\n",
# Line 946:       "Line 186:     \"`\\\\W` matches one non-alphanumeric character\\n\",\n",
# Line 947:       "Line 187:     \"```\\n\",\n",
# Line 948:       "Line 188:     \"\\n\",\n",
# Line 949:       "Line 189:     \"Using the above notation we can now shorten our previous\\n\",\n",
# Line 950:       "Line 190:     \"variable name example to `r’[a-zA-Z_]\\\\w*\\\\Z’`\\n\",\n",
# Line 951:       "Line 191:     \"\\n\",\n",
# Line 952:       "Line 192:     \"The patterns `\\\\A`, `\\\\b`, `\\\\B`, and `\\\\Z` will all match an empty\\n\",\n",
# Line 953:       "Line 193:     \"string, but in specific places.\\n\",\n",
# Line 954:       "Line 194:     \"The patterns `\\\\A` and `\\\\Z` will recognise the beginning and end\\n\",\n",
# Line 955:       "Line 195:     \"of the string, respectively.\\n\",\n",
# Line 956:       "Line 196:     \"Note that the patterns `ˆ` and `$` can in some cases match also\\n\",\n",
# Line 957:       "Line 197:     \"after a newline and before a newline, correspondingly.\\n\",\n",
# Line 958:       "Line 198:     \"So, `\\\\A` is distinct from `ˆ`, and `\\\\Z` is distinct from `$`.\\n\",\n",
# Line 959:       "Line 199:     \"The pattern `\\\\b` matches at the start or end of a word. The\\n\",\n",
# Line 960:       "Line 200:     \"pattern `\\\\B` does the reverse.\"\n",
# Line 961:       "Line 201:    ]\n",
# Line 962:       "Line 202:   },\n",
# Line 963:       "Line 203:   {\n",
# Line 964:       "Line 204:    \"cell_type\": \"markdown\",\n",
# Line 965:       "Line 205:    \"metadata\": {\n",
# Line 966:       "Line 206:     \"colab_type\": \"text\",\n",
# Line 967:       "Line 207:     \"id\": \"m2XG2faQ4JJp\"\n",
# Line 968:       "Line 208:    },\n",
# Line 969:       "Line 209:    \"source\": [\n",
# Line 970:       "Line 210:     \"### Match and search functions\\n\",\n",
# Line 971:       "Line 211:     \"\\n\",\n",
# Line 972:       "Line 212:     \"We have so far only used the `re.match` function which tries\\n\",\n",
# Line 973:       "Line 213:     \"to find a match at the beginning of a string\\n\",\n",
# Line 974:       "Line 214:     \"The function `re.search` allows to match any substring of a\\n\",\n",
# Line 975:       "Line 215:     \"string.\\n\",\n",
# Line 976:       "Line 216:     \"Example: `re.search(r'\\\\bback\\\\b', s)` will match\\n\",\n",
# Line 977:       "Line 217:     \"strings `\\\"back\\\"`, `\\\"a back, is a body part\\\"`, `\\\"get back\\\"`. But it\\n\",\n",
# Line 978:       "Line 218:     \"will not match the strings `\\\"backspace\\\"` or `\\\"comeback\\\"`.\\n\",\n",
# Line 979:       "Line 219:     \"\\n\",\n",
# Line 980:       "Line 220:     \"The function `re.search` finds only the first occurence.\\n\",\n",
# Line 981:       "Line 221:     \"We can use the `re.findall` function to find all occurences.\\n\",\n",
# Line 982:       "Line 222:     \"Let’s say we want to find all present participle words in a\\n\",\n",
# Line 983:       "Line 223:     \"string `s`. The present participle words have ending `'ing'`.\\n\",\n",
# Line 984:       "Line 224:     \"The function call would look like this:\\n\",\n",
# Line 985:       "Line 225:     \"`re.findall(r'\\\\w+ing\\\\b', s)`.\\n\",\n",
# Line 986:       "Line 226:     \"Let’s try running this:\"\n",
# Line 987:       "Line 227:    ]\n",
# Line 988:       "Line 228:   },\n",
# Line 989:       "Line 229:   {\n",
# Line 990:       "Line 230:    \"cell_type\": \"code\",\n",
# Line 991:       "Line 231:    \"execution_count\": 2,\n",
# Line 992:       "Line 232:    \"metadata\": {\n",
# Line 993:       "Line 233:     \"colab\": {},\n",
# Line 994:       "Line 234:     \"colab_type\": \"code\",\n",
# Line 995:       "Line 235:     \"id\": \"AIsbkC0I4JJp\",\n",
# Line 996:       "Line 236:     \"outputId\": \"fc7e8c40-d29d-4225-80f3-9fae69b04aa0\"\n",
# Line 997:       "Line 237:    },\n",
# Line 998:       "Line 238:    \"outputs\": [\n",
# Line 999:       "Line 239:     {\n",

# %% [markdown]
# It is easy to forget to close the file. One can use a *context manager* to solve this problem. A context manager is created with the `with` statement. After the indented block of the `with` statement exits, the file will be automatically closed.

# %%
with open("../realworld/csv/04_rw_csv.ipynb", "r") as f:          # the file will be automatically closed,
                                              # when the with block exits
    for i in range(5):
        line = f.readline()
        print(f"Line {i}: {line}", end="")
# Out:
# Line 0: {
# Line 1:  "cells": [
# Line 2:   {
# Line 3:    "cell_type": "markdown",
# Line 4:    "metadata": {},

# %% [markdown]
# The `file` object is iterable. This means that we can iterate through the lines in the file using a for loop, like in the below example:

# %%
max_len = 0

with open("02_regex.ipynb", "r") as f:
    for line in f:    # iterates through all the lines in the file
        if len(line) > max_len:
            max_len = len(line)
print(f"The longest line in this file has length {max_len}")
# Out:
# The longest line in this file has length 19631

# %% [markdown]
# ### Standard file objects
# Python has automatically three file objects open:
#
# * `sys.stdin` for *standard input*
# * `sys.stdout` for *standard output*
# * `sys.stderr` for *standard error*
# To read a line from a user (keyboard), you can call `sys.stdin.readline()`. To write a line to a user (screen), call `sys.stdout.write(line)`. The standard error is meant for error messages only, even though its output often goes to the same destination as standard output.
#
# The print function uses the file `sys.stdout` and input function uses the file `sys.stdin`. An example of usage:

# %%
import sys
import random
i=random.randint(-10,10)
if i >= 0:
    sys.stdout.write("Got a positive integer.\n")
else:
    sys.stderr.write("Got a negative integer.\n")
# Out:
# Got a positive integer.

# %% [markdown]
# These standard file objects are meant to be a basic input/output mechanism in textual form. The destinations of the file objects can be changed to point
# somewhere else than the usual keyboard and screen. Very often these are redirected to some files. For example, it is usual to point the stderr to a file where all
# error messages are logged.

# %% [markdown]
# ## sys module
#
# We saw above that the `sys` module contains the three file objects `sys.stdin`, `sys.stdout`, and `sys.stderr`. It has also few other useful attributes. The attribute `sys.path` is the list of folders that Python uses to look for imported modules. The list `sys.argv` contains the so called *command line parameters*. For example in Linux if you are using the terminal, then you can run your program with the command `python3 programname.py param1 param2 ...`. After Python has started your program, the command line parameters are visible as follows. The name of the program is in `sys.argv[0]`. The rest of the command line parameters are after the program name in this list: `sys.argv[1]=="param1"`, `sys.argv[2]=="param2"`, and so on. The command line parameters can be useful in adjusting the behaviour of your program. A few examples of these will be in the following exercises. (The terminal window is a textual interface to your computer instead of the usual graphical interface.)
#
# The function `sys.exit` can be used to exit immediately your program. The integer parameter given to this function is the return value of the program. Usually the return value 0 means that the program ran successfully, and non-zero integer means that an error occurred. This return value is accessible from the terminal window from where you started the program.

# %% [markdown]
# #### <div class="alert alert-info">Group Exercise 2 (file listing)</div>
#
# The file `files/listing.txt` contains a list of files with one line per file. Each line contains seven fields: access rights, number of references, owner's name, name of owning group, file size, date, filename. These fields are separated with one or more spaces. Note that there may be spaces also within these seven fields.
#
# Write function `file_listing` that loads the file `files/listing.txt`. It should return a list of tuples (size, month, day, hour, minute, filename). Use regular expressions to do this (either `match`, `search`, `findall`, or `finditer` method).
#
# An example: for line
# ```
# -rw-r--r-- 1 jttoivon hyad-all   25399 Nov  2 21:25 exception_hierarchy.pdf
# ```
# the function should create the tuple `(25399, "Nov", 2, 21, 25, "exception_hierarchy.pdf")`.
# <hr/>

# %%
import sys
import os
os.listdir(path='.')
# Out:
# ['.DS_Store',
#  '02_regex.ipynb',
#  '__pycache__',
#  'supplemental',
#  '04_closures_generators.ipynb',
#  'README.md',
#  '05_gen_regex_exercises.ipynb',
#  '01_generators.ipynb',
#  'files',
#  '.ipynb_checkpoints',
#  '03_str_manipulate.ipynb']

# %%
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles

# %%
dirName = '.';
 
# Get the list of all files in directory tree at given path
listOfFiles = getListOfFiles(dirName)
print(listOfFiles)
# Out:
# ['./.DS_Store', './02_regex.ipynb', './__pycache__/file1.cpython-37.pyc', './supplemental/README.md', './04_closures_generators.ipynb', './README.md', './05_gen_regex_exercises.ipynb', './01_generators.ipynb', './files/.DS_Store', './files/listing.txt', './files/alice.txt', './files/rgb.txt', './files/table.png', './.ipynb_checkpoints/05_gen_regex_exercises-checkpoint.ipynb', './.ipynb_checkpoints/03_str_manipulate-checkpoint.ipynb', './.ipynb_checkpoints/01_generators-checkpoint.ipynb', './.ipynb_checkpoints/04_closures_generators-checkpoint.ipynb', './.ipynb_checkpoints/02_regex-checkpoint.ipynb', './03_str_manipulate.ipynb']

# %% [markdown]
# #### <div class="alert alert-info">Group Exercise 3 (red green blue)</div>
#
# The file `files/rgb.txt` contains names of colors and their numerical representations in RGB format. The RBG format allows a color to be represented as a mixture of red, green, and blue components. Each component can have an integer value in the range [0,255]. Each line in the file contains four fields: red, green, blue, and colorname.
# Each field is separated by some amount of whitespace (tab or space in this case).
# The text file is formatted to make it print nicely, but that makes it harder to process by a computer. Note that some color names can also contain a space character.
#
# Write function `red_green_blue` that reads the file `rgb.txt` from the folder `files`.  Remove the irrelevant first line of the file. The function should return a list of strings. Clean-up the file so that the strings in the returned list have four fields separated by a single tab character (`\t`). Use regular expressions to do this.
#
# The first string in the returned list should be:
# ```
# '255\t250\t250\tsnow'
# ```
#
# <hr/>

# %% [raw]
# # red	#FF0000	rgb(255,0,0)
# # blue  #0000FF	rgb(0, 0, 255)
# # green #008000	rgb(0, 128, 0)

# %%
with open("files/rgb.txt", "r") as f:
# for line in f:
#     f.read().split()
#     print(f)
# with open("files/rgb.txt", "r") as fin:
     # data = fin.read().splitlines(True)
# with open("files/rgb.txt", "w") as fout:
      # fout.writelines(data[1:1])
      #print(data)
      for line in f:
          line = f.readline()
          print(line)
      # print(f.read())
f.close()
# Out:
# 255 250 250		snow
#
# 248 248 255		GhostWhite
#
# 245 245 245		WhiteSmoke
#
# 255 250 240		floral white
#
# 253 245 230		old lace
#
# 250 240 230		linen
#
# 250 235 215		AntiqueWhite
#
# 255 239 213		PapayaWhip
#
# 255 235 205		BlanchedAlmond
#
# 255 218 185		peach puff
#
# 255 222 173		navajo white
#
# 255 228 181		moccasin
#
# 255 255 240		ivory
#
# 255 250 205		LemonChiffon
#
# 240 255 240		honeydew
#
# 245 255 250		MintCream
#
# 240 248 255		alice blue
#
# 230 230 250		lavender
#
# 255 240 245		LavenderBlush
#
# 255 228 225		MistyRose
#
#   0   0   0		black
#
#  47  79  79		DarkSlateGray
#
#  47  79  79		DarkSlateGrey
#
# 105 105 105		DimGray
#
# 105 105 105		DimGrey
#
# 112 128 144		SlateGray
#
# 112 128 144		SlateGrey
#
# 119 136 153		LightSlateGray
#
# 119 136 153		LightSlateGrey
#
# 190 190 190		grey
#
# 211 211 211		LightGrey
#
# 211 211 211		LightGray
#
#  25  25 112		MidnightBlue
#
#   0   0 128		navy blue
#
# 100 149 237		cornflower blue
#
#  72  61 139		dark slate blue
#
# 106  90 205		slate blue
#
# 123 104 238		medium slate blue
#
# 132 112 255		light slate blue
#
#   0   0 205		medium blue
#
#  65 105 225		royal blue
#
#   0   0 255		blue
#
#  30 144 255		DodgerBlue
#
#   0 191 255		DeepSkyBlue
#
# 135 206 235		SkyBlue
#
# 135 206 250		LightSkyBlue
#
#  70 130 180		SteelBlue
#
# 176 196 222		LightSteelBlue
#
# 173 216 230		LightBlue
#
# 176 224 230		PowderBlue
#
# 175 238 238		PaleTurquoise
#
#   0 206 209		DarkTurquoise
#
#  72 209 204		MediumTurquoise
#
#   0 255 255		cyan
#
# 224 255 255		LightCyan
#
#  95 158 160		CadetBlue
#
# 102 205 170		MediumAquamarine
#
#   0 100   0		dark green
#
#  85 107  47		dark olive green
#
# 143 188 143		dark sea green
#
#  46 139  87		sea green
#
#  60 179 113		medium sea green
#
#  32 178 170		light sea green
#
# 152 251 152		pale green
#
#   0 255 127		spring green
#
# 124 252   0		lawn green
#
#   0 255   0		green
#
#   0 250 154		medium spring green
#
# 173 255  47		green yellow
#
#  50 205  50		lime green
#
# 154 205  50		yellow green
#
#  34 139  34		forest green
#
# 107 142  35		olive drab
#
# 189 183 107		dark khaki
#
# 240 230 140		khaki
#
# 238 232 170		PaleGoldenrod
#
# 250 250 210		LightGoldenrodYellow
#
# 255 255 224		LightYellow
#
# 255 215   0 		gold
#
# 238 221 130		LightGoldenrod
#
# 184 134  11		dark goldenrod
#
# 188 143 143		rosy brown
#
# 205  92  92		indian red
#
# 139  69  19		saddle brown
#
# 160  82  45		sienna
#
# 222 184 135		burlywood
#
# 245 222 179		wheat
#
# 244 164  96		SandyBrown
#
# 210 105  30		chocolate
#
# 165  42  42		brown
#
# 233 150 122		DarkSalmon
#
# 255 160 122		light salmon
#
# 255 165   0		orange
#
# 255 140   0		DarkOrange
#
# 240 128 128		light coral
#
# 255  99  71		tomato
#
# 255  69   0		OrangeRed
#
# 255 105 180		hot pink
#
# 255  20 147		deep pink
#
# 255 192 203		pink
#
# 255 182 193		LightPink
#
# 219 112 147		PaleVioletRed
#
# 199  21 133		medium violet red
#
# 208  32 144		violet red
#
# 255   0 255		magenta
#
# 221 160 221		plum
#
# 186  85 211		medium orchid
#
# 153  50 204		dark orchid
#
# 148   0 211		dark violet
#
# 138  43 226		blue violet
#
# 160  32 240		purple
#
# 147 112 219		MediumPurple
#
# 255 250 250		snow1
#
# 205 201 201		snow3
#
# 255 245 238		seashell1
#
# 205 197 191		seashell3
#
# 255 239 219		AntiqueWhite1
#
# 205 192 176		AntiqueWhite3
#
# 255 228 196		bisque1
#
# 205 183 158		bisque3
#
# 255 218 185		PeachPuff1
#
# 205 175 149		PeachPuff3
#
# 255 222 173		NavajoWhite1
#
# 205 179 139		NavajoWhite3
#
# 255 250 205		LemonChiffon1
#
# 205 201 165		LemonChiffon3
#
# 255 248 220		cornsilk1
#
# 205 200 177		cornsilk3
#
# 255 255 240		ivory1
#
# 205 205 193		ivory3
#
# 240 255 240		honeydew1
#
# 193 205 193		honeydew3
#
# 255 240 245		LavenderBlush1
#
# 205 193 197		LavenderBlush3
#
# 255 228 225		MistyRose1
#
# 205 183 181		MistyRose3
#
# 240 255 255		azure1
#
# 193 205 205		azure3
#
# 131 111 255		SlateBlue1
#
# 105  89 205		SlateBlue3
#
#  72 118 255		RoyalBlue1
#
#  58  95 205		RoyalBlue3
#
#   0   0 255		blue1
#
#   0   0 205		blue3
#
#  30 144 255		DodgerBlue1
#
#  24 116 205		DodgerBlue3
#
#  99 184 255		SteelBlue1
#
#  79 148 205		SteelBlue3
#
#   0 191 255		DeepSkyBlue1
#
#   0 154 205		DeepSkyBlue3
#
# 135 206 255		SkyBlue1
#
# 108 166 205		SkyBlue3
#
# 176 226 255		LightSkyBlue1
#
# 141 182 205		LightSkyBlue3
#
# 198 226 255		SlateGray1
#
# 159 182 205		SlateGray3
#
# 202 225 255		LightSteelBlue1
#
# 162 181 205		LightSteelBlue3
#
# 191 239 255		LightBlue1
#
# 154 192 205		LightBlue3
#
# 224 255 255		LightCyan1
#
# 180 205 205		LightCyan3
#
# 187 255 255		PaleTurquoise1
#
# 150 205 205		PaleTurquoise3
#
# 152 245 255		CadetBlue1
#
# 122 197 205		CadetBlue3
#
#   0 245 255		turquoise1
#
#   0 197 205		turquoise3
#
#   0 255 255		cyan1
#
#   0 205 205		cyan3
#
# 151 255 255		DarkSlateGray1
#
# 121 205 205		DarkSlateGray3
#
# 127 255 212		aquamarine1
#
# 102 205 170		aquamarine3
#
# 193 255 193		DarkSeaGreen1
#
# 155 205 155		DarkSeaGreen3
#
#  84 255 159		SeaGreen1
#
#  67 205 128		SeaGreen3
#
# 154 255 154		PaleGreen1
#
# 124 205 124		PaleGreen3
#
#   0 255 127		SpringGreen1
#
#   0 205 102		SpringGreen3
#
#   0 255	  0		green1
#
#   0 205	  0		green3
#
# 127 255	  0		chartreuse1
#
# 102 205	  0		chartreuse3
#
# 192 255	 62		OliveDrab1
#
# 154 205	 50		OliveDrab3
#
# 202 255 112		DarkOliveGreen1
#
# 162 205	 90		DarkOliveGreen3
#
# 255 246 143		khaki1
#
# 205 198 115		khaki3
#
# 255 236 139		LightGoldenrod1
#
# 205 190 112		LightGoldenrod3
#
# 255 255 224		LightYellow1
#
# 205 205 180		LightYellow3
#
# 255 255	  0		yellow1
#
# 205 205	  0		yellow3
#
# 255 215	  0		gold1
#
# 205 173	  0		gold3
#
# 255 193	 37		goldenrod1
#
# 205 155	 29		goldenrod3
#
# 255 185	 15		DarkGoldenrod1
#
# 205 149	 12		DarkGoldenrod3
#
# 255 193 193		RosyBrown1
#
# 205 155 155		RosyBrown3
#
# 255 106 106		IndianRed1
#
# 205  85	 85		IndianRed3
#
# 255 130	 71		sienna1
#
# 205 104	 57		sienna3
#
# 255 211 155		burlywood1
#
# 205 170 125		burlywood3
#
# 255 231 186		wheat1
#
# 205 186 150		wheat3
#
# 255 165	 79		tan1
#
# 205 133	 63		tan3
#
# 255 127	 36		chocolate1
#
# 205 102	 29		chocolate3
#
# 255  48	 48		firebrick1
#
# 205  38	 38		firebrick3
#
# 255  64	 64		brown1
#
# 205  51	 51		brown3
#
# 255 140 105		salmon1
#
# 205 112	 84		salmon3
#
# 255 160 122		LightSalmon1
#
# 205 129	 98		LightSalmon3
#
# 255 165	  0		orange1
#
# 205 133	  0		orange3
#
# 255 127	  0		DarkOrange1
#
# 205 102	  0		DarkOrange3
#
# 255 114	 86		coral1
#
# 205  91	 69		coral3
#
# 255  99	 71		tomato1
#
# 205  79	 57		tomato3
#
# 255  69	  0		OrangeRed1
#
# 205  55	  0		OrangeRed3
#
# 255   0	  0		red1
#
# 205   0	  0		red3
#
# 255  20 147		DeepPink1
#
# 205  16 118		DeepPink3
#
# 255 110 180		HotPink1
#
# 205  96 144		HotPink3
#
# 255 181 197		pink1
#
# 205 145 158		pink3
#
# 255 174 185		LightPink1
#
# 205 140 149		LightPink3
#
# 255 130 171		PaleVioletRed1
#
# 205 104 137		PaleVioletRed3
#
# 255  52 179		maroon1
#
# 205  41 144		maroon3
#
# 255  62 150		VioletRed1
#
# 205  50 120		VioletRed3
#
# 255   0 255		magenta1
#
# 205   0 205		magenta3
#
# 255 131 250		orchid1
#
# 205 105 201		orchid3
#
# 255 187 255		plum1
#
# 205 150 205		plum3
#
# 224 102 255		MediumOrchid1
#
# 180  82 205		MediumOrchid3
#
# 191  62 255		DarkOrchid1
#
# 154  50 205		DarkOrchid3
#
# 155  48 255		purple1
#
# 125  38 205		purple3
#
# 171 130 255		MediumPurple1
#
# 137 104 205		MediumPurple3
#
# 255 225 255		thistle1
#
# 205 181 205		thistle3
#
#   0   0   0		gray0
#
#   3   3   3		gray1
#
#   5   5   5		gray2
#
#   8   8   8		gray3
#
#  10  10  10 		gray4
#
#  13  13  13 		gray5
#
#  15  15  15 		gray6
#
#  18  18  18 		gray7
#
#  20  20  20 		gray8
#
#  23  23  23 		gray9
#
#  26  26  26 		gray10
#
#  28  28  28 		gray11
#
#  31  31  31 		gray12
#
#  33  33  33 		gray13
#
#  36  36  36 		gray14
#
#  38  38  38 		gray15
#
#  41  41  41 		gray16
#
#  43  43  43 		gray17
#
#  46  46  46 		gray18
#
#  48  48  48 		gray19
#
#  51  51  51 		gray20
#
#  54  54  54 		gray21
#
#  56  56  56 		gray22
#
#  59  59  59 		gray23
#
#  61  61  61 		gray24
#
#  64  64  64 		gray25
#
#  66  66  66 		gray26
#
#  69  69  69 		gray27
#
#  71  71  71 		gray28
#
#  74  74  74 		gray29
#
#  77  77  77 		gray30
#
#  79  79  79 		gray31
#
#  82  82  82 		gray32
#
#  84  84  84 		gray33
#
#  87  87  87 		gray34
#
#  89  89  89 		gray35
#
#  92  92  92 		gray36
#
#  94  94  94 		gray37
#
#  97  97  97 		gray38
#
#  99  99  99 		gray39
#
# 102 102 102 		gray40
#
# 105 105 105 		gray41
#
# 107 107 107 		gray42
#
# 110 110 110 		gray43
#
# 112 112 112 		gray44
#
# 115 115 115 		gray45
#
# 117 117 117 		gray46
#
# 120 120 120 		gray47
#
# 122 122 122 		gray48
#
# 125 125 125 		gray49
#
# 127 127 127 		gray50
#
# 130 130 130 		gray51
#
# 133 133 133 		gray52
#
# 135 135 135 		gray53
#
# 138 138 138 		gray54
#
# 140 140 140 		gray55
#
# 143 143 143 		gray56
#
# 145 145 145 		gray57
#
# 148 148 148 		gray58
#
# 150 150 150 		gray59
#
# 153 153 153 		gray60
#
# 156 156 156 		gray61
#
# 158 158 158 		gray62
#
# 161 161 161 		gray63
#
# 163 163 163 		gray64
#
# 166 166 166 		gray65
#
# 168 168 168 		gray66
#
# 171 171 171 		gray67
#
# 173 173 173 		gray68
#
# 176 176 176 		gray69
#
# 179 179 179 		gray70
#
# 181 181 181 		gray71
#
# 184 184 184 		gray72
#
# 186 186 186 		gray73
#
# 189 189 189 		gray74
#
# 191 191 191 		gray75
#
# 194 194 194 		gray76
#
# 196 196 196 		gray77
#
# 199 199 199 		gray78
#
# 201 201 201 		gray79
#
# 204 204 204 		gray80
#
# 207 207 207 		gray81
#
# 209 209 209 		gray82
#
# 212 212 212 		gray83
#
# 214 214 214 		gray84
#
# 217 217 217 		gray85
#
# 219 219 219 		gray86
#
# 222 222 222 		gray87
#
# 224 224 224 		gray88
#
# 227 227 227 		gray89
#
# 229 229 229 		gray90
#
# 232 232 232 		gray91
#
# 235 235 235 		gray92
#
# 237 237 237 		gray93
#
# 240 240 240 		gray94
#
# 242 242 242 		gray95
#
# 245 245 245 		gray96
#
# 247 247 247 		gray97
#
# 250 250 250 		gray98
#
# 252 252 252 		gray99
#
# 255 255 255 		gray100
#
# 169 169 169		dark grey
#
# 169 169 169		dark gray
#
# 0     0 139		dark blue
#
# 0   139 139		dark cyan
#
# 139   0 139		dark magenta
#
# 139   0   0		dark red
#
# 144 238 144		light green

# %% [markdown]
# #### <div class="alert alert-info">Group Exercise 4 (word frequencies)</div>
#
# Create function `word_frequencies` that gets a filename as a parameter and returns a dict with the word frequencies. In the dictionary the keys are the words and the corresponding values are the number of times that word occurred in the file specified by the function parameter. Read all the lines from the file and split the lines into words using the `split()` method. Further, remove punctuation from the ends of words using the `strip("""!"#$%&'()*,-./:;?@[]_""")` method call.
#
# Test this function in the main function using the file `alice.txt`. In the output, there should be a word and its count per line separated by a tab:
#
# ```
# The     64
# Project 83
# Gutenberg	26
# EBook   3
# of      303
# ```
#
# <hr/>

# %%
from collections import Counter
def word_count(fname):
        with open(fname) as f:
                return Counter(f.read().split())

print("Number of words in the file :",word_count("files/alice.txt"))
# Out:
# Number of words in the file : Counter({'the': 175, 'of': 120, 'and': 101, 'to': 78, 'The': 68, 'a': 68, 'in': 58, 'are': 51, 'is': 34, 'or': 29, 'on': 24, 'with': 20, 'by': 19, 'for': 18, 'you': 17, 'have': 16, 'be': 15, 'We': 15, 'from': 13, 'as': 12, 'northern': 12, 'north': 11, 'that': 10, 'it': 10, 'day': 10, 'may': 10, 'A': 9, 'many': 9, 'our': 9, 'life': 8, 'more': 8, 'at': 8, 'an': 8, 'In': 8, 'They': 8, 'not': 7, 'their': 7, 'they': 7, 'up': 7, 'aircraft': 7, 'must': 7, 'were': 7, 'most': 6, 'lake': 6, 'large': 6, 'if': 6, 'ice': 6, 'can': 6, 'all': 6, 'miles': 6, 'fishing': 6, 'your': 6, 'we': 6, 'If': 5, 'down': 5, 'than': 5, 'his': 5, 'southern': 5, 'do': 5, 'some': 5, 'fish': 5, 'when': 5, 'day.': 5, 'winter': 5, 'For': 5, 'new': 5, 'TV': 5, 'road': 4, 'north.': 4, 'away': 4, 'There': 4, 'so': 4, 'live': 4, 'services': 4, 'food': 4, 'local': 4, 'Most': 4, 'these': 4, 'but': 4, 'available': 4, 'small': 4, '40': 4, 'them': 4, 'life.': 4, 'few': 4, 'has': 4, 'roads': 4, 'left': 4, 'hunting': 4, 'move': 4, 'home': 4, 'To': 4, 'fresh': 4, 'was': 4, 'had': 4, 'only': 3, 'side': 3, 'any': 3, 'been': 3, 'bush': 3, 'dog': 3, 'breaking': 3, 'trout,': 3, 'never': 3, 'one': 3, 'trip': 3, 'lakes': 3, 'year': 3, 'cabin': 3, 'those': 3, 'during': 3, 'city': 3, 'which': 3, 'no': 3, 'car': 3, 'start': 3, 'conditions': 3, 'Many': 3, 'transport': 3, 'pilots': 3, 'summer': 3, 'fly': 3, 'aircraft.': 3, 'too': 3, 'thick': 3, 'change': 3, 'equipment.': 3, 'flying': 3, 'hear': 3, 'pilot': 3, 'engines': 3, 'problem': 3, 'oil': 3, 'regular': 3, 'into': 3, 'ice.': 3, 'arctic': 3, 'each': 3, 'flight': 3, 'south.': 3, 'usually': 3, 'Some': 3, 'will': 3, 'vehicles': 3, 'hours': 3, 'get': 3, 'take': 3, 'boats': 3, 'favorite': 3, 'use': 3, 'As': 3, 'another': 3, 'moose': 3, 'Other': 3, 'made': 3, 'hundreds': 3, 'carry': 3, 'travel': 3, 'same': 3, 'own': 3, 'remote': 3, 'On': 3, 'You': 3, 'per': 3, '2': 3, '10': 3, 'miss': 3, '100': 2, '53': 2, 'Jim': 2, 'degrees.': 2, "It's": 2, 'travellers': 2, 'rigors': 2, 'tales': 2, 'man': 2, 'flies,': 2, 'carried': 2, 'record': 2, 'through': 2, 'ducks': 2, 'feeding': 2, 'quiet': 2, 'Once': 2, 'loon': 2, 'voice': 2, 'wildlife': 2, 'land': 2, 'special': 2, 'person': 2, 'farther': 2, 'this': 2, 'becomes': 2, 'whether': 2, 'first': 2, 'owners': 2, 'basis.': 2, 'center': 2, 'equipped': 2, 'paved': 2, 'natural': 2, 'gas': 2, 'provide': 2, 'food,': 2, 'repairs,': 2, 'family': 2, 'seasons.': 2, 'five': 2, 'well': 2, 'streets': 2, 'These': 2, 'communities,': 2, 'urban': 2, 'areas': 2, 'nearby': 2, 'bus': 2, 'taxi': 2, 'service': 2, 'Even': 2, "it's": 2, 'back': 2, 'pick': 2, 'delivery': 2, 'winter.': 2, 'requires': 2, 'especially': 2, 'rail': 2, 'all.': 2, 'because': 2, 'natives': 2, 'ground.': 2, 'fishermen,': 2, 'fish,': 2, 'logging': 2, 'settlements.': 2, 'skis': 2, 'problems': 2, 'below': 2, 'zero,': 2, 'All': 2, 'propeller': 2, 'tied': 2, 'holes': 2, 'four': 2, 'onto': 2, 'passengers': 2, 'heavy': 2, 'cold.': 2, 'ensure': 2, 'next': 2, 'covered': 2, 'snow': 2, 'engine': 2, '50': 2, 'degrees': 2, 'This': 2, 'after': 2, 'lack': 2, 'communities': 2, 'pay': 2, 'people': 2, 'landing': 2, 'out': 2, 'winter,': 2, 'major': 2, 'enjoy': 2, 'motors': 2, 'stored': 2, 'bait': 2, 'Moose': 2, 'require': 2, 'kept': 2, 'hunting.': 2, 'home.': 2, 'spring': 2, 'equipment': 2, 'return': 2, 'begin': 2, 'fishing,': 2, 'fire': 2, 'At': 2, 'lakes.': 2, 'MEDEVAC': 2, 'types.': 2, 'arrive': 2, 'private': 2, 'lakes,': 2, 'great': 2, 'short': 2, 'contact': 2, 'airport': 2, 'there': 2, 'rather': 2, 'course': 2, 'present': 2, 'civilization.': 2, 'around': 2, 'surrounded': 2, 'songs': 2, 'bird': 2, 'cry': 2, 'evening': 2, 'wail': 2, 'passing': 2, 'he': 2, 'taste': 2, 'wild': 2, 'blueberries.': 2, 'Is': 2, 'high': 2, 'shore.': 2, 'like': 2, 'But': 2, 'neighbors': 2, 'also': 2, 'then': 2, 'trip.': 2, 'order': 2, 'appliances,': 2, 'mail': 2, 'radio': 2, 'prices': 2, 'cost': 2, 'higher': 2, 'years': 2, 'then,': 2, 'prices.': 2, 'ancestry.': 2, 'o ...

# %% [markdown]
# #### <div class="alert alert-info">Group Exercise 5 (file count)</div>
#
# This exercise can give two points at maximum!
#
# Part 1.
#
# Create a function `file_count` that gets a filename as parameter and returns a triple of numbers. The function should read the file, count the number of lines, words, and characters in the file, and return a triple with these count in this order. You get division into words by splitting at whitespace. You don't have to remove punctuation.
#
# Part 2.
#
# Create a main function that in a loop calls `file_count` using each filename in the list of command line parameters `sys.argv[1:]` as a parameter, in turn.
# For call `python3 src/file_count file1 file2 ...`
# the output should be
# ```
# ?      ?       ?       file1
# ?      ?       ?       file2
# ...
# ```
# The fields are separated by tabs (`\t`). The fields are in order: linecount, wordcount, charactercount, filename.
# <hr/>

# %%
import os

def count_files(in_directory):
    joiner= (in_directory + os.path.sep).__add__
    return sum(
        os.path.isfile(filename)
        for filename
        in map(joiner, os.listdir(in_directory))
    )

# %%
count_files("/usr/lib")
# Out:
# 293

# %% [markdown]
# #### <div class="alert alert-info">Group Exercise 6 (file extensions)</div>
#
# This exercise can give two points at maximum!
#
# Part 1.
#
# Write function `file_extensions` that gets as a parameter a filename.
# It should read through the lines from this file. Each line contains a filename.
# Find the extension for each filename. The function should return a pair, where the
# first element is a list containing all filenames with no extension (with the preceding period (`.`) removed).
# The second element of the pair is a dictionary with extensions as keys and corresponding values are lists with filenames having that extension.
#
# Sounds a bit complicated, but hopefully the next example will clarify this.
# If the file contains the following lines
# ```
# file1.txt
# mydocument.pdf
# file2.txt
# archive.tar.gz
# test
# ```
# then the return value should be the pair:
# `(["test"], { "txt" : ["file1.txt", "file2.txt"], "pdf" : ["mydocument.pdf"], "gz" : ["archive.tar.gz"] } )`
#
# Part 2.
#
# Write a `main` method that calls the `file_extensions` function with "src/filenames.txt" as the argument. Then print the results so that for each extension there is a line consisting of the extension and the number of files with that extension. The first line of the output should give the number of files without extensions.
#
# With the example in part 1, the output should be
# ```
# 1 files with no extension
# gz 1
# pdf 1
# txt 2
# ```
# Had there been no filenames without extension then the first line would have been `0 files with no extension`. In the printout list the extensions in alphabetical order.
# <hr/>

# %%
import os

# unpacking the tuple
file_name, file_extension = os.path.splitext("files/rgb.txt")

print(file_name)
print(file_extension)
# Out:
# files/rgb
# .txt

# %% [markdown]
# <!--NAVIGATION-->
# Module 6. | [Generators](./01_generators.ipynb) | **[Regular Expressions](./02_regex.ipynb)** | [String Manipulation & Regular Expressions](03_str_manipulate.ipynb) | [Closures & Generators](./04_closures_generators.ipynb) | [Exercises](./05_gen_regex_exercises.ipynb)
# <br>
# [Top](#)

# %% [markdown]
# - - -
#
# Copyright © 2020 Qualex Consulting Services Incorporated.
