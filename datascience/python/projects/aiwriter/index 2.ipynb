# %% [markdown]
# Data Science Fundamentals: Python |
# [Table of Contents](../../index.ipynb)
# - - -
# <!--NAVIGATION-->
# [Real World](../../realworld/index.ipynb) - Projects: [Iris Dataset](../iris/index.ipynb) | [Music Reviews](../music_reviews/index.ipynb) | **[AI-Writer](../aiwriter/index.ipynb)**

# %% [markdown]
# ## Real World: AI-Writer

# %%
import requests
import json
import time

# HTML by http://hilite.me/ , thanks!

# the config
SERVER = "https://panel.ai-writer.com/"
API_KEY = "079E1CD3108C0EED0F4FE34FBC5D8C9D"

RESEARCH_QUERY = "Top 10 Esports Twitch Streamers"

# helper functions
def pretty_print(headline, json_obj):
    print("-----------------", headline, "-----------------")
    print(json.dumps(json_obj, sort_keys=True, indent=4, separators=(',', ': ')))


# first, we create a new research request for the keyword "marketing"
research_request_obj = requests.post(SERVER + '/aiw/apiendpoint2/put_research_request/'+requests.utils.quote(RESEARCH_QUERY), params={"api_key":API_KEY, "identifier": "test_identifier"}).json()

# show output
pretty_print("NEW REQUEST", research_request_obj)

# list the last 10 requests
research_list_obj = requests.get(SERVER + '/aiw/apiendpoint2/list_research_requests/0/10', params={"api_key":API_KEY}).json()

# show list
pretty_print("CURRENT RESEARCH", research_list_obj)


# now get the research result, we will wait for a while and keep asking the server about it
for _ in range(30):

    # request the result of the query
    research_result = requests.get(SERVER + '/aiw/apiendpoint2/get_research_result/'+research_request_obj["id"], params={"api_key":API_KEY}).json()

    # if the result is here, we will break the waiting loop
    if "result" in research_result and research_result["result"] is not None:
        break

    # the sleep makes sure we do not bomb the API endpoints
    time.sleep(30)


# go through all rewritten paragraphs and print them
for paragraph in research_result["result"]["article"]:
    print(paragraph["paragraph_text"])

# print all cited sources
for src_url in research_result["result"]["cited_sources"]:
    print("Source:", src_url)
# Out:
# ----------------- NEW REQUEST -----------------
# {
#     "beeing_processed": false,
#     "done": false,
#     "error_occurred": false,
#     "estimated_time_needed": 155.8184245654515,
#     "id": "5f77df633e071ce06a702f7e",
#     "identifier": "test_identifier",
#     "processing_end_time": 0,
#     "processing_start_time": 0,
#     "query": "Top 10 Esports Twitch Streamers",
#     "source_freshness": "any"
# }
# ----------------- CURRENT RESEARCH -----------------
# [
#     {
#         "beeing_processed": false,
#         "done": true,
#         "error_occurred": false,
#         "estimated_time_needed": 139.86041576521737,
#         "id": "5f721e6695237859b35ea871",
#         "identifier": "test_identifier",
#         "processing_end_time": 1601314546.5898209,
#         "processing_start_time": 1601314410.7470834,
#         "query": "content marketing",
#         "source_freshness": "any"
#     },
#     {
#         "beeing_processed": false,
#         "done": false,
#         "error_occurred": false,
#         "estimated_time_needed": 155.8184245654515,
#         "id": "5f77df633e071ce06a702f7e",
#         "identifier": "test_identifier",
#         "processing_end_time": 0,
#         "processing_start_time": 0,
#         "query": "Top 10 Esports Twitch Streamers",
#         "source_freshness": "any"
#     }
# ]
# This Twitch Streamer is also one of the top Twitch streamers and has the fastest growing Twitch channel in Twitch history. He is known to spend over 70 hours live on Twitch each week, and he also has the fourth highest number of followers on the most-watched Fortnite channel. With the fourth highest follower count, Tfue has more followers than the second - and most - watched Twitch channel of all time.
# According to Twitch, in 2020, there will be over 100 events per day with over 1,000 players from over 50 countries and more than 1.5 million viewers. Twitch Rivals is one of the most popular esports events on Twitch and the second largest esports event in the world after Dota 2.
# This will be the second time chess is introduced in Twitch Rivals, where the best chess variants come together on Twitch to compete in a higher difficulty. A pandemic that is forcing more users online has boosted Twitch as a factor in that growth. After Microsoft's decision to close the Microsoft Mixer, Unikrn has developed its own version of the popular online game platform TwitchMixer.
# Viewing growth was 101 per cent in April compared to the previous year, 60 per cent in March and the second highest in May and June.
# With over 3 billion hours in the first quarter of 2020 and an increase in that number per second, Amazon's video game platform Twitch is the official leader in viewing the most popular video games on the world's largest video game streaming platform. The list of most-watched Twitch streamers is ranked by the number of streams per hour, according to Twitch's annual report of December 1, 2017.
# This popularity can lead to a variety of opportunities for a streamer in the world of video game streaming, and there is a lot of money that can be made with the service itself. Although there are many other benefits to earning a following on Twitch, the rewards for streamers often exceed the potential revenue they could earn as a sports professional.
# While cracking the top 5 streamer list on Twitch can be seen as reaching the zenith of success, this elite group is in a constant state of flux. LIRIK, asmongold and xqcow made it into Twitch's top five for the first time in 2019, but that changed dramatically in April, May and June. TFue, Shoud and Ninja all briefly hopped around the list before each making it back into the top 10.
# The top five streamers on Twitch may change every quarter, but the only thing that has been consistent over the past two months is that the majority use StreamElements for their production, monetization and engagement. Pokimane, one of the world's leading gaming sites, has a growing following of 5.6 million fans on Twitch. It is one of Twitch's most popular streamers and can earn a lot of money at the end of each month.
# He plays Fortnite and League of Legends, but he also streams food and entertainment of all kinds on his Twitch channel and YouTube channel.
# He made it to the big time on Twitch and represents one of the most popular Twitch channels in the esports world with more than 1.5 million monthly active users.
# DrLupo is a player who streams videos from Fortnite and Call of Duty, and he has one of the fastest growing channels on Twitch with more than 1.5 million monthly active users. The Twitch streamer has several brand partnerships on his profile page. It has the second fastest-growing FortNite channel in the world and the third most popular Twitch channel of all time with over 2.2 million subscribers and its own YouTube channel with nearly 1 million viewers.
# He is an active Twitch streamer who spends 65 to 70 hours live every week and does not discuss games, predictions, news or problems.
# The Twitch Streamer is the most popular Fortnite in-game video and posts a variety of games and other videos. He has a classy chair on his Profile U, a service that helps players improve their game on the Twitch profile. The Twitch channel, which is the most viewed on Twitch, has over 2.5 million subscribers and more than 1.2 million views per day.
# He is an active Twitch streamer who spends over 60 hours live on Twitch every week and is now one of the most popular Twitch streamers in the world of sports. His Twitch profile also features a variety of videos of him in the game and on his Twitch channel. While more popular on Fortnite, he also streams other games such as League of Legends, Dota 2 and Counter - Strike: Global Offensive. He also works with many other top players, especially the top players in Dota2 and Overwatch.
# His estimated income is around $5.4 million a year, making him one of the most popular Twitch streamers in the world of esports. Shroud is a Polish Candian Streamer who was one of the leading content developers on Twitch until he left Microsoft Mixer and left the Twitch platform.
# Source: https://www.esportznetwork.com/top-10-most-watched-twitch-streamers-in-2020/
# Source: https://blog.streamelements.com/state-of-the-stream-q2-2019-facebook-gaming-growth-gta-v-surges-and-twitch-influencers-get-more-529ee67f1b7e
# Source: https://www.esportsbets.com/news/highest-paid-twitch-streamers/
# Source: https://shanebarker.com/blog/twitch-streamers/
# Source: https://www.thelivemirror.com/richest-twitch-streamers-2020/
# Source: https://twitchfollowers.com/top-20-twitch-streamers/
# Source: https://www.chess.com/news/view/july-10-twitch-rivals-chess-showdown
