# %% [markdown]
# Data Science Fundamentals: Python |
# [Table of Contents](../../../index.ipynb)
# - - -
# <!--NAVIGATION-->
# Real World Examples: [Web Scraping](../../web_scraping/01_rw_web_scraping.ipynb) | [Automation](../../automation/02_rw_automation.ipynb) | [Messaging](../../messaging/03_rw_messaging.ipynb) | [CSV](../../csv/04_rw_csv.ipynb) | [Games](../../games/05_games.ipynb) | [Mobile](../../mobile/06_mobile.ipynb) | [Computer Vision](../../computer_vision/08_computer_vision.ipynb) | [Chatbot](../../chatbot/10_chatbot.ipynb) | [Built-In Database](../../database/11_database.ipynb)
# - - -
# Life Examples: [COVID-19](../../COVID-19/COVID-19_visualizations-plotly.ipynb) | [Police Brutality](https://maminian.github.io/brutality-map/) | **[Spanish Flu](../spanishflu/index.ipynb)**

# %% [markdown]
# ## [Spanish Flu](https://en.wikipedia.org/wiki/Spanish_flu)
# ### February 1918 – April 1920
# #### [Wages](../wages/index.ipynb) | [Life Expectancy](../expectancy/index.ipynb) | [Mortality Rates](../mortality/index.ipynb) | [Lockdown](../lockdown/index.ipynb)

# %% [markdown]
# ## Lockdown

# %% [markdown]
# ![images](../images/spanish_flu_3.jpg)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_excel("data_lockdown.xlsx")

# %%
df.head()
# Out:
#                         City  1915 Mortality Rate  1918 Mortality Rate  \
# 0    Los Angeles, California                 87.4                484.5
# 1        Oakland, California                 98.6                496.6
# 2  San Francisco, California                130.6                647.7
# 3           Denver, Colorado                184.8                727.7
# 4    Bridgeport, Connecticut                206.0                825.4
#
#   Lockdown Policy
# 0   Strict Policy
# 1   Strict Policy
# 2  Lenient Policy
# 3  Lenient Policy
# 4  Lenient Policy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 25 non-null     object
#  1   1915 Mortality Rate  25 non-null     float64
#  2   1918 Mortality Rate  25 non-null     float64
#  3   Lockdown Policy      25 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 928.0+ bytes

# %%
plt.figure(figsize=(14,5))
sn.scatterplot(x='1918 Mortality Rate',y='City',data=df,hue='Lockdown Policy')
# Out:
# <AxesSubplot:xlabel='1918 Mortality Rate', ylabel='City'>

# %%
plt.figure(figsize=(16,6))
sn.scatterplot(x='1918 Mortality Rate',y='1915 Mortality Rate',data=df,hue=df["Lockdown Policy"])
# Out:
# <AxesSubplot:xlabel='1918 Mortality Rate', ylabel='1915 Mortality Rate'>
