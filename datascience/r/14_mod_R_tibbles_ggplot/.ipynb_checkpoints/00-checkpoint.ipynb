# %% [markdown]
# Data Science Fundamentals: R |
# [Table of Contents](../index.ipynb)
# - - -
# <!--NAVIGATION-->
# Module 15. [tidyverse](./00.ipynb) | [R Markdown](./01.ipynb) | [R + Shiny App](./02.ipynb) | [Basic Visualization](./03.ipynb) | [Tibbles](./04.ipynb)  | [ggplot2](./05.ipynb) | [Statistical Transformations](./06.ipynb) | [Exercises](./07.ipynb)

# %% [markdown]
# # [tidyverse](https://www.tidyverse.org/)

# %% [markdown]
# ![tidyverse](images/slides1.png)

# %%
#Install tidyverse if you have not already done so.
#install.packages("tidyverse")

# %%
#library(tidyverse)

# %% [markdown]
# ![tidyverse](images/slides2.png)

# %% [markdown]
# ## [tidyverse Beginners Cheatsheet](docs/tidyverse-cheat-sheet.pdf)

# %% [markdown]
# ## Loading JSON Files

# %%
#Install rjson if you have not already done so.
#install.packages("rjson")

# %%
# Load the package required to read JSON files.
library("rjson")

# Give the input file name to the function.
result <- fromJSON(file = "dataSets/input.json")

# Print the result.
print(result)
# Out:
# $ID
# [1] "1" "2" "3" "4" "5" "6" "7" "8"
#
# $Name
# [1] "Rick"     "Dan"      "Michelle" "Ryan"     "Gary"     "Nina"     "Simon"
# [8] "Guru"
#
# $Salary
# [1] "623.3"  "515.2"  "611"    "729"    "843.25" "578"    "632.8"  "722.5"
#
# $StartDate
# [1] "1/1/2012"   "9/23/2013"  "11/15/2014" "5/11/2014"  "3/27/2015"
# [6] "5/21/2013"  "7/30/2013"  "6/17/2014"
#
# $Dept
# [1] "IT"         "Operations" "IT"         "HR"         "Finance"
# [6] "IT"         "Operations" "Finance"

# %%
library("rjson")

result <- fromJSON(file = "dataSets/input.json")

json_data_frame <- as.data.frame(result)

# %%
json_data_frame
# Out:
#   ID Name     Salary StartDate  Dept
# 1 1  Rick     623.3  1/1/2012   IT
# 2 2  Dan      515.2  9/23/2013  Operations
# 3 3  Michelle 611    11/15/2014 IT
# 4 4  Ryan     729    5/11/2014  HR
# 5 5  Gary     843.25 3/27/2015  Finance
# 6 6  Nina     578    5/21/2013  IT
# 7 7  Simon    632.8  7/30/2013  Operations
# 8 8  Guru     722.5  6/17/2014  Finance

# %%
#Install RJSONIO if you have not already done so.
#install.packages("RJSONIO")

# %%
library(RJSONIO)
# from the website
foodMarketsRaw <- fromJSON("https://data.ny.gov/api/views/9a8c-vfzj/rows.json?accessType=DOWNLOAD")
# Out:
# Warning message:
# "package 'RJSONIO' was built under R version 3.6.2"
# Attaching package: 'RJSONIO'
#
# The following objects are masked from 'package:rjson':
#
#     fromJSON, toJSON

# %%
foodMarkets <- foodMarketsRaw[['data']]

# name the food market 1
foodMarkets[[1]][[14]]

# name of food market 2
foodMarkets[[2]][[14]]

fmNames <- sapply(foodMarkets, function(x) x[[14]])
head(fmNames)
# Out:
# [1] "STEWARTS SHOP 389"
# [1] "MAN IN THE MOON"
# [[1]]
# [1] "STEWARTS SHOP 389"
#
# [[2]]
# [1] "MAN IN THE MOON"
#
# [[3]]
# [1] "J M L DELI"
#
# [[4]]
# [1] "EZ WHITE STREET"
#
# [[5]]
# [1] "QUICKLEES 012"
#
# [[6]]
# [1] "180 LA DELI GROCERY"

# %%
#Install gdata if you have not already done so.
#install.packages("gdata")

# %%
# for the trim function
library(gdata)
grabInfo <- function(var){
  print(paste("Variable", var, sep=" "))
  sapply(foodMarkets, function(x) returnData(x, var))
}

returnData <- function(x, var){
  if(!is.null( x[[var]])){
  	return( trim(x[[var]]))
  	}else{
  		return(NA)
  	}
  }


# do the extraction and assembly
 fmDataDF <- data.frame(sapply(1:22, grabInfo), stringsAsFactors=FALSE)
# Out:
# Warning message:
# "package 'gdata' was built under R version 3.6.3"gdata: Unable to locate valid perl interpreter
# gdata:
# gdata: read.xls() will be unable to read Excel XLS and XLSX files
# gdata: unless the 'perl=' argument is used to specify the location of a
# gdata: valid perl intrpreter.
# gdata:
# gdata: (To avoid display of this message in the future, please ensure
# gdata: perl is installed and available on the executable search path.)
# gdata: Unable to load perl libaries needed by read.xls()
# gdata: to support 'XLX' (Excel 97-2004) files.
#
# gdata: Unable to load perl libaries needed by read.xls()
# gdata: to support 'XLSX' (Excel 2007+) files.
#
# gdata: Run the function 'installXLSXsupport()'
# gdata: to automatically download and install the perl
# gdata: libaries needed to support Excel XLS and XLSX formats.
#
# Attaching package: 'gdata'
#
# The following object is masked from 'package:stats':
#
#     nobs
#
# The following object is masked from 'package:utils':
#
#     object.size
#
# The following object is masked from 'package:base':
#
#     startsWith
# [1] "Variable 1"
# [1] "Variable 2"
# [1] "Variable 3"
# [1] "Variable 4"
# [1] "Variable 5"
# [1] "Variable 6"
# [1] "Variable 7"
# [1] "Variable 8"
# [1] "Variable 9"
# [1] "Variable 10"
# [1] "Variable 11"
# [1] "Variable 12"
# [1] "Variable 13"
# [1] "Variable 14"
# [1] "Variable 15"
# [1] "Variable 16"
# [1] "Variable 17"
# [1] "Variable 18"
# [1] "Variable 19"
# [1] "Variable 20"
# [1] "Variable 21"
# [1] "Variable 22"

# %%
fmDataDF
# Out:
#       X1                 X2                                   X3  X4
# 1     row-bmva-tkb5-2dx7 00000000-0000-0000-90F2-26A64FA6E755 0   1630695187
# 2     row-2cqz_dfmj~m5gb 00000000-0000-0000-4C32-933D3D828E69 0   1630695187
# 3     row-yf74-k3xm~pajw 00000000-0000-0000-F593-7EC8D32A16E1 0   1630695187
# 4     row-y39z-m2eu-6z2z 00000000-0000-0000-9530-45D17AE44F42 0   1630695187
# 5     row-4zcr-722r-y9fi 00000000-0000-0000-C192-5C6A048F84FB 0   1630695187
# 6     row-84xv.rwmz_s6g2 00000000-0000-0000-F06C-FA33AEBA3A64 0   1630695187
# 7     row-vn8h_btsb-k49b 00000000-0000-0000-1BE7-9416F2D8B1FA 0   1630695187
# 8     row-gjdx_6u4i_sid3 00000000-0000-0000-1B08-7806A4C53397 0   1630695187
# 9     row-futc~f58v~riqi 00000000-0000-0000-51EC-BEFB33D5AF3A 0   1630695187
# 10    row-thuf-sked_pz8j 00000000-0000-0000-3787-BE6EF140485F 0   1630695187
# 11    row-dz64.pdvr.fyd6 00000000-0000-0000-B215-36E6BD06A77E 0   1630695187
# 12    row-niwh-qxdt-s4zc 00000000-0000-0000-F876-815B384503B2 0   1630695187
# 13    row-j7ts.nuxc~gzvk 00000000-0000-0000-212E-DBA3FAE692EF 0   1630695187
# 14    row-384h~q447.b73r 00000000-0000-0000-9E9F-AFFF8EACDC9E 0   1630695187
# 15    row-ngnd_n8bm-r7kk 00000000-0000-0000-ED65-9B1D1300BCDB 0   1630695187
# 16    row-izyx.kujg.s7rg 00000000-0000-0000-68A0-E09338052C63 0   1630695187
# 17    row-m8bz.dnt7_s2gq 00000000-0000-0000-7829-0C55413BCCB4 0   1630695187
# 18    row-39vh.q9zv-47hg 00000000-0000-0000-D5C7-412AC2ED2528 0   1630695187
# 19    row-hrbh.8uxt_7tmg 00000000-0000-0000-9ABA-36B99F07AD35 0   1630695187
# 20    row-mtpq_c82w-za5z 00000000-0000-0000-1F08-9B58AA17868B 0   1630695187
# 21    row-5jtv.p6yj.kgsx 00000000-0000-0000-0A94-16364B1128F2 0   1630695187
# 22    row-y9hs.dnpq~bmdz 00000000-0000-0000-A17C-FF8B33A8D210 0   1630695187
# 23    row-vxus_5kjt.y5sa 00000000-0000-0000-548D-7818BF223C6F 0   1630695187
# 24    row-cnri~j59x_4sst 00000000-0000-0000-45C7-91E1B26E9044 0   1630695187
# 25    row-vf2j_vhx9_jqt8 00000000-0000-0000-E276-E546DCB32228 0   1630695187
# 26    row-v3zd~2387.tp63 00000000-0000-0000-B4FB-285A1CFB7838 0   1630695187
# 27    row-fzcu-zecc~cwhv 00000000-0000-0000-DD17-0031235F479E 0   1630695187
# 28    row-vmy2_g8ji~be6b 00000000-0000-0000-0F84-8AA650A4FD7D 0   1630695187
# 29    row-43q8.82c5.bj83 00000000-0000-0000-EEE1-A7A7613212DA 0   1630695187
# 30    row-fjcz-czpd.shdm 00000000-0000-0000-2C98-B6B2FCA508E0 0   1630695187
# ...   ...                ...                                  ... ...
# 28443 row-mkun~5em7_5r5n 00000000-0000-0000-014A-B140884269BF 0   1630695187
# 28444 row-ej3b~6q2t-i3ru 00000000-0000-0000-1CBC-08329B00A20C 0   1630695187
# 28445 row-aurb.prv8_mjmt 00000000-0000-0000-479E-4FE7FB8E15ED 0   1630695187
# 28446 row-tc8b.izyg_zdq2 00000000-0000-0000-1A89-A89B366AE85F 0   1630695187
# 28447 row-ft8e.bct2.2z3g 00000000-0000-0000-B276-41059EEBAD69 0   1630695187
# 28448 row-re2u_mii2~bq25 00000000-0000-0000-C759-F98C8B2BD64D 0   1630695187
# 28449 row-zi2k_efsu.kfm2 00000000-0000-0000-E4E2-5BE8799ECEE0 0   1630695187
# 28450 row-xp3r~kitb~u4zd 00000000-0000-0000-931F-6AC53549BB32 0   1630695187
# 28451 row-h7tj~gjc6.mf3w 00000000-0000-0000-5779-8F1E37561798 0   1630695187
# 28452 row-pvnt-mahe-uhnv 00000000-0000-0000-382E-3DBD80729034 0   1630695187
# 28453 row-zz4q_rk8x_ifvn 00000000-0000-0000-CF37-0BCFD3867E1E 0   1630695187
# 28454 row-zxqg.7k8q-gfpr 00000000-0000-0000-7159-453E680C8DE7 0   1630695187
# 28455 row-cx2e-dcuw_w4et 00000000-0000-0000-8650-E634F78AE342 0   1630695187
# 28456 row-gj43~udv5_535c 00000000-0000-0000-9C19-4CDF671677B7 0   1630695187
# 28457 row-e5q7-pqh6-tr7d 00000000-0000-0000-9C04-5C0DCC7D27BC 0   1630695187
# 28458 row-ab69~wvex.eiyg 00000000-0000-0000-CE66-DEEB617DB082 0   1630695187
# 28459 row-garp-9dna.gi36 00000000-0000-0000-C48E-2C3CB19FD57A 0   1630695187
# 28460 row-qcns-jgna.ihsv 00000000-0000-0000-623B-5532B416F43A 0   1630695187
# 28461 row-t5fh.g7cf_mkus 00000000-0000-0000-40B9-846C4D64A66E 0   1630695187
# 28462 row-fpxe-5kmc-zw2i 00000000-0000-0000-53E5-443BCA119F7F 0   1630695187
# 28463 row-fjef_ti3k_rd9m 00000000-0000-0000-D773-5613E6ECBA80 0   1630695187
# 28464 row-dmb3-a5q4-edr3 00000000-0000-0000-B657-F343AC462184 0   1630695187
# 28465 row-8sh9_8xdd-ns2g 00000000-0000-0000-B169-3EF43893E34D 0   1630695187
# 28466 row-ngms~dfjn-znrt 00000000-0000-0000-935B-D2A982AA3560 0   1630695187
# 28467 row-tbka~6944.nxsj 00000000-0000-0000-C360-A7BD84EE4ADE 0   1630695187
# 28468 row-gm7f-pfsv_868e 00000000-0000-0000-84D1-ABBEAB879043 0   1630695187
# 28469 row-yq9y_4nfk_8s77 00000000-0000-0000-BC58-F7978E345138 0   1630695187
# 28470 row-yhfz_pi6g_mnkd 00000000-0000-0000-582D-AE663603F08E 0   1630695187
# 28471 row-q4hn.4mwm.kuxt 00000000-0000-0000-B807-4D46F1534E78 0   1630695187
# 28472 row-jkde~wyvq_dge8 00000000-0000-0000-8059-EE48F39ED790 0   1630695187
#       X5  X6         X7  X8  X9           X10    ...
# 1     NA  1630695201 NA  { } Greene       190060 ...
# 2     NA  1630695201 NA  { } Oswego       735781 ...
# 3     NA  1630695201 NA  { } Kings        740047 ...
# 4     NA  1630695201 NA  { } Dutchess     741000 ...
# 5     NA  1630695201 NA  { } Steuben      706669 ...
# 6     NA  1630695201 NA  { } Bronx        705401 ...
# 7     NA  1630695201 NA  { } New York     745415 ...
# 8     NA  1630695201 NA  { } Chenango     738725 ...
# 9     NA  1630695201 NA  { } Nassau       713956 ...
# 10    NA  1630695201 NA  { } Nassau       282141 ...
# 11    NA  1630695201 NA  { } Warren       748383 ...
# 12    NA  1630695201 NA  { } Onondaga     311158 ...
# 13    NA  1630695201 NA  { } Queens       637172 ...
# 14    NA  1630695201 NA  { } Greene       731102 ...
# 15    NA  1630695201 NA  { } Monroe       748682 ...
# 16    NA  1630695201 NA  { } Erie         739428 ...
# 17    NA  1630695201 NA  { } Queens       634717 ...
# 18    NA  1630695201 NA  { } Seneca       450137 ...
# 19    NA  1630695201 NA  { } Oneida       300536 ...
# 20    NA  1630695201 NA  { } Monroe       260694 ...
# 21    NA  1630695201 NA  { } Queens       730157 ...
# 22    NA  1630695201 NA  { } Orange       330765 ...
# 23    NA  1630695201 NA  { } Clinton      095374 ...
# 24    NA  1630695201 NA  { } Queens       631529 ...
# 25    NA  1630695201 NA  { } Yates        731155 ...
# 26    NA  1630695201 NA  { } Clinton      090339 ...
# 27    NA  1630695201 NA  { } Delaware     728623 ...
# 28    NA  1630695201 NA  { } Erie         732218 ...
# 29    NA  1630695201 NA  { } New York     739781 ...
# 30    NA  1630695201 NA  { } St. Lawrence 400244 ...
# ...   ... ...        ... ... ...          ...
# 28443 NA  1630695207 NA  { } Bronx        745116 ...
# 28444 NA  1630695207 NA  { } Richmond     641567 ...
# 28445 NA  1630695207 NA  { } Queens       729039 ...
# 28446 NA  1630695207 NA  { } Monroe       731629 ...
# 28447 NA  1630695207 NA  { } Suffolk      714374 ...
# 28448 NA  1630695207 NA  { } Queens       705893 ...
# 28449 NA  1630695207 NA  { } Suffolk      741612 ...
# 28450 NA  1630695207 NA  { } Richmond     730820 ...
# 28451 NA  1630695207 NA  { } Albany       010615 ...
# 28452 NA  1630695207 NA  { } Jefferson    735282 ...
# 28453 NA  1630695207 NA  { } Kings        746932 ...
# 28454 NA  1630695207 NA  { } Queens       727401 ...
# 28455 NA  1630695207 NA  { } Richmond     748059 ...
# 28456 NA  1630695207 NA  { } Richmond     737290 ...
# 28457 NA  1630695207 NA  { } Richmond     746825 ...
# 28458 NA  1630695207 NA  { } Bronx        719037 ...
# 28459 NA  1630695207 NA  { } Suffolk      472801 ...
# 28460 NA  1630695207 NA  { } Queens       672034 ...
# 28461 NA  1630695207 NA  { } Kings        672051 ...
# 28462 NA  1630695207 NA  { } Broome       030215 ...
# 28463 NA  1630695207 NA  { } Queens       671206 ...
# 28464 NA  1630695207 NA  { } Otsego       749091 ...
# 28465 NA  1630695207 NA  { } Queens       639695 ...
# 28466 NA  1630695207 NA  { } Bronx        608591 ...
# 28467 NA  1630695207 NA  { } Bronx        728237 ...
# 28468 NA  1630695207 NA  { } Kings        723059 ...
# 28469 NA  1630695207 NA  { } Richmond     714797 ...
# 28470 NA  1630695207 NA  { } Queens       717456 ...
# 28471 NA  1630695207 NA  { } Queens       717592 ...
# 28472 NA  1630695207 NA  { } Queens       671764 ...
#       X13                              X14                     X15
# 1     STEWARTS SHOPS CORP              STEWARTS SHOP 389       4834
# 2     LEAR AMY MARIE T                 MAN IN THE MOON         192
# 3     J M L DELI CORP                  J M L DELI              297
# 4     EZ WHITE STREET CORP             EZ WHITE STREET         31
# 5     PEMM LLC                         QUICKLEES 012           349-353
# 6     180 LA DELI GROCERY CORP         180 LA DELI GROCERY     180
# 7     MISIPASTA LLC                    MISIPASTA               55
# 8     DOLGEN NEW YORK LLC              DOLLAR GENERAL #19913   109
# 9     BPRF LLC                         BPRF                    236-01
# 10    EFE CORP                         EFE STORE               767
# 11    CANDY SPACE LLC THE              THE CANDY SPACE         1439
# 12    TOPS PT LLC                      TOPS 365                119
# 13    LINDEN BLVD SERVICE STATION CORP MOBIL                   113-21
# 14    JULIUS ROSE SALUMERIA CORP       TODAROS SALUMERIA       5344
# 15    SUN REYA LLC                     DIVANNA CHOCOLATES      250
# 16    SPEEDWAY LLC                     SPEEDWAY #9898          6125
# 17    MERRICK MEAT FARMS INC           MERRICK MEAT FARMS      234-21
# 18    D&M GROCERY INC                  D&M GROCERY             14
# 19    715 JOHN ST LLC                  SUPER PLUS MARKET       715
# 20    CVS ALBANY LLC                   CVS PHARMACY 2067       2580
# 21    ARTUR ARONOV                     SHOE CARE SERVICES      81-53A
# 22    HATZLUCAH MEAT MARKET INC        HATZLUCAH MEAT MARKET   2
# 23    JOLLEY ASSOC LLC (ESTATE OF)     SHORT STOP              443
# 24    BRAUN TUNA                       BRAUNS FISH STORE       72-14
# 25    7-ELEVEN INC                     A PLUS #40140H          139
# 26    GIROUX ORCHARDS LLC              CHAZY ORCHARDS          9486
# 27    DOLGENCORP OF NEW YORK INC       DOLLAR GENERAL #17621   36558
# 28    7-ELEVEN INC                     A PLUS #40192H          8000
# 29    YDHNY INC                        FOODTOWN SEAFOOD        10600
# 30    PERRYS  BEVERAGE CENTER INC      PERRYS PLACE            7211
# ...   ...                              ...                     ...
# 28443 ACTIVE CONVENIENCE INC           ACTIVE CONVENIENCE      1885
# 28444 ANTONICO FOODS CORP              LA BELLA MARKETPLACE    99
# 28445 FUXING MINI MARKET INC           FUXING MINI MARKET      41-36
# 28446 SHOP SMART MARKET INC            SHOP SMART MARKET       439
# 28447 PRZYSMAK DELI INC                PRZYSMAK DELI           1635
# 28448 EL NILE MEAT MARKET INC          EL NOOR                 2502
# 28449 FATIMA FOOD INC                  7 ELEVEN STORE #23450D  1701
# 28450 ALPER GROCERY INC                ALPER GROCERY           71
# 28451 DUNCO INC                        A PLUS SUNOCO           656
# 28452 7-ELEVEN INC                     A PLUS #40487H          26253
# 28453 ALOE FRUITS LLC                  ALOE FRUITS             500
# 28454 FAMOUS DELI OF QUEENS INC        FAMOUS DELI OF QUEENS   157-23
# 28455 JANA FOOD CORP                   JANA FOOD               159
# 28456 MONSEY PLACE DELI & GROCERY INC  MONSEY PLACE DELI & GRO 950
# 28457 SANAA HOOKAH PLUS CORP           SANAA HOOKAH PLUS       7311
# 28458 DESHI FOOD MARKETS INC           DESHI FOOD MARKETS      1271
# 28459 COLLEGE PLAZA99 CENTS STORE INC  99 CENTS GREAT STORE    41
# 28460 FRESH MEADOWS NATURAL INC        FRESH MEADOWS NATURAL   6974
# 28461 REYES PATRICIA M                 JASMIN GROCERY STORE    679
# 28462 CORDISCO JOHN A                  CORDISCOS CORNER STORE  308
# 28463 KLEYNBURG ROMAN                  7-ELEVEN STORE #35314A  50-92
# 28464 SMITH WENDY                      EMPIRE NATURAL FOODS    9
# 28465 OVIEDO RAMONA                    RO FRANCIS LEWIS DELI   112-01
# 28466 RODRIGUEZ DANIEL                 DANIEL RODRIGUEZ PRODUC 190
# 28467 1454 MC DELI GROCERY CORP        1454 MC DELI GROCERY    1454
# 28468 OCEAN A & R PHARMACY INC         OCEAN A & R PHARMACY    2806
# 28469 BAGELS R US INC                  BAGELS R US             4300
# 28470 ALCANTARA SALIN SOLIS            SOLIS GROCERY STORE     39-17
# 28471 108 NINOS CORP                   108 NINOS               53-09
# 28472 KING POLO INC                    SHOP FAIR               153-30
#       X16                         X17 X18 X19              X20 X21   X22
# 1     RT 81 PO BOX 240            NA  NA  GREENVILLE       NY  12083 2900
# 2     W 1ST ST                    NA  NA  OSWEGO           NY  13126 6000
# 3     T S BOYLAND ST.             NA  NA  BROOKLYN         NY  11233 0
# 4     SOUTHWHITE STREET           NA  NA  POUGHKEEPSIE     NY  12601 1000
# 5     W MORRIS ST                 NA  NA  BATH             NY  14810 1500
# 6     MCLELLAN ST                 NA  NA  BRONX            NY  10456 1100
# 7     W 49TH ST                   NA  NA  NEW YORK         NY  10020 0
# 8     STATE RT 12                 NA  NA  CHENANGO FORKS   NY  13746 9700
# 9     LINDEN BLVD                 NA  NA  ELMONT           NY  11003 800
# 10    WANTAGH AVE                 NA  NA  WANTAGH          NY  11793 500
# 11    US 9 UNIT 6 FRENCH MTN COMM NA  NA  LAKE GEORGE      NY  12845 2100
# 12    W SENECA TPKE               NA  NA  MANLIUS          NY  13104 39080
# 13    MERRICK BLVD                NA  NA  ST ALBANS        NY  11433 150
# 14    ROUTE 23                    NA  NA  WINDHAM          NY  12496 4800
# 15    E MAIN ST.                  NA  NA  ROCHESTER        NY  14604 0
# 16    MAIN ST                     NA  NA  BUFFALO          NY  14221 3000
# 17    MERRICK BLVD                NA  NA  LAURELTON        NY  11422 10000
# 18    SWIFT ST                    NA  NA  WATERLOO         NY  13165 1200
# 19    JOHN ST                     NA  NA  UTICA            NY  13501 1200
# 20    E HENRIETTA RD              NA  NA  HENRIETTA        NY  14467 0
# 21    LEFFERTS BLVD               NA  NA  KEW GARDENS      NY  11415 600
# 22    GARFIELD   #102             NA  NA  MONROE           NY  10950 600
# 23    RT 3                        NA  NA  PLATTSBURGH      NY  12901 1500
# 24    MAIN ST                     NA  NA  FLUSHING         NY  11367 1500
# 25    ELM ST.                     NA  NA  PENN YAN         NY  14527 0
# 26    RT 9                        NA  NA  CHAZY            NY  12921 800
# 27    ROUTE 23                    NA  NA  GRAND GORGE      NY  12434 0
# 28    MAIN & TRANSIT              NA  NA  BUFFALO          NY  14221 2400
# 29    160TH STREET                NA  NA  NEW YORK         NY  10032 0
# 30    ST HWY 68                   NA  NA  OGDENSBURG       NY  13669 1800
# ...   ...                         ... ... ...              ... ...   ...
# 28443 WEBSTER AVE                 NA  NA  BRONX            NY  10457 500
# 28444 ELLIS ST                    NA  NA  STATEN ISLAND    NY  10307 25000
# 28445 MAIN STREET                 NA  NA  FLUSHING         NY  11355 800
# 28446 SOUTH AVENUE                NA  NA  ROCHESTER        NY  14620 0
# 28447 GREAT NECK RD  UNIT 8       NA  NA  COPIAGUE         NY  11726 1000
# 28448 STEINWAY ST.                NA  NA  ASTORIA          NY  11103 500
# 28449 UNION BLVD                  NA  NA  BAY SHORE        NY  11706 2500
# 28450 LAFAYETTE AVENUE            NA  NA  STATEN ISLAND    NY  10301 2000
# 28451 ALBANY SHAKER RD            NA  NA  ALBANY           NY  12211 1800
# 28452 US RT 11                    NA  NA  EVANS MILLS      NY  13637 3500
# 28453 DEKALB AVE                  NA  NA  BROOKLYN         NY  11205 0
# 28454 ROCKAWAY BLVD               NA  NA  JAMAICA          NY  11434 1200
# 28455 LAFAYETTE AVE               NA  NA  STATEN ISLAND    NY  10301 3000
# 28456 RICHMOND AVE                NA  NA  STATEN ISLAND    NY  10314 1800
# 28457 AMBOY ROAD                  NA  NA  STATEN ISLAND    NY  10307 2500
# 28458 WHITE PLAINS RD             NA  NA  BRONX            NY  10472 0
# 28459 COLLEGE PLAZA               NA  NA  SELDEN           NY  11784 2000
# 28460 188TH ST                    NA  NA  FRESH MEADOWS    NY  11365 2000
# 28461 MYRTLE AVE                  NA  NA  BROOKLYN         NY  11205 800
# 28462 CHENANGO ST                 NA  NA  BINGHAMTON       NY  13901 1900
# 28463 NORTHERN BLVD               NA  NA  LONG ISLAND CITY NY  11101 1000
# 28464 RAILROAD AVE                NA  NA  COOPERSTOWN      NY  13326 0
# 28465 FRANCIS LEWIS BLVD          NA  NA  QUEENS VILLAGE   NY  11429 1200
# 28466 E 166TH ST                  NA  NA  BRONX            NY  10456 1000
# 28467 GRAND CONCOURSE             NA  NA  BRONX            NY  10457 1400
# 28468 OCEAN AVE                   NA  NA  BROOKLYN         NY  11229 2000
# 28469 AMBOY RD                    NA  NA  STATEN ISLAND    NY  10312 1800
# 28470 112TH ST                    NA  NA  CORONA           NY  11368 0
# 28471 108TH ST                    NA  NA  CORONA           NY  11368 700
# 28472 89TH AVE                    NA  NA  JAMAICA          NY  11432 10000

# %%
foodMarkets[[1]][[23]]
# Out:
# NULL

# %%
grabGeoInfo<-function(val){

    l<- length(foodMarkets[[1]][[val]])
    tmp<-lapply(1:l, function(y) 

      sapply(foodMarkets, function(x){

        if(!is.null(x[[val]][[y]])){
          return(x[[val]][[y]])
        }else{
          return(NA)
        }

        })     
      )
}

# %%
# add the names
columns<-foodMarketsRaw[['meta']][['view']][['columns']]

# %%
columns
# Out:
# [[1]]
# [[1]]$id
# [1] -1
#
# [[1]]$name
# [1] "sid"
#
# [[1]]$dataTypeName
# [1] "meta_data"
#
# [[1]]$fieldName
# [1] ":sid"
#
# [[1]]$position
# [1] 0
#
# [[1]]$renderTypeName
# [1] "meta_data"
#
# [[1]]$format
# named list()
#
# [[1]]$flags
# [1] "hidden"
#
#
# [[2]]
# [[2]]$id
# [1] -1
#
# [[2]]$name
# [1] "id"
#
# [[2]]$dataTypeName
# [1] "meta_data"
#
# [[2]]$fieldName
# [1] ":id"
#
# [[2]]$position
# [1] 0
#
# [[2]]$renderTypeName
# [1] "meta_data"
#
# [[2]]$format
# named list()
#
# [[2]]$flags
# [1] "hidden"
#
#
# [[3]]
# [[3]]$id
# [1] -1
#
# [[3]]$name
# [1] "position"
#
# [[3]]$dataTypeName
# [1] "meta_data"
#
# [[3]]$fieldName
# [1] ":position"
#
# [[3]]$position
# [1] 0
#
# [[3]]$renderTypeName
# [1] "meta_data"
#
# [[3]]$format
# named list()
#
# [[3]]$flags
# [1] "hidden"
#
#
# [[4]]
# [[4]]$id
# [1] -1
#
# [[4]]$name
# [1] "created_at"
#
# [[4]]$dataTypeName
# [1] "meta_data"
#
# [[4]]$fieldName
# [1] ":created_at"
#
# [[4]]$position
# [1] 0
#
# [[4]]$renderTypeName
# [1] "meta_data"
#
# [[4]]$format
# named list()
#
# [[4]]$flags
# [1] "hidden"
#
#
# [[5]]
# [[5]]$id
# [1] -1
#
# [[5]]$name
# [1] "created_meta"
#
# [[5]]$dataTypeName
# [1] "meta_data"
#
# [[5]]$fieldName
# [1] ":created_meta"
#
# [[5]]$position
# [1] 0
#
# [[5]]$renderTypeName
# [1] "meta_data"
#
# [[5]]$format
# named list()
#
# [[5]]$flags
# [1] "hidden"
#
#
# [[6]]
# [[6]]$id
# [1] -1
#
# [[6]]$name
# [1] "updated_at"
#
# [[6]]$dataTypeName
# [1] "meta_data"
#
# [[6]]$fieldName
# [1] ":updated_at"
#
# [[6]]$position
# [1] 0
#
# [[6]]$renderTypeName
# [1] "meta_data"
#
# [[6]]$format
# named list()
#
# [[6]]$flags
# [1] "hidden"
#
#
# [[7]]
# [[7]]$id
# [1] -1
#
# [[7]]$name
# [1] "updated_meta"
#
# [[7]]$dataTypeName
# [1] "meta_data"
#
# [[7]]$fieldName
# [1] ":updated_meta"
#
# [[7]]$position
# [1] 0
#
# [[7]]$renderTypeName
# [1] "meta_data"
#
# [[7]]$format
# named list()
#
# [[7]]$flags
# [1] "hidden"
#
#
# [[8]]
# [[8]]$id
# [1] -1
#
# [[8]]$name
# [1] "meta"
#
# [[8]]$dataTypeName
# [1] "meta_data"
#
# [[8]]$fieldName
# [1] ":meta"
#
# [[8]]$position
# [1] 0
#
# [[8]]$renderTypeName
# [1] "meta_data"
#
# [[8]]$format
# named list()
#
# [[8]]$flags
# [1] "hidden"
#
#
# [[9]]
# [[9]]$id
# [1] 547687020
#
# [[9]]$name
# [1] "County"
#
# [[9]]$dataTypeName
# [1] "text"
#
# [[9]]$description
# [1] "The county in which the licensed entity is physically located"
#
# [[9]]$fieldName
# [1] "county"
#
# [[9]]$position
# [1] 1
#
# [[9]]$renderTypeName
# [1] "text"
#
# [[9]]$tableColumnId
# [1] 8179659
#
# [[9]]$width
# [1] 137
#
# [[9]]$cachedContents
# [[9]]$cachedContents$non_null
# [1] "28472"
#
# [[9]]$cachedContents$largest
# [1] "Yates"
#
# [[9]]$cachedContents$null
# [1] "0"
#
# [[9]]$cachedContents$top
# [[9]]$cachedContents$top[[1]]
#    item   count
# "Kings"  "4881"
#
# [[9]]$cachedContents$top[[2]]
#     item    count
# "Queens"   "3043"
#
# [[9]]$cachedContents$top[[3]]
#    item   count
# "Bronx"  "2560"
#
# [[9]]$cachedContents$top[[4]]
#       item      count
# "New York"     "2483"
#
# [[9]]$cachedContents$top[[5]]
#      item     count
# "Suffolk"    "1916"
#
# [[9]]$cachedContents$top[[6]]
#     item    count
# "Nassau"   "1459"
#
# [[9]]$cachedContents$top[[7]]
#   item  count
# "Erie" "1261"
#
# [[9]]$cachedContents$top[[8]]
#          item         count
# "Westchester"        "1131"
#
# [[9]]$cachedContents$top[[9]]
#     item    count
# "Monroe"    "862"
#
# [[9]]$cachedContents$top[[10]]
#       item      count
# "Onondaga"      "647"
#
# [[9]]$cachedContents$top[[11]]
#       item      count
# "Richmond"      "578"
#
# [[9]]$cachedContents$top[[12]]
#     item    count
# "Orange"    "518"
#
# [[9]]$cachedContents$top[[13]]
#     item    count
# "Albany"    "455"
#
# [[9]]$cachedContents$top[[14]]
#       item      count
# "Dutchess"      "411"
#
# [[9]]$cachedContents$top[[15]]
#     item    count
# "Oneida"    "360"
#
# [[9]]$cachedContents$top[[16]]
#       item      count
# "Rockland"      "346"
#
# [[9]]$cachedContents$top[[17]]
#     item    count
# "Ulster"    "343"
#
# [[9]]$cachedContents$top[[18]]
#       item      count
# "Saratoga"      "289"
#
# [[9]]$cachedContents$top[[19]]
#     item    count
# "Broome"    "275"
#
# [[9]]$cachedContents$top[[20]]
#      item     count
# "Niagara"     "264"
#
#
# [[9]]$cachedContents$smallest
# [1] "Albany"
#
# [[9]]$cachedContents$count
# [1] "28472"
#
# [[9]]$cachedContents$cardinality
# [1] "62"
#
#
# [[9]]$format
#    align
# "center"
#
#
# [[10]]
# [[10]]$id
# [1] 547687021
#
# [[10]]$name
# [1] "License Number"
#
# [[10]]$dataTypeName
# [1] "text"
#
# [[10]]$description
# [1] "The licensed entityâ\200\231s license number for this location"
#
# [[10]]$fieldName
# [1] "license_number"
#
# [[10]]$position
# [1] 2
#
# [[10]]$renderTypeName
# [1] "text"
#
# [[10]]$tableColumnId
# [1] 8179648
#
# [[10]]$width
# [1] 183
#
# [[10]]$cachedContents
# [[10]]$cachedContents$non_null
# [1] "28472"
#
# [[10]]$cachedContents$largest
# [1] "749282"
#
# [[10]]$cachedContents$null
# [1] "0"
#
# [[10]]$cachedContents$top
# [[10]]$cachedContents$top[[1]]
#     item    count
# "707955"      "1"
#
# [[10]]$cachedContents$top[[2]]
#     item    count
# "380353"      "1"
#
# [[10]]$cachedContents$top[[3]]
#     item    count
# "708798"      "1"
#
# [[10]]$cachedContents$top[[4]]
#     item    count
# "608434"      "1"
#
# [[10]]$cachedContents$top[[5]]
#     item    count
# "287440"      "1"
#
# [[10]]$cachedContents$top[[6]]
#     item    count
# "744192"      "1"
#
# [[10]]$cachedContents$top[[7]]
#     item    count
# "720712"      "1"
#
# [[10]]$cachedContents$top[[8]]
#     item    count
# "739769"      "1"
#
# [[10]]$cachedContents$top[[9]]
#     item    count
# "641391"      "1"
#
# [[10]]$cachedContents$top[[10]]
#     item    count
# "619514"      "1"
#
# [[10]]$cachedContents$top[[11]]
#     item    count
# "739668"      "1"
#
# [[10]]$cachedContents$top[[12]]
#     item    count
# "731595"      "1"
#
# [[10]]$cachedContents$top[[13]]
#     item    count
# "604597"      "1"
#
# [[10]]$cachedContents$top[[14]]
#     item    count
# "739095"      "1"
#
# [[10]]$cachedContents$top[[15]]
#     item    count
# "746903"      "1"
#
# [[10]]$cachedContents$top[[16]]
#     item    count
# "712820"      "1"
#
# [[10]]$cachedContents$top[[17]]
#     item    count
# "552501"      "1"
#
# [[10]]$cachedContents$top[[18]]
#     item    count
# "473341"      "1"
#
# [[10]]$cachedContents$top[[19]]
#     item    count
# "743228"      "1"
#
# [[10]]$cachedContents$top[[20]]
#     item    count
# "740966"      "1"
#
#
# [[10]]$cachedContents$smallest
# [1] "010008"
#
# [[10]]$cachedContents$count
# [1] "28472"
#
# [[10]]$cachedContents$cardinality
# [1] "28472"
#
#
# [[10]]$format
#    align
# "center"
#
#
# [[11]]
# [[11]]$id
# [1] 547687022
#
# [[11]]$name
# [1] "Operation Type"
#
# [[11]]$dataTypeName
# [1] "text"
#
# [[11]]$description
# [1] "The type of operation the licensed entity conducts"
#
# [[11]]$fieldName
# [1] "operation_type"
#
# [[11]]$position
# [1] 3
#
# [[11]]$renderTypeName
# [1] "text"
#
# [[11]]$tableColumnId
# [1] 8179649
#
# [[11]]$width
# [1] 176
#
# [[11]]$cachedContents
# [[11]]$cachedContents$non_null
# [1] "28472"
#
# [[11]]$cachedContents$largest
# [1] "Store"
#
# [[11]]$cachedContents$null
# [1] "0"
#
# [[11]]$cachedContents$top
# [[11]]$cachedContents$top[[1]]
#    item   count
# "Store" "28472"
#
#
# [[11]]$cachedContents$smallest
# [1] "Store"
#
# [[11]]$cachedContents$count
# [1] "28472"
#
# [[11]]$cachedContents$cardinality
# [1] "1"
#
#
# [[11]]$format
#    align
# "center"
#
#
# [[12]]
# [[12]]$id
# [1] 547687023
#
# [[12]]$name
# [1] "Establishment Type"
#
# [[12]]$dataTypeName
# [1] "text"
#
# [[12]]$description
# [1] "The establishment type for the licensed entity at this location; see document in â\200\230Aboutâ\200\231 section, or go to https://data.ny.gov/api/views/9a8c-vfzj/files/UBDP3oW2f-K767I4f51EJaIUO8eNGPrAQQj8tSvBhbo?download=true&filename=NYSDAM_RetailFoodStoresEstablishmentTypeCodes.pdf"
#
# [[12]]$fieldName
# [1] "estab_type"
#
# [[12]]$position
# [1] 4
#
# [[12]]$renderTypeName
# [1] "text"
#
# [[12]]$tableColumnId
# [1] 21635505
#
# [[12]]$width
# [1] 196
#
# [[12]]$cachedContents
# [[12]]$cachedContents$non_null
# [1] "28472"
#
# [[12]]$cachedContents$largest
# [1] "JKDA"
#
# [[12]]$cachedContents$null
# [1] "0"
#
# [[12]]$cachedContents$top
# [[12]]$cachedContents$top[[1]]
#    item   count
#   "JAC" "19397"
#
# [[12]]$cachedContents$top[[2]]
#   item  count
#    "A" "6801"
#
# [[12]]$cachedContents$top[[3]]
#   item  count
# "JABC" "1256"
#
# [[12]]$cachedContents$top[[4]]
#   item  count
# "JACH"  "155"
#
# [[12]]$cachedContents$top[[5]]
#   item  count
# "JACD"  "121"
#
# [[12]]$cachedContents$top[[6]]
#    item   count
# "JABCH"   "106"
#
# [[12]]$cachedContents$top[[7]]
#   item  count
# "JACK"   "83"
#
# [[12]]$cachedContents$top[[8]]
#    item   count
# "JACDK"    "68"
#
# [[12]]$cachedContents$top[[9]]
#  item count
# "JAD"  "57"
#
# [[12]]$cachedContents$top[[10]]
#  item count
# "JAB"  "51"
#
# [[12]]$cachedContents$top[[11]]
#   item  count
# "JABH"   "38"
#
# [[12]]$cachedContents$top[[12]]
#    item   count
# "JABCK"    "31"
#
# [[12]]$cachedContents$top[[13]]
#   item  count
# "JADK"   "30"
#
# [[12]]$cachedContents$top[[14]]
#   item  count
# "JACW"   "26"
#
# [[12]]$cachedContents$top[[15]]
#     item    count
# "JABCHK"     "21"
#
# [[12]]$cachedContents$top[[16]]
#    item   count
# "JACHK"    "21"
#
# [[12]]$cachedContents$top[[17]]
#    item   count
# "JABHK"    "19"
#
# [[12]]$cachedContents$top[[18]]
#     item    count
# "JACDHK"     "17"
#
# [[12]]$cachedContents$top[[19]]
#  item count
# "JAW"  "16"
#
# [[12]]$cachedContents$top[[20]]
#  item count
# "JAS"  "11"
#
#
# [[12]]$cachedContents$smallest
# [1] "A"
#
# [[12]]$cachedContents$count
# [1] "28472"
#
# [[12]]$cachedContents$cardinality
# [1] "82"
#
#
# [[12]]$format
#    align
# "center"
#
#
# [[13]]
# [[13]]$id
# [1] 547687024
#
# [[13]]$name
# [1] "Entity Name"
#
# [[13]]$dataTypeName
# [1] "text"
#
# [[13]]$description
# [1] "The name of the licensed entity"
#
# [[13]]$fieldName
# [1] "entity_name"
#
# [[13]]$position
# [1] 5
#
# [[13]]$renderTypeName
# [1] "text"
#
# [[13]]$tableColumnId
# [1] 8179650
#
# [[13]]$width
# [1] 306
#
# [[13]]$cachedContents
# [[13]]$cachedContents$non_null
# [1] "28472"
#
# [[13]]$cachedContents$largest
# [1] "Z&Z TWO BROTHERS INC"
#
# [[13]]$cachedContents$null
# [1] "0"
#
# [[13]]$cachedContents$top
# [[13]]$cachedContents$top[[1]]
#             item            count
# "CVS ALBANY LLC"            "486"
#
# [[13]]$cachedContents$top[[2]]
#                         item                        count
# "DOLGENCORP OF NEW YORK INC"                        "415"
#
# [[13]]$cachedContents$top[[3]]
#                      item                     count
# "WALGREEN EASTERN CO INC"                     "405"
#
# [[13]]$cachedContents$top[[4]]
#                  item                 count
# "STEWARTS SHOPS CORP"                 "345"
#
# [[13]]$cachedContents$top[[5]]
#                     item                    count
# "DOLLAR TREE STORES INC"                    "327"
#
# [[13]]$cachedContents$top[[6]]
#           item          count
# "SPEEDWAY LLC"          "278"
#
# [[13]]$cachedContents$top[[7]]
#                             item                            count
# "FAMILY DOLLAR STORES OF NY INC"                            "254"
#
# [[13]]$cachedContents$top[[8]]
#                       item                      count
# "RITE AID OF NEW YORK INC"                      "172"
#
# [[13]]$cachedContents$top[[9]]
#                           item                          count
# "UNITED REFINING CO OF PA INC"                          "129"
#
# [[13]]$cachedContents$top[[10]]
#               item              count
# "TOPS MARKETS LLC"              "109"
#
# [[13]]$cachedContents$top[[11]]
#       item      count
# "ALDI INC"      "107"
#
# [[13]]$cachedContents$top[[12]]
#           item          count
# "7-ELEVEN INC"          "105"
#
# [[13]]$cachedContents$top[[13]]
#                    item                   count
# "MIRABITO HOLDINGS INC"                   "102"
#
# [[13]]$cachedContents$top[[14]]
#                      item                     count
# "WAL-MART STORES EAST LP"                      "92"
#
# [[13]]$cachedContents$top[[15]]
#                            item                           count
# "A PLUS CONVENIENCE STORES INC"                            "90"
#
# [[13]]$cachedContents$top[[16]]
#                   item                  count
# "CUMBERLAND FARMS INC"                   "81"
#
# [[13]]$cachedContents$top[[17]]
#                             item                            count
# "PRICE CHOPPER OPERATING CO INC"                             "80"
#
# [[13]]$cachedContents$top[[18]]
#          item         count
# "ECKERD CORP"          "75"
#
# [[13]]$cachedContents$top[[19]]
#                               item                              count
# "STOP&SHOP SUPERMARKET CO LLC THE"                               "74"
#
# [[13]]$cachedContents$top[[20]]
#                  item                 count
# "DOLGEN NEW YORK LLC"                  "73"
#
#
# [[13]]$cachedContents$smallest
# [1] "0113 FOOD CORP"
#
# [[13]]$cachedContents$count
# [1] "28472"
#
# [[13]]$cachedContents$cardinality
# [1] "21995"
#
#
# [[13]]$format
#  align
# "left"
#
#
# [[14]]
# [[14]]$id
# [1] 547687025
#
# [[14]]$name
# [1] "DBA Name"
#
# [[14]]$dataTypeName
# [1] "text"
#
# [[14]]$description
# [1] "â\200œDoing business asâ\200\235 (DBA) name for the licensed entity"
#
# [[14]]$fieldName
# [1] "dba_name"
#
# [[14]]$position
# [1] 6
#
# [[14]]$renderTypeName
# [1] "text"
#
# [[14]]$tableColumnId
# [1] 8179651
#
# [[14]]$width
# [1] 196
#
# [[14]]$cachedContents
# [[14]]$cachedContents$non_null
# [1] "28467"
#
# [[14]]$cachedContents$largest
# [1] "ZZ MART"
#
# [[14]]$cachedContents$null
# [1] "5"
#
# [[14]]$cachedContents$top
# [[14]]$cachedContents$top[[1]]
#                  item                 count
# "EDIBLE ARRANGEMENTS"                  "64"
#
# [[14]]$cachedContents$top[[2]]
#     item    count
# "C TOWN"     "48"
#
# [[14]]$cachedContents$top[[3]]
#       item      count
# "KEY FOOD"       "45"
#
# [[14]]$cachedContents$top[[4]]
#         item        count
# "MOBIL MART"         "43"
#
# [[14]]$cachedContents$top[[5]]
#                      item                     count
# "HISSHO SUSHI@STOP&SHOP#"                      "33"
#
# [[14]]$cachedContents$top[[6]]
#  item count
#  "BP"  "32"
#
# [[14]]$cachedContents$top[[7]]
#                    item                   count
# "FINE FARE SUPERMARKET"                    "25"
#
# [[14]]$cachedContents$top[[8]]
#                item               count
# "BRAVO SUPERMARKET"                "24"
#
# [[14]]$cachedContents$top[[9]]
#        item       count
# "FINE FARE"        "24"
#
# [[14]]$cachedContents$top[[10]]
#     item    count
# "SUNOCO"     "23"
#
# [[14]]$cachedContents$top[[11]]
#                item               count
# "IDEAL FOOD BASKET"                "21"
#
# [[14]]$cachedContents$top[[12]]
#                      item                     count
# "AFC SUSHI @ PRICE CHOPP"                      "21"
#
# [[14]]$cachedContents$top[[13]]
#      item     count
# "BP SHOP"      "21"
#
# [[14]]$cachedContents$top[[14]]
#          item         count
# "FOOD BAZAAR"          "20"
#
# [[14]]$cachedContents$top[[15]]
#       item      count
# "FOODTOWN"       "19"
#
# [[14]]$cachedContents$top[[16]]
#                      item                     count
# "DOLLAR GENERAL STORE #1"                      "19"
#
# [[14]]$cachedContents$top[[17]]
#                  item                 count
# "CLIFFS LOCAL MARKET"                  "19"
#
# [[14]]$cachedContents$top[[18]]
#                 item                count
# "WHOLE FOODS MARKET"                 "19"
#
# [[14]]$cachedContents$top[[19]]
#            item           count
# "FOOD UNIVERSE"            "18"
#
# [[14]]$cachedContents$top[[20]]
#              item             count
# "SHELL FOOD MART"              "18"
#
#
# [[14]]$cachedContents$smallest
# [1] "0113 FOOD"
#
# [[14]]$cachedContents$count
# [1] "28472"
#
# [[14]]$cachedContents$cardinality
# [1] "26218"
#
#
# [[14]]$format
#  align
# "left"
#
#
# [[15]]
# [[15]]$id
# [1] 547687026
#
# [[15]]$name
# [1] "Street Number"
#
# [[15]]$dataTypeName
# [1] "text"
#
# [[15]]$description
# [1] "The street number for the physical address of the licensed entity; will be blank if no data is recorded"
#
# [[15]]$fieldName
# [1] "street_number"
#
# [[15]]$position
# [1] 7
#
# [[15]]$renderTypeName
# [1] "text"
#
# [[15]]$tableColumnId
# [1] 8179652
#
# [[15]]$width
# [1] 174
#
# [[15]]$cachedContents
# [[15]]$cachedContents$non_null
# [1] "28280"
#
# [[15]]$cachedContents$largest
# [1] "9A"
#
# [[15]]$cachedContents$null
# [1] "192"
#
# [[15]]$cachedContents$top
# [[15]]$cachedContents$top[[1]]
#  item count
#   "1" "164"
#
# [[15]]$cachedContents$top[[2]]
#  item count
#   "2" "125"
#
# [[15]]$cachedContents$top[[3]]
#  item count
# "100"  "98"
#
# [[15]]$cachedContents$top[[4]]
#  item count
#  "10"  "81"
#
# [[15]]$cachedContents$top[[5]]
#  item count
#  "20"  "74"
#
# [[15]]$cachedContents$top[[6]]
#  item count
#  "50"  "72"
#
# [[15]]$cachedContents$top[[7]]
#  item count
# "200"  "67"
#
# [[15]]$cachedContents$top[[8]]
#  item count
#  "15"  "65"
#
# [[15]]$cachedContents$top[[9]]
#  item count
#  "40"  "63"
#
# [[15]]$cachedContents$top[[10]]
#  item count
#   "5"  "60"
#
# [[15]]$cachedContents$top[[11]]
#  item count
# "500"  "59"
#
# [[15]]$cachedContents$top[[12]]
#  item count
#   "7"  "54"
#
# [[15]]$cachedContents$top[[13]]
#  item count
#   "4"  "54"
#
# [[15]]$cachedContents$top[[14]]
#  item count
# "101"  "54"
#
# [[15]]$cachedContents$top[[15]]
#  item count
#  "16"  "53"
#
# [[15]]$cachedContents$top[[16]]
#  item count
# "300"  "53"
#
# [[15]]$cachedContents$top[[17]]
#  item count
#   "9"  "52"
#
# [[15]]$cachedContents$top[[18]]
#  item count
#   "6"  "51"
#
# [[15]]$cachedContents$top[[19]]
#  item count
#  "19"  "51"
#
# [[15]]$cachedContents$top[[20]]
#  item count
# "120"  "51"
#
#
# [[15]]$cachedContents$smallest
# [1] "1"
#
# [[15]]$cachedContents$count
# [1] "28472"
#
# [[15]]$cachedContents$cardinality
# [1] "8469"
#
#
# [[15]]$format
#    align
# "center"
#
#
# [[16]]
# [[16]]$id
# [1] 547687027
#
# [[16]]$name
# [1] "Street Name"
#
# [[16]]$dataTypeName
# [1] "text"
#
# [[16]]$description
# [1] "The street name for the physical location of the licensed entity; the first address line recorded"
#
# [[16]]$fieldName
# [1] "street_name"
#
# [[16]]$position
# [1] 8
#
# [[16]]$renderTypeName
# [1] "text"
#
# [[16]]$tableColumnId
# [1] 8179653
#
# [[16]]$width
# [1] 232
#
# [[16]]$cachedContents
# [[16]]$cachedContents$non_null
# [1] "28472"
#
# [[16]]$cachedContents$largest
# [1] "ZEREGA AVENUE"
#
# [[16]]$cachedContents$null
# [1] "0"
#
# [[16]]$cachedContents$top
# [[16]]$cachedContents$top[[1]]
#       item      count
# "BROADWAY"      "611"
#
# [[16]]$cachedContents$top[[2]]
#      item     count
# "MAIN ST"     "571"
#
# [[16]]$cachedContents$top[[3]]
#        item       count
# "E MAIN ST"       "166"
#
# [[16]]$cachedContents$top[[4]]
#      item     count
# "3RD AVE"     "164"
#
# [[16]]$cachedContents$top[[5]]
#          item         count
# "JAMAICA AVE"         "162"
#
# [[16]]$cachedContents$top[[6]]
#      item     count
# "5TH AVE"     "144"
#
# [[16]]$cachedContents$top[[7]]
#          item         count
# "MAIN STREET"         "142"
#
# [[16]]$cachedContents$top[[8]]
#           item          count
# "NOSTRAND AVE"          "142"
#
# [[16]]$cachedContents$top[[9]]
#        item       count
# "N MAIN ST"       "128"
#
# [[16]]$cachedContents$top[[10]]
#              item             count
# "WHITE PLAINS RD"             "127"
#
# [[16]]$cachedContents$top[[11]]
#          item         count
# "MONTAUK HWY"         "120"
#
# [[16]]$cachedContents$top[[12]]
#        item       count
# "W MAIN ST"       "120"
#
# [[16]]$cachedContents$top[[13]]
#          item         count
# "CENTRAL AVE"         "114"
#
# [[16]]$cachedContents$top[[14]]
#      item     count
# "8TH AVE"     "109"
#
# [[16]]$cachedContents$top[[15]]
#        item       count
# "FULTON ST"       "108"
#
# [[16]]$cachedContents$top[[16]]
#            item           count
# "NORTHERN BLVD"           "107"
#
# [[16]]$cachedContents$top[[17]]
#         item        count
# "MYRTLE AVE"        "106"
#
# [[16]]$cachedContents$top[[18]]
#         item        count
# "CHURCH AVE"        "101"
#
# [[16]]$cachedContents$top[[19]]
#           item          count
# "FLATBUSH AVE"          "100"
#
# [[16]]$cachedContents$top[[20]]
#           item          count
# "HILLSIDE AVE"          "100"
#
#
# [[16]]$cachedContents$smallest
# [1] "02 ATLANTIC AVE"
#
# [[16]]$cachedContents$count
# [1] "28472"
#
# [[16]]$cachedContents$cardinality
# [1] "8792"
#
#
# [[16]]$format
#  align
# "left"
#
#
# [[17]]
# [[17]]$id
# [1] 547687028
#
# [[17]]$name
# [1] "Address Line 2"
#
# [[17]]$dataTypeName
# [1] "text"
#
# [[17]]$description
# [1] "The second address line recorded for the physical location of the licensed entity; blank if no data is recorded"
#
# [[17]]$fieldName
# [1] "address_line_2"
#
# [[17]]$position
# [1] 9
#
# [[17]]$renderTypeName
# [1] "text"
#
# [[17]]$tableColumnId
# [1] 8179654
#
# [[17]]$width
# [1] 188
#
# [[17]]$cachedContents
#    non_null        null       count cardinality
#         "0"     "28472"     "28472"         "0"
#
# [[17]]$format
#  align
# "left"
#
#
# [[18]]
# [[18]]$id
# [1] 547687029
#
# [[18]]$name
# [1] "Address Line 3"
#
# [[18]]$dataTypeName
# [1] "text"
#
# [[18]]$description
# [1] "The third address line recorded for the physical location of the licensed entity; blank if no data is recorded"
#
# [[18]]$fieldName
# [1] "address_line_3"
#
# [[18]]$position
# [1] 10
#
# [[18]]$renderTypeName
# [1] "text"
#
# [[18]]$tableColumnId
# [1] 8179655
#
# [[18]]$width
# [1] 187
#
# [[18]]$cachedContents
#    non_null        null       count cardinality
#         "0"     "28472"     "28472"         "0"
#
# [[18]]$format
#  align
# "left"
#
#
# [[19]]
# [[19]]$id
# [1] 547687030
#
# [[19]]$name
# [1] "City"
#
# [[19]]$dataTypeName
# [1] "text"
#
# [[19]]$description
# [1] "The name of the city in which the licensed entity is physically located"
#
# [[19]]$fieldName
# [1] "city"
#
# [[19]]$position
# [1] 11
#
# [[19]]$renderTypeName
# [1] "text"
#
# [[19]]$tableColumnId
# [1] 8179656
#
# [[19]]$width
# [1] 148
#
# [[19]]$cachedContents
# [[19]]$cachedContents$non_null
# [1] "28472"
#
# [[19]]$cachedContents$largest
# [1] "YOUNGSVILLE"
#
# [[19]]$cachedContents$null
# [1] "0"
#
# [[19]]$cachedContents$top
# [[19]]$cachedContents$top[[1]]
#       item      count
# "BROOKLYN"     "4877"
#
# [[19]]$cachedContents$top[[2]]
#    item   count
# "BRONX"  "2560"
#
# [[19]]$cachedContents$top[[3]]
#       item      count
# "NEW YORK"     "2478"
#
# [[19]]$cachedContents$top[[4]]
#      item     count
# "BUFFALO"     "697"
#
# [[19]]$cachedContents$top[[5]]
#        item       count
# "ROCHESTER"       "679"
#
# [[19]]$cachedContents$top[[6]]
#            item           count
# "STATEN ISLAND"           "578"
#
# [[19]]$cachedContents$top[[7]]
#       item      count
# "SYRACUSE"      "380"
#
# [[19]]$cachedContents$top[[8]]
#      item     count
# "JAMAICA"     "348"
#
# [[19]]$cachedContents$top[[9]]
#      item     count
# "YONKERS"     "294"
#
# [[19]]$cachedContents$top[[10]]
#     item    count
# "ALBANY"    "279"
#
# [[19]]$cachedContents$top[[11]]
#      item     count
# "ASTORIA"     "245"
#
# [[19]]$cachedContents$top[[12]]
#       item      count
# "FLUSHING"      "222"
#
# [[19]]$cachedContents$top[[13]]
#        item       count
# "RIDGEWOOD"       "196"
#
# [[19]]$cachedContents$top[[14]]
#     item    count
# "CORONA"    "192"
#
# [[19]]$cachedContents$top[[15]]
#          item         count
# "SCHENECTADY"         "181"
#
# [[19]]$cachedContents$top[[16]]
#           item          count
# "POUGHKEEPSIE"          "147"
#
# [[19]]$cachedContents$top[[17]]
#               item              count
# "LONG ISLAND CITY"              "147"
#
# [[19]]$cachedContents$top[[18]]
#              item             count
# "JACKSON HEIGHTS"             "142"
#
# [[19]]$cachedContents$top[[19]]
#    item   count
# "UTICA"   "134"
#
# [[19]]$cachedContents$top[[20]]
#       item      count
# "WOODSIDE"      "126"
#
#
# [[19]]$cachedContents$smallest
# [1] "ACCORD"
#
# [[19]]$cachedContents$count
# [1] "28472"
#
# [[19]]$cachedContents$cardinality
# [1] "1424"
#
#
# [[19]]$format
#  align
# "left"
#
#
# [[20]]
# [[20]]$id
# [1] 547687031
#
# [[20]]$name
# [1] "State"
#
# [[20]]$dataTypeName
# [1] "text"
#
# [[20]]$description
# [1] "The two character state code for the physical location of the licensed entity"
#
# [[20]]$fieldName
# [1] "state"
#
# [[20]]$position
# [1] 12
#
# [[20]]$renderTypeName
# [1] "text"
#
# [[20]]$tableColumnId
# [1] 8179657
#
# [[20]]$width
# [1] 123
#
# [[20]]$cachedContents
# [[20]]$cachedContents$non_null
# [1] "28472"
#
# [[20]]$cachedContents$largest
# [1] "NY"
#
# [[20]]$cachedContents$null
# [1] "0"
#
# [[20]]$cachedContents$top
# [[20]]$cachedContents$top[[1]]
#    item   count
#    "NY" "28472"
#
#
# [[20]]$cachedContents$smallest
# [1] "NY"
#
# [[20]]$cachedContents$count
# [1] "28472"
#
# [[20]]$cachedContents$cardinality
# [1] "1"
#
#
# [[20]]$format
#    align
# "center"
#
#
# [[21]]
# [[21]]$id
# [1] 547687032
#
# [[21]]$name
# [1] "Zip Code"
#
# [[21]]$dataTypeName
# [1] "text"
#
# [[21]]$description
# [1] "The United States Postal Service (USPS) ZIP code for the physical location of the licensed entity"
#
# [[21]]$fieldName
# [1] "zip_code"
#
# [[21]]$position
# [1] 13
#
# [[21]]$renderTypeName
# [1] "text"
#
# [[21]]$tableColumnId
# [1] 8179658
#
# [[21]]$width
# [1] 152
#
# [[21]]$cachedContents
# [[21]]$cachedContents$non_null
# [1] "28472"
#
# [[21]]$cachedContents$largest
# [1] "14905"
#
# [[21]]$cachedContents$null
# [1] "0"
#
# [[21]]$cachedContents$top
# [[21]]$cachedContents$top[[1]]
#    item   count
# "11220"   "235"
#
# [[21]]$cachedContents$top[[2]]
#    item   count
# "11385"   "208"
#
# [[21]]$cachedContents$top[[3]]
#    item   count
# "11226"   "208"
#
# [[21]]$cachedContents$top[[4]]
#    item   count
# "10467"   "200"
#
# [[21]]$cachedContents$top[[5]]
#    item   count
# "11207"   "196"
#
# [[21]]$cachedContents$top[[6]]
#    item   count
# "11211"   "196"
#
# [[21]]$cachedContents$top[[7]]
#    item   count
# "11368"   "192"
#
# [[21]]$cachedContents$top[[8]]
#    item   count
# "11208"   "189"
#
# [[21]]$cachedContents$top[[9]]
#    item   count
# "11212"   "185"
#
# [[21]]$cachedContents$top[[10]]
#    item   count
# "10002"   "181"
#
# [[21]]$cachedContents$top[[11]]
#    item   count
# "11221"   "180"
#
# [[21]]$cachedContents$top[[12]]
#    item   count
# "10456"   "178"
#
# [[21]]$cachedContents$top[[13]]
#    item   count
# "10029"   "177"
#
# [[21]]$cachedContents$top[[14]]
#    item   count
# "10458"   "177"
#
# [[21]]$cachedContents$top[[15]]
#    item   count
# "11206"   "175"
#
# [[21]]$cachedContents$top[[16]]
#    item   count
# "11223"   "171"
#
# [[21]]$cachedContents$top[[17]]
#    item   count
# "11219"   "171"
#
# [[21]]$cachedContents$top[[18]]
#    item   count
# "11214"   "166"
#
# [[21]]$cachedContents$top[[19]]
#    item   count
# "10452"   "159"
#
# [[21]]$cachedContents$top[[20]]
#    item   count
# "11235"   "152"
#
#
# [[21]]$cachedContents$smallest
# [1] "06390"
#
# [[21]]$cachedContents$count
# [1] "28472"
#
# [[21]]$cachedContents$cardinality
# [1] "1538"
#
#
# [[21]]$format
#    align
# "center"
#
#
# [[22]]
# [[22]]$id
# [1] 547687033
#
# [[22]]$name
# [1] "Square Footage"
#
# [[22]]$dataTypeName
# [1] "number"
#
# [[22]]$description
# [1] "The square footage of the entire physical location of the licensed entity"
#
# [[22]]$fieldName
# [1] "square_footage"
#
# [[22]]$position
# [1] 14
#
# [[22]]$renderTypeName
# [1] "number"
#
# [[22]]$tableColumnId
# [1] 21635506
#
# [[22]]$width
# [1] 184
#
# [[22]]$cachedContents
# [[22]]$cachedContents$non_null
# [1] "28472"
#
# [[22]]$cachedContents$largest
# [1] "850000"
#
# [[22]]$cachedContents$null
# [1] "0"
#
# [[22]]$cachedContents$top
# [[22]]$cachedContents$top[[1]]
#   item  count
#    "0" "5162"
#
# [[22]]$cachedContents$top[[2]]
#   item  count
# "1000" "2556"
#
# [[22]]$cachedContents$top[[3]]
#   item  count
# "1500" "2008"
#
# [[22]]$cachedContents$top[[4]]
#   item  count
# "2000" "1918"
#
# [[22]]$cachedContents$top[[5]]
#   item  count
# "1200" "1704"
#
# [[22]]$cachedContents$top[[6]]
#   item  count
# "3000"  "940"
#
# [[22]]$cachedContents$top[[7]]
#  item count
# "800" "919"
#
# [[22]]$cachedContents$top[[8]]
#   item  count
# "2500"  "799"
#
# [[22]]$cachedContents$top[[9]]
#   item  count
# "1800"  "708"
#
# [[22]]$cachedContents$top[[10]]
#   item  count
# "5000"  "579"
#
# [[22]]$cachedContents$top[[11]]
#  item count
# "500" "564"
#
# [[22]]$cachedContents$top[[12]]
#    item   count
# "10000"   "505"
#
# [[22]]$cachedContents$top[[13]]
#   item  count
# "4000"  "501"
#
# [[22]]$cachedContents$top[[14]]
#  item count
# "900" "426"
#
# [[22]]$cachedContents$top[[15]]
#  item count
# "600" "388"
#
# [[22]]$cachedContents$top[[16]]
#   item  count
# "1600"  "368"
#
# [[22]]$cachedContents$top[[17]]
#   item  count
# "8000"  "327"
#
# [[22]]$cachedContents$top[[18]]
#   item  count
# "1400"  "288"
#
# [[22]]$cachedContents$top[[19]]
#   item  count
# "1100"  "287"
#
# [[22]]$cachedContents$top[[20]]
#   item  count
# "6000"  "279"
#
#
# [[22]]$cachedContents$smallest
# [1] "0"
#
# [[22]]$cachedContents$count
# [1] "28472"
#
# [[22]]$cachedContents$cardinality
# [1] "874"
#
#
# [[22]]$format
# precisionStyle          align
#     "standard"        "right"
#
#
# [[23]]
# [[23]]$id
# [1] 547687034
#
# [[23]]$name
# [1] "Georeference"
#
# [[23]]$dataTypeName
# [1] "point"
#
# [[23]]$description
# [1] ""
#
# [[23]]$fieldName
# [1] "georeference"
#
# [[23]]$position
# [1] 15
#
# [[23]]$renderTypeName
# [1] "point"
#
# [[23]]$tableColumnId
# [1] 139258330
#
# [[23]]$cachedContents
# [[23]]$cachedContents$non_null
# [1] "27352"
#
# [[23]]$cachedContents$null
# [1] "1120"
#
# [[23]]$cachedContents$top
# [[23]]$cachedContents$top[[1]]
# [[23]]$cachedContents$top[[1]]$item
# [[23]]$cachedContents$top[[1]]$item$coordinates
# [1] -72.78654  40.92813
#
# [[23]]$cachedContents$top[[1]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[1]]$count
# [1] "19"
#
#
# [[23]]$cachedContents$top[[2]]
# [[23]]$cachedContents$top[[2]]$item
# [[23]]$cachedContents$top[[2]]$item$coordinates
# [1] -73.92578  40.75333
#
# [[23]]$cachedContents$top[[2]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[2]]$count
# [1] "19"
#
#
# [[23]]$cachedContents$top[[3]]
# [[23]]$cachedContents$top[[3]]$item
# [[23]]$cachedContents$top[[3]]$item$coordinates
# [1] -73.94821  40.70000
#
# [[23]]$cachedContents$top[[3]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[3]]$count
# [1] "16"
#
#
# [[23]]$cachedContents$top[[4]]
# [[23]]$cachedContents$top[[4]]$item
# [[23]]$cachedContents$top[[4]]$item$coordinates
# [1] -77.59074  43.16605
#
# [[23]]$cachedContents$top[[4]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[4]]$count
# [1] "13"
#
#
# [[23]]$cachedContents$top[[5]]
# [[23]]$cachedContents$top[[5]]$item
# [[23]]$cachedContents$top[[5]]$item$coordinates
# [1] -78.83781  42.89331
#
# [[23]]$cachedContents$top[[5]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[5]]$count
# [1] "12"
#
#
# [[23]]$cachedContents$top[[6]]
# [[23]]$cachedContents$top[[6]]$item
# [[23]]$cachedContents$top[[6]]$item$coordinates
# [1] -73.94526  40.79681
#
# [[23]]$cachedContents$top[[6]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[6]]$count
# [1] "12"
#
#
# [[23]]$cachedContents$top[[7]]
# [[23]]$cachedContents$top[[7]]$item
# [[23]]$cachedContents$top[[7]]$item$coordinates
# [1] -73.98837  40.71823
#
# [[23]]$cachedContents$top[[7]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[7]]$count
# [1] "11"
#
#
# [[23]]$cachedContents$top[[8]]
# [[23]]$cachedContents$top[[8]]$item
# [[23]]$cachedContents$top[[8]]$item$coordinates
# [1] -73.91898  40.83663
#
# [[23]]$cachedContents$top[[8]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[8]]$count
# [1] "10"
#
#
# [[23]]$cachedContents$top[[9]]
# [[23]]$cachedContents$top[[9]]$item
# [[23]]$cachedContents$top[[9]]$item$coordinates
# [1] -73.98899  40.73197
#
# [[23]]$cachedContents$top[[9]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[9]]$count
# [1] "9"
#
#
# [[23]]$cachedContents$top[[10]]
# [[23]]$cachedContents$top[[10]]$item
# [[23]]$cachedContents$top[[10]]$item$coordinates
# [1] -74.00756  40.65713
#
# [[23]]$cachedContents$top[[10]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[10]]$count
# [1] "9"
#
#
# [[23]]$cachedContents$top[[11]]
# [[23]]$cachedContents$top[[11]]$item
# [[23]]$cachedContents$top[[11]]$item$coordinates
# [1] -73.6130  40.7385
#
# [[23]]$cachedContents$top[[11]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[11]]$count
# [1] "9"
#
#
# [[23]]$cachedContents$top[[12]]
# [[23]]$cachedContents$top[[12]]$item
# [[23]]$cachedContents$top[[12]]$item$coordinates
# [1] -73.99056  40.75618
#
# [[23]]$cachedContents$top[[12]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[12]]$count
# [1] "8"
#
#
# [[23]]$cachedContents$top[[13]]
# [[23]]$cachedContents$top[[13]]$item
# [[23]]$cachedContents$top[[13]]$item$coordinates
# [1] -75.77710  42.91721
#
# [[23]]$cachedContents$top[[13]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[13]]$count
# [1] "8"
#
#
# [[23]]$cachedContents$top[[14]]
# [[23]]$cachedContents$top[[14]]$item
# [[23]]$cachedContents$top[[14]]$item$coordinates
# [1] -73.98347  40.69074
#
# [[23]]$cachedContents$top[[14]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[14]]$count
# [1] "7"
#
#
# [[23]]$cachedContents$top[[15]]
# [[23]]$cachedContents$top[[15]]$item
# [[23]]$cachedContents$top[[15]]$item$coordinates
# [1] -74.07026  41.15617
#
# [[23]]$cachedContents$top[[15]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[15]]$count
# [1] "7"
#
#
# [[23]]$cachedContents$top[[16]]
# [[23]]$cachedContents$top[[16]]$item
# [[23]]$cachedContents$top[[16]]$item$coordinates
# [1] -74.00447  40.74223
#
# [[23]]$cachedContents$top[[16]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[16]]$count
# [1] "7"
#
#
# [[23]]$cachedContents$top[[17]]
# [[23]]$cachedContents$top[[17]]$item
# [[23]]$cachedContents$top[[17]]$item$coordinates
# [1] -73.95671  40.64276
#
# [[23]]$cachedContents$top[[17]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[17]]$count
# [1] "7"
#
#
# [[23]]$cachedContents$top[[18]]
# [[23]]$cachedContents$top[[18]]$item
# [[23]]$cachedContents$top[[18]]$item$coordinates
# [1] -73.81332  40.76515
#
# [[23]]$cachedContents$top[[18]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[18]]$count
# [1] "6"
#
#
# [[23]]$cachedContents$top[[19]]
# [[23]]$cachedContents$top[[19]]$item
# [[23]]$cachedContents$top[[19]]$item$coordinates
# [1] -74.07462  41.09246
#
# [[23]]$cachedContents$top[[19]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[19]]$count
# [1] "6"
#
#
# [[23]]$cachedContents$top[[20]]
# [[23]]$cachedContents$top[[20]]$item
# [[23]]$cachedContents$top[[20]]$item$coordinates
# [1] -77.61324  43.08723
#
# [[23]]$cachedContents$top[[20]]$item$type
# [1] "Point"
#
#
# [[23]]$cachedContents$top[[20]]$count
# [1] "6"
#
#
#
# [[23]]$cachedContents$count
# [1] "28472"
#
# [[23]]$cachedContents$cardinality
# [1] "25694"
#
#
# [[23]]$format
# named list()
#
#
# [[24]]
# [[24]]$id
# [1] 547687035
#
# [[24]]$name
# [1] "NYS Municipal Boundaries"
#
# [[24]]$dataTypeName
# [1] "number"
#
# [[24]]$description
# [1] "This column was automatically created in order to record in what polygon from the dataset 'NYS Municipal Boundaries' (yamh-8v7k) the point in column 'georeference' is located.  This enables the creation of region maps (choropleths) in the visualization canvas and data lens."
#
# [[24]]$fieldName
# [1] ":@computed_region_yamh_8v7k"
#
# [[24]]$position
# [1] 22
#
# [[24]]$renderTypeName
# [1] "number"
#
# [[24]]$tableColumnId
# [1] 139258331
#
# [[24]]$computationStrategy
# [[24]]$computationStrategy$source_columns
# [1] "georeference"
#
# [[24]]$computationStrategy$type
# [1] "georegion_match_on_point"
#
# [[24]]$computationStrategy$parameters
#        region   primary_key
#  "_yamh-8v7k" "_feature_id"
#
#
# [[24]]$format
# named list()

# %%
# extract names for geo and non-geo
getNames<-function(x){
  if(is.null(columns[[x]]$subColumnTypes)){
    return(columns[[x]]$name)
  }else{
    return(columns[[x]]$subColumnTypes)
  }
}

fmNames<-unlist(sapply(1:length(columns), getNames))

# %%
names(fmDataDF)<-fmNames
head(fmDataDF)
# Out:
# Error in names(fmDataDF) <- fmNames: 'names' attribute [24] must be the same length as the vector [22]
# Traceback:

# %%
# long lat
fmDataDF$latitude<-as.numeric(fmDataDF$latitude)
fmDataDF$longitude<-as.numeric(fmDataDF$longitude)

# %%
#Install gdata if you have not already done so. 
#install.packages("rgdal")

# %%
# visualization

library(rgdal)
library(ggplot2)
state<-readOGR("X:/administrative/social_media/blogposts/json_from_R", layer="nys")
## OGR data source with driver: ESRI Shapefile 
## Source: "X:/administrative/social_media/blogposts/json_from_R", layer: "nys"
## with 1 features and 53 fields
## Feature type: wkbMultiPolygon with 2 dimensions
