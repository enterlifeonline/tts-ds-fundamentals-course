# %% [markdown]
# Data Science Fundamentals: R |
# [Table of Contents](../index.ipynb)
# - - -
# <!--NAVIGATION-->
# Module 16. [Exploratory Data Analysis Using Models](./00.ipynb) | [Model Basics](./01.ipynb) | [Model Building](./02.ipynb) | [Exercises](./03.ipynb)

# %% [markdown]
# # Model Building with R

# %% [markdown]
# ![images](images/slides15.png)

# %% [markdown]
# ## Diamond Dataset

# %%
install.packages("hexbin")
# Out:
# The downloaded binary packages are in
# 	/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T//RtmpPmNFju/downloaded_packages

# %%
library(tidyverse)
library(modelr)
options(na.action = na.warn)

# %%
library(nycflights13)
library(hexbin)
library(lubridate)

# %% [markdown]
# It looks like lower quality diamonds have higher prices because there is an important confounding variable: the weight (carat) of the diamond. The weight of the diamond is the single most important factor for determining the price of the diamond, and lower quality diamonds tend to be larger.

# %%
ggplot(diamonds, aes(carat, price)) + 
  geom_hex(bins = 50)
# Out:
# plot without title

# %% [markdown]
# ### Why are lower quality diamonds more expensive?

# %% [markdown]
# a surprising relationship between the quality of diamonds and their price: low quality diamonds (poor cuts, bad colours, and inferior clarity) have higher prices.

# %%
ggplot(diamonds, aes(cut, price)) + geom_boxplot()
# Out:
# plot without title

# %%
ggplot(diamonds, aes(color, price)) + geom_boxplot()
# Out:
# plot without title

# %%
ggplot(diamonds, aes(clarity, price)) + geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# Remember that diamond color goes from J (worst) to D (best).

# %% [markdown]
# ## Patterns and Models

# %% [markdown]
# It is hard to understand the relationship between cut and price.  Use a model to remove the very strong relationship between price and carat.

# %%
# fit a model
mod <- lm(log(price) ~ log(carat), data = diamonds)
# plot the predictions
diamonds.mod <- diamonds %>% add_predictions(mod) %>%
  mutate(pred=exp(pred), resid=price-pred)

# %%
ggplot(diamonds.mod) + geom_point(aes(x=carat, y=pred))
# Out:
# plot without title

# %% [markdown]
# ## Residuals

# %% [markdown]
# Residuals are the differences between the true and predicted price.

# %%
ggplot(diamonds.mod) + geom_point(aes(x=carat, y=resid), alpha=0.2)
# Out:
# plot without title

# %% [markdown]
# This model seems to overestimate the price of large diamonds.

# %% [markdown]
# ## Using Residuals

# %% [markdown]
# Once you've removed the strong relationship between carat and price, you can see what you expect in the relationship between cut and price:  relative to their size, better quality diamonds are more expensive.

# %%
ggplot(diamonds) + 
  geom_boxplot(aes(x=cut, y=price))
# Out:
# plot without title

# %%
ggplot(diamonds.mod) +
  geom_boxplot(aes(x=cut, y=resid))
# Out:
# plot without title

# %% [markdown]
# ## Price and Carat

# %% [markdown]
# Focus on diamonds smaller than 2.5 carats (99.7% of the data).

# %% [markdown]
# ### A More Complicated Model

# %%
mod_diamond2 <- lm(lprice ~ lcarat + color + cut + clarity, data = diamonds2)

# %% [markdown]
# This model now includes four predictors, so it's getting harder to visualize.  Since there are no interaction terms: plot them individually in four plots.   For example, we can plot the effect of "cut" with others fixed.

# %%
grid <- diamonds2 %>% 
  data_grid(cut, .model = mod_diamond2) %>% 
  add_predictions(mod_diamond2)
grid
# Out:
#   cut       lcarat     color clarity pred
# 1 Fair      -0.5145732 G     VS2     11.20557
# 2 Good      -0.5145732 G     VS2     11.32050
# 3 Very Good -0.5145732 G     VS2     11.37396
# 4 Premium   -0.5145732 G     VS2     11.40627
# 5 Ideal     -0.5145732 G     VS2     11.43759

# %%
ggplot(grid, aes(color, pred)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# For the effect of color, we used:

# %%
grid <- diamonds2 %>% 
  data_grid(color, lcarat = 0, cut = "Good", clarity = "SI1") %>% 
  add_predictions(mod_diamond2)
ggplot(grid, aes(color, pred)) + geom_point()
# Out:
# plot without title

# %%
ggplot(grid, aes(cut, pred)) + 
  geom_point()
# Out:
# plot without title

# %%
diamonds.mod <- diamonds2 %>% add_residuals(mod_diamond, "lresid")
ggplot(diamonds.mod) + geom_point(aes(x=lcarat, y=lresid), alpha=0.05)
# Out:
# plot without title

# %% [markdown]
# Now we see no obvious trend in the residuals.  However, some diamonds have quite large residuals.

# %%
diamonds2 <- diamonds2 %>% 
  add_residuals(mod_diamond2, "lresid2")

ggplot(diamonds2, aes(lcarat, lresid2)) + 
  geom_hex(bins = 50)
# Out:
# plot without title

# %%
# log-transform carat and price, then fit linear model
diamonds2 <- diamonds %>% filter(carat <= 2.5) %>%
  mutate(lprice = log2(price), lcarat = log2(carat))
mod_diamond <- lm(lprice ~ lcarat, data = diamonds2)
diamonds.mod <- diamonds2 %>%
  add_predictions(mod_diamond, "lprice.pred") %>%
  add_residuals(mod_diamond, "lprice.resid")

# %%
p1 <- ggplot(diamonds.mod, aes(cut, lprice.resid)) + geom_boxplot()
p2 <- ggplot(diamonds.mod, aes(color, lprice.resid)) + geom_boxplot()

# %%
p1
# Out:
# plot without title

# %%
p2
# Out:
# plot without title

# %% [markdown]
# Now we see the relationship we expect: as the quality of the diamond increases, so too does its relative price. The same thing can be observed with "clarity".

# %% [markdown]
# - - -
# ## Hands-On Exercises

# %%
library(tidyverse)

# %%
library(nycflights13)

# %%
library(lubridate)

# %%
flights
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
# 11     2013 1     1   558      600            -2         849      851
# 12     2013 1     1   558      600            -2         853      856
# 13     2013 1     1   558      600            -2         924      917
# 14     2013 1     1   558      600            -2         923      937
# 15     2013 1     1   559      600            -1         941      910
# 16     2013 1     1   559      559             0         702      706
# 17     2013 1     1   559      600            -1         854      902
# 18     2013 1     1   600      600             0         851      858
# 19     2013 1     1   600      600             0         837      825
# 20     2013 1     1   601      600             1         844      850
# 21     2013 1     1   602      610            -8         812      820
# 22     2013 1     1   602      605            -3         821      805
# 23     2013 1     1   606      610            -4         858      910
# 24     2013 1     1   606      610            -4         837      845
# 25     2013 1     1   607      607             0         858      915
# 26     2013 1     1   608      600             8         807      735
# 27     2013 1     1   611      600            11         945      931
# 28     2013 1     1   613      610             3         925      921
# 29     2013 1     1   615      615             0        1039     1100
# 30     2013 1     1   615      615             0         833      842
# ⋮      ⋮    ⋮     ⋮   ⋮        ⋮              ⋮         ⋮        ⋮
# 336747 2013 9     30  2123     2125            -2       2223     2247
# 336748 2013 9     30  2127     2129            -2       2314     2323
# 336749 2013 9     30  2128     2130            -2       2328     2359
# 336750 2013 9     30  2129     2059            30       2230     2232
# 336751 2013 9     30  2131     2140            -9       2225     2255
# 336752 2013 9     30  2140     2140             0         10       40
# 336753 2013 9     30  2142     2129            13       2250     2239
# 336754 2013 9     30  2145     2145             0        115      140
# 336755 2013 9     30  2147     2137            10         30       27
# 336756 2013 9     30  2149     2156            -7       2245     2308
# 336757 2013 9     30  2150     2159            -9       2250     2306
# 336758 2013 9     30  2159     1845           194       2344     2030
# 336759 2013 9     30  2203     2205            -2       2339     2331
# 336760 2013 9     30  2207     2140            27       2257     2250
# 336761 2013 9     30  2211     2059            72       2339     2242
# 336762 2013 9     30  2231     2245           -14       2335     2356
# 336763 2013 9     30  2233     2113            80        112       30
# 336764 2013 9     30  2235     2001           154         59     2249
# 336765 2013 9     30  2237     2245            -8       2345     2353
# 336766 2013 9     30  2240     2245            -5       2334     2351
# 336767 2013 9     30  2240     2250           -10       2347        7
# 336768 2013 9     30  2241     2246            -5       2345        1
# 336769 2013 9     30  2307     2255            12       2359     2358
# 336770 2013 9     30  2349     2359           -10        325      350
# 336771 2013 9     30    NA     1842            NA         NA     2019
# 336772 2013 9     30    NA     1455            NA         NA     1634
# 336773 2013 9     30    NA     2200            NA         NA     2312
# 336774 2013 9     30    NA     1210            NA         NA     1330
# 336775 2013 9     30    NA     1159            NA         NA     1344
# 336776 2013 9     30    NA      840            NA         NA     1020
#        arr_delay carrier flight tailnum origin dest air_time distance hour
# 1       11       UA      1545   N14228  EWR    IAH  227      1400     5
# 2       20       UA      1714   N24211  LGA    IAH  227      1416     5
# 3       33       AA      1141   N619AA  JFK    MIA  160      1089     5
# 4      -18       B6       725   N804JB  JFK    BQN  183      1576     5
# 5      -25       DL       461   N668DN  LGA    ATL  116       762     6
# 6       12       UA      1696   N39463  EWR    ORD  150       719     5
# 7       19       B6       507   N516JB  EWR    FLL  158      1065     6
# 8      -14       EV      5708   N829AS  LGA    IAD   53       229     6
# 9       -8       B6        79   N593JB  JFK    MCO  140       944     6
# 10       8       AA       301   N3ALAA  LGA    ORD  138       733     6
# 11      -2       B6        49   N793JB  JFK    PBI  149      1028     6
# 12      -3       B6        71   N657JB  JFK    TPA  158      1005     6
# 13       7       UA       194   N29129  JFK    LAX  345      2475     6
# 14     -14       UA      1124   N53441  EWR    SFO  361      2565     6
# 15      31       AA       707   N3DUAA  LGA    DFW  257      1389     6
# 16      -4       B6      1806   N708JB  JFK    BOS   44       187     5
# 17      -8       UA      1187   N76515  EWR    LAS  337      2227     6
# 18      -7       B6       371   N595JB  LGA    FLL  152      1076     6
# 19      12       MQ      4650   N542MQ  LGA    ATL  134       762     6
# 20      -6       B6       343   N644JB  EWR    PBI  147      1023     6
# 21      -8       DL      1919   N971DL  LGA    MSP  170      1020     6
# 22      16       MQ      4401   N730MQ  LGA    DTW  105       502     6
# 23     -12       AA      1895   N633AA  EWR    MIA  152      1085     6
# 24      -8       DL      1743   N3739P  JFK    ATL  128       760     6
# 25     -17       UA      1077   N53442  EWR    MIA  157      1085     6
# 26      32       MQ      3768   N9EAMQ  EWR    ORD  139       719     6
# 27      14       UA       303   N532UA  JFK    SFO  366      2586     6
# 28       4       B6       135   N635JB  JFK    RSW  175      1074     6
# 29     -21       B6       709   N794JB  JFK    SJU  182      1598     6
# 30      -9       DL       575   N326NB  EWR    ATL  120       746     6
# ⋮      ⋮         ⋮       ⋮      ⋮       ⋮      ⋮    ⋮        ⋮        ⋮
# 336747 -24       EV      5489   N712EV  LGA    CHO   45       305     21
# 336748  -9       EV      3833   N16546  EWR    CLT   72       529     21
# 336749 -31       B6        97   N807JB  JFK    DEN  213      1626     21
# 336750  -2       EV      5048   N751EV  LGA    RIC   45       292     20
# 336751 -30       MQ      3621   N807MQ  JFK    DCA   36       213     21
# 336752 -30       AA       185   N335AA  JFK    LAX  298      2475     21
# 336753  11       EV      4509   N12957  EWR    PWM   47       284     21
# 336754 -25       B6      1103   N633JB  JFK    SJU  192      1598     21
# 336755   3       B6      1371   N627JB  LGA    FLL  139      1076     21
# 336756 -23       UA       523   N813UA  EWR    BOS   37       200     21
# 336757 -16       EV      3842   N10575  EWR    MHT   39       209     21
# 336758 194       9E      3320   N906XJ  JFK    BUF   50       301     18
# 336759   8       EV      5311   N722EV  LGA    BGR   61       378     22
# 336760   7       MQ      3660   N532MQ  LGA    BNA   97       764     21
# 336761  57       EV      4672   N12145  EWR    STL  120       872     20
# 336762 -21       B6       108   N193JB  JFK    PWM   48       273     22
# 336763  42       UA       471   N578UA  EWR    SFO  318      2565     21
# 336764 130       B6      1083   N804JB  JFK    MCO  123       944     20
# 336765  -8       B6       234   N318JB  JFK    BTV   43       266     22
# 336766 -17       B6      1816   N354JB  JFK    SYR   41       209     22
# 336767 -20       B6      2002   N281JB  JFK    BUF   52       301     22
# 336768 -16       B6       486   N346JB  JFK    ROC   47       264     22
# 336769   1       B6       718   N565JB  JFK    BOS   33       187     22
# 336770 -25       B6       745   N516JB  JFK    PSE  196      1617     23
# 336771  NA       EV      5274   N740EV  LGA    BNA   NA       764     18
# 336772  NA       9E      3393   NA      JFK    DCA   NA       213     14
# 336773  NA       9E      3525   NA      LGA    SYR   NA       198     22
# 336774  NA       MQ      3461   N535MQ  LGA    BNA   NA       764     12
# 336775  NA       MQ      3572   N511MQ  LGA    CLE   NA       419     11
# 336776  NA       MQ      3531   N839MQ  LGA    RDU   NA       431      8
#        minute time_hour
# 1      15     2013-01-01 05:00:00
# 2      29     2013-01-01 05:00:00
# 3      40     2013-01-01 05:00:00
# 4      45     2013-01-01 05:00:00
# 5       0     2013-01-01 06:00:00
# 6      58     2013-01-01 05:00:00
# 7       0     2013-01-01 06:00:00
# 8       0     2013-01-01 06:00:00
# 9       0     2013-01-01 06:00:00
# 10      0     2013-01-01 06:00:00
# 11      0     2013-01-01 06:00:00
# 12      0     2013-01-01 06:00:00
# 13      0     2013-01-01 06:00:00
# 14      0     2013-01-01 06:00:00
# 15      0     2013-01-01 06:00:00
# 16     59     2013-01-01 05:00:00
# 17      0     2013-01-01 06:00:00
# 18      0     2013-01-01 06:00:00
# 19      0     2013-01-01 06:00:00
# 20      0     2013-01-01 06:00:00
# 21     10     2013-01-01 06:00:00
# 22      5     2013-01-01 06:00:00
# 23     10     2013-01-01 06:00:00
# 24     10     2013-01-01 06:00:00
# 25      7     2013-01-01 06:00:00
# 26      0     2013-01-01 06:00:00
# 27      0     2013-01-01 06:00:00
# 28     10     2013-01-01 06:00:00
# 29     15     2013-01-01 06:00:00
# 30     15     2013-01-01 06:00:00
# ⋮      ⋮      ⋮
# 336747 25     2013-09-30 21:00:00
# 336748 29     2013-09-30 21:00:00
# 336749 30     2013-09-30 21:00:00
# 336750 59     2013-09-30 20:00:00
# 336751 40     2013-09-30 21:00:00
# 336752 40     2013-09-30 21:00:00
# 336753 29     2013-09-30 21:00:00
# 336754 45     2013-09-30 21:00:00
# 336755 37     2013-09-30 21:00:00
# 336756 56     2013-09-30 21:00:00
# 336757 59     2013-09-30 21:00:00
# 336758 45     2013-09-30 18:00:00
# 336759  5     2013-09-30 22:00:00
# 336760 40     2013-09-30 21:00:00
# 336761 59     2013-09-30 20:00:00
# 336762 45     2013-09-30 22:00:00
# 336763 13     2013-09-30 21:00:00
# 336764  1     2013-09-30 20:00:00
# 336765 45     2013-09-30 22:00:00
# 336766 45     2013-09-30 22:00:00
# 336767 50     2013-09-30 22:00:00
# 336768 46     2013-09-30 22:00:00
# 336769 55     2013-09-30 22:00:00
# 336770 59     2013-09-30 23:00:00
# 336771 42     2013-09-30 18:00:00
# 336772 55     2013-09-30 14:00:00
# 336773  0     2013-09-30 22:00:00
# 336774 10     2013-09-30 12:00:00
# 336775 59     2013-09-30 11:00:00
# 336776 40     2013-09-30 08:00:00

# %% [markdown]
# ### What affects the number of daily flights?

# %% [markdown]
# Create a new date variable.

# %%
daily <- flights %>%
  mutate(date = make_date(year, month, day))
daily %>% select(date, everything())
# Out:
#        date       year month day dep_time sched_dep_time dep_delay arr_time
# 1      2013-01-01 2013 1     1   517      515             2         830
# 2      2013-01-01 2013 1     1   533      529             4         850
# 3      2013-01-01 2013 1     1   542      540             2         923
# 4      2013-01-01 2013 1     1   544      545            -1        1004
# 5      2013-01-01 2013 1     1   554      600            -6         812
# 6      2013-01-01 2013 1     1   554      558            -4         740
# 7      2013-01-01 2013 1     1   555      600            -5         913
# 8      2013-01-01 2013 1     1   557      600            -3         709
# 9      2013-01-01 2013 1     1   557      600            -3         838
# 10     2013-01-01 2013 1     1   558      600            -2         753
# 11     2013-01-01 2013 1     1   558      600            -2         849
# 12     2013-01-01 2013 1     1   558      600            -2         853
# 13     2013-01-01 2013 1     1   558      600            -2         924
# 14     2013-01-01 2013 1     1   558      600            -2         923
# 15     2013-01-01 2013 1     1   559      600            -1         941
# 16     2013-01-01 2013 1     1   559      559             0         702
# 17     2013-01-01 2013 1     1   559      600            -1         854
# 18     2013-01-01 2013 1     1   600      600             0         851
# 19     2013-01-01 2013 1     1   600      600             0         837
# 20     2013-01-01 2013 1     1   601      600             1         844
# 21     2013-01-01 2013 1     1   602      610            -8         812
# 22     2013-01-01 2013 1     1   602      605            -3         821
# 23     2013-01-01 2013 1     1   606      610            -4         858
# 24     2013-01-01 2013 1     1   606      610            -4         837
# 25     2013-01-01 2013 1     1   607      607             0         858
# 26     2013-01-01 2013 1     1   608      600             8         807
# 27     2013-01-01 2013 1     1   611      600            11         945
# 28     2013-01-01 2013 1     1   613      610             3         925
# 29     2013-01-01 2013 1     1   615      615             0        1039
# 30     2013-01-01 2013 1     1   615      615             0         833
# ⋮      ⋮          ⋮    ⋮     ⋮   ⋮        ⋮              ⋮         ⋮
# 336747 2013-09-30 2013 9     30  2123     2125            -2       2223
# 336748 2013-09-30 2013 9     30  2127     2129            -2       2314
# 336749 2013-09-30 2013 9     30  2128     2130            -2       2328
# 336750 2013-09-30 2013 9     30  2129     2059            30       2230
# 336751 2013-09-30 2013 9     30  2131     2140            -9       2225
# 336752 2013-09-30 2013 9     30  2140     2140             0         10
# 336753 2013-09-30 2013 9     30  2142     2129            13       2250
# 336754 2013-09-30 2013 9     30  2145     2145             0        115
# 336755 2013-09-30 2013 9     30  2147     2137            10         30
# 336756 2013-09-30 2013 9     30  2149     2156            -7       2245
# 336757 2013-09-30 2013 9     30  2150     2159            -9       2250
# 336758 2013-09-30 2013 9     30  2159     1845           194       2344
# 336759 2013-09-30 2013 9     30  2203     2205            -2       2339
# 336760 2013-09-30 2013 9     30  2207     2140            27       2257
# 336761 2013-09-30 2013 9     30  2211     2059            72       2339
# 336762 2013-09-30 2013 9     30  2231     2245           -14       2335
# 336763 2013-09-30 2013 9     30  2233     2113            80        112
# 336764 2013-09-30 2013 9     30  2235     2001           154         59
# 336765 2013-09-30 2013 9     30  2237     2245            -8       2345
# 336766 2013-09-30 2013 9     30  2240     2245            -5       2334
# 336767 2013-09-30 2013 9     30  2240     2250           -10       2347
# 336768 2013-09-30 2013 9     30  2241     2246            -5       2345
# 336769 2013-09-30 2013 9     30  2307     2255            12       2359
# 336770 2013-09-30 2013 9     30  2349     2359           -10        325
# 336771 2013-09-30 2013 9     30    NA     1842            NA         NA
# 336772 2013-09-30 2013 9     30    NA     1455            NA         NA
# 336773 2013-09-30 2013 9     30    NA     2200            NA         NA
# 336774 2013-09-30 2013 9     30    NA     1210            NA         NA
# 336775 2013-09-30 2013 9     30    NA     1159            NA         NA
# 336776 2013-09-30 2013 9     30    NA      840            NA         NA
#        sched_arr_time arr_delay carrier flight tailnum origin dest air_time
# 1       819            11       UA      1545   N14228  EWR    IAH  227
# 2       830            20       UA      1714   N24211  LGA    IAH  227
# 3       850            33       AA      1141   N619AA  JFK    MIA  160
# 4      1022           -18       B6       725   N804JB  JFK    BQN  183
# 5       837           -25       DL       461   N668DN  LGA    ATL  116
# 6       728            12       UA      1696   N39463  EWR    ORD  150
# 7       854            19       B6       507   N516JB  EWR    FLL  158
# 8       723           -14       EV      5708   N829AS  LGA    IAD   53
# 9       846            -8       B6        79   N593JB  JFK    MCO  140
# 10      745             8       AA       301   N3ALAA  LGA    ORD  138
# 11      851            -2       B6        49   N793JB  JFK    PBI  149
# 12      856            -3       B6        71   N657JB  JFK    TPA  158
# 13      917             7       UA       194   N29129  JFK    LAX  345
# 14      937           -14       UA      1124   N53441  EWR    SFO  361
# 15      910            31       AA       707   N3DUAA  LGA    DFW  257
# 16      706            -4       B6      1806   N708JB  JFK    BOS   44
# 17      902            -8       UA      1187   N76515  EWR    LAS  337
# 18      858            -7       B6       371   N595JB  LGA    FLL  152
# 19      825            12       MQ      4650   N542MQ  LGA    ATL  134
# 20      850            -6       B6       343   N644JB  EWR    PBI  147
# 21      820            -8       DL      1919   N971DL  LGA    MSP  170
# 22      805            16       MQ      4401   N730MQ  LGA    DTW  105
# 23      910           -12       AA      1895   N633AA  EWR    MIA  152
# 24      845            -8       DL      1743   N3739P  JFK    ATL  128
# 25      915           -17       UA      1077   N53442  EWR    MIA  157
# 26      735            32       MQ      3768   N9EAMQ  EWR    ORD  139
# 27      931            14       UA       303   N532UA  JFK    SFO  366
# 28      921             4       B6       135   N635JB  JFK    RSW  175
# 29     1100           -21       B6       709   N794JB  JFK    SJU  182
# 30      842            -9       DL       575   N326NB  EWR    ATL  120
# ⋮      ⋮              ⋮         ⋮       ⋮      ⋮       ⋮      ⋮    ⋮
# 336747 2247           -24       EV      5489   N712EV  LGA    CHO   45
# 336748 2323            -9       EV      3833   N16546  EWR    CLT   72
# 336749 2359           -31       B6        97   N807JB  JFK    DEN  213
# 336750 2232            -2       EV      5048   N751EV  LGA    RIC   45
# 336751 2255           -30       MQ      3621   N807MQ  JFK    DCA   36
# 336752   40           -30       AA       185   N335AA  JFK    LAX  298
# 336753 2239            11       EV      4509   N12957  EWR    PWM   47
# 336754  140           -25       B6      1103   N633JB  JFK    SJU  192
# 336755   27             3       B6      1371   N627JB  LGA    FLL  139
# 336756 2308           -23       UA       523   N813UA  EWR    BOS   37
# 336757 2306           -16       EV      3842   N10575  EWR    MHT   39
# 336758 2030           194       9E      3320   N906XJ  JFK    BUF   50
# 336759 2331             8       EV      5311   N722EV  LGA    BGR   61
# 336760 2250             7       MQ      3660   N532MQ  LGA    BNA   97
# 336761 2242            57       EV      4672   N12145  EWR    STL  120
# 336762 2356           -21       B6       108   N193JB  JFK    PWM   48
# 336763   30            42       UA       471   N578UA  EWR    SFO  318
# 336764 2249           130       B6      1083   N804JB  JFK    MCO  123
# 336765 2353            -8       B6       234   N318JB  JFK    BTV   43
# 336766 2351           -17       B6      1816   N354JB  JFK    SYR   41
# 336767    7           -20       B6      2002   N281JB  JFK    BUF   52
# 336768    1           -16       B6       486   N346JB  JFK    ROC   47
# 336769 2358             1       B6       718   N565JB  JFK    BOS   33
# 336770  350           -25       B6       745   N516JB  JFK    PSE  196
# 336771 2019            NA       EV      5274   N740EV  LGA    BNA   NA
# 336772 1634            NA       9E      3393   NA      JFK    DCA   NA
# 336773 2312            NA       9E      3525   NA      LGA    SYR   NA
# 336774 1330            NA       MQ      3461   N535MQ  LGA    BNA   NA
# 336775 1344            NA       MQ      3572   N511MQ  LGA    CLE   NA
# 336776 1020            NA       MQ      3531   N839MQ  LGA    RDU   NA
#        distance hour minute time_hour
# 1      1400     5    15     2013-01-01 05:00:00
# 2      1416     5    29     2013-01-01 05:00:00
# 3      1089     5    40     2013-01-01 05:00:00
# 4      1576     5    45     2013-01-01 05:00:00
# 5       762     6     0     2013-01-01 06:00:00
# 6       719     5    58     2013-01-01 05:00:00
# 7      1065     6     0     2013-01-01 06:00:00
# 8       229     6     0     2013-01-01 06:00:00
# 9       944     6     0     2013-01-01 06:00:00
# 10      733     6     0     2013-01-01 06:00:00
# 11     1028     6     0     2013-01-01 06:00:00
# 12     1005     6     0     2013-01-01 06:00:00
# 13     2475     6     0     2013-01-01 06:00:00
# 14     2565     6     0     2013-01-01 06:00:00
# 15     1389     6     0     2013-01-01 06:00:00
# 16      187     5    59     2013-01-01 05:00:00
# 17     2227     6     0     2013-01-01 06:00:00
# 18     1076     6     0     2013-01-01 06:00:00
# 19      762     6     0     2013-01-01 06:00:00
# 20     1023     6     0     2013-01-01 06:00:00
# 21     1020     6    10     2013-01-01 06:00:00
# 22      502     6     5     2013-01-01 06:00:00
# 23     1085     6    10     2013-01-01 06:00:00
# 24      760     6    10     2013-01-01 06:00:00
# 25     1085     6     7     2013-01-01 06:00:00
# 26      719     6     0     2013-01-01 06:00:00
# 27     2586     6     0     2013-01-01 06:00:00
# 28     1074     6    10     2013-01-01 06:00:00
# 29     1598     6    15     2013-01-01 06:00:00
# 30      746     6    15     2013-01-01 06:00:00
# ⋮      ⋮        ⋮    ⋮      ⋮
# 336747  305     21   25     2013-09-30 21:00:00
# 336748  529     21   29     2013-09-30 21:00:00
# 336749 1626     21   30     2013-09-30 21:00:00
# 336750  292     20   59     2013-09-30 20:00:00
# 336751  213     21   40     2013-09-30 21:00:00
# 336752 2475     21   40     2013-09-30 21:00:00
# 336753  284     21   29     2013-09-30 21:00:00
# 336754 1598     21   45     2013-09-30 21:00:00
# 336755 1076     21   37     2013-09-30 21:00:00
# 336756  200     21   56     2013-09-30 21:00:00
# 336757  209     21   59     2013-09-30 21:00:00
# 336758  301     18   45     2013-09-30 18:00:00
# 336759  378     22    5     2013-09-30 22:00:00
# 336760  764     21   40     2013-09-30 21:00:00
# 336761  872     20   59     2013-09-30 20:00:00
# 336762  273     22   45     2013-09-30 22:00:00
# 336763 2565     21   13     2013-09-30 21:00:00
# 336764  944     20    1     2013-09-30 20:00:00
# 336765  266     22   45     2013-09-30 22:00:00
# 336766  209     22   45     2013-09-30 22:00:00
# 336767  301     22   50     2013-09-30 22:00:00
# 336768  264     22   46     2013-09-30 22:00:00
# 336769  187     22   55     2013-09-30 22:00:00
# 336770 1617     23   59     2013-09-30 23:00:00
# 336771  764     18   42     2013-09-30 18:00:00
# 336772  213     14   55     2013-09-30 14:00:00
# 336773  198     22    0     2013-09-30 22:00:00
# 336774  764     12   10     2013-09-30 12:00:00
# 336775  419     11   59     2013-09-30 11:00:00
# 336776  431      8   40     2013-09-30 08:00:00

# %% [markdown]
# ## Hands-On Exercise 1.

# %% [markdown]
# ![images](images/handson1.png)

# %%
# hands on exercise 1

daily <- flights %>% 
  mutate(date = make_date(year, month, day)) %>% 
  group_by(date) %>% 
  summarise(n = n())
daily
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#     date       n
# 1   2013-01-01 842
# 2   2013-01-02 943
# 3   2013-01-03 914
# 4   2013-01-04 915
# 5   2013-01-05 720
# 6   2013-01-06 832
# 7   2013-01-07 933
# 8   2013-01-08 899
# 9   2013-01-09 902
# 10  2013-01-10 932
# 11  2013-01-11 930
# 12  2013-01-12 690
# 13  2013-01-13 828
# 14  2013-01-14 928
# 15  2013-01-15 894
# 16  2013-01-16 901
# 17  2013-01-17 927
# 18  2013-01-18 924
# 19  2013-01-19 674
# 20  2013-01-20 786
# 21  2013-01-21 912
# 22  2013-01-22 890
# 23  2013-01-23 897
# 24  2013-01-24 925
# 25  2013-01-25 922
# 26  2013-01-26 680
# 27  2013-01-27 823
# 28  2013-01-28 923
# 29  2013-01-29 890
# 30  2013-01-30 900
# ⋮   ⋮          ⋮
# 336 2013-12-02 1004
# 337 2013-12-03  973
# 338 2013-12-04  958
# 339 2013-12-05  969
# 340 2013-12-06  970
# 341 2013-12-07  691
# 342 2013-12-08  875
# 343 2013-12-09  962
# 344 2013-12-10  943
# 345 2013-12-11  954
# 346 2013-12-12  968
# 347 2013-12-13  970
# 348 2013-12-14  692
# 349 2013-12-15  880
# 350 2013-12-16  964
# 351 2013-12-17  949
# 352 2013-12-18  956
# 353 2013-12-19  974
# 354 2013-12-20  980
# 355 2013-12-21  811
# 356 2013-12-22  895
# 357 2013-12-23  985
# 358 2013-12-24  761
# 359 2013-12-25  719
# 360 2013-12-26  936
# 361 2013-12-27  963
# 362 2013-12-28  814
# 363 2013-12-29  888
# 364 2013-12-30  968
# 365 2013-12-31  776

# %%
ggplot(daily, aes(date, n)) + 
  geom_line()
# Out:
# plot without title

# %% [markdown]
# ## Hands-On Exercise 2.

# %% [markdown]
# ![images](images/handson2.png)

# %%
# hands on exercise 2
daily <- daily %>% 
  mutate(wday = wday(date, label = TRUE))
ggplot(daily, aes(wday, n)) + 
  geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# ## Hands-On Exercise 3.

# %% [markdown]
# ![images](images/handson3.png)

# %%
# hands on exercises 3
mod <- lm(n ~ wday, data = daily)

grid <- daily %>% 
  data_grid(wday) %>% 
  add_predictions(mod, "n")

ggplot(daily, aes(wday, n)) + 
  geom_boxplot() +
  geom_point(data = grid, colour = "red", size = 4)
# Out:
# plot without title

# %% [markdown]
# ## Hands-On Exercise 4.

# %% [markdown]
# ![images](images/handson4.png)

# %%
# hands on exercises 4
daily <- daily %>% 
  add_residuals(mod)
daily %>% 
  ggplot(aes(date, resid)) + 
  geom_ref_line(h = 0) + 
  geom_line()
# Out:
# plot without title

# %% [markdown]
# ## Hands-On Exercises 5.

# %% [markdown]
# ![images](images/handson5.png)

# %%
ggplot(daily, aes(date, resid, color = wday)) +
  geom_ref_line(h = 0) + geom_line()
# Out:
# plot without title

# %%
# hands on exercises 5

# %% [markdown]
# ## Hands-On Exercises 6.

# %% [markdown]
# ![images](images/handson6.png)

# %%
# hands on exercises 6
daily %>% 
  filter(wday == "Sat") %>% 
  ggplot(aes(date, n)) + 
    geom_point() + 
    geom_line() +
    scale_x_date(NULL, date_breaks = "1 month", date_labels = "%b")
# Out:
# plot without title

# %% [markdown]
# ## Hands-On Exercises 7

# %% [markdown]
# ![images](images/handson7.png)

# %%
daily <- daily %>%
  mutate(term = cut(date,
                   breaks = ymd("2013-01-01", "2013-06-05", "2013-08-25", "2014-01-01"),
                   labels = c("spring", "summer", "fall")))

# %%
# exercise 7

daily %>% 
  filter(wday == "Sat") %>% 
  ggplot(aes(date, n, colour = term)) +
  geom_point(alpha = 1/3) + 
  geom_line() +
  scale_x_date(NULL, date_breaks = "1 month", date_labels = "%b")
# Out:
# plot without title

# %% [markdown]
# ## Hands-On Exercises 8

# %% [markdown]
# ![images](images/handson8.png)

# %%
# hands on exercises 8

daily %>% 
  ggplot(aes(wday, n, colour = term)) +
    geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# ## Hands-On Exercises 9

# %% [markdown]
# ![images](images/handson9.png)

# %%
# hands on exercises 9

mod1 <- lm(n ~ wday, data = daily)
mod2 <- lm(n ~ wday * term, data = daily)

daily %>% 
  gather_residuals(without_term = mod1, with_term = mod2) %>% 
  ggplot(aes(date, resid, colour = model)) +
    geom_line(alpha = 0.75)
# Out:
# plot without title

# %% [markdown]
# ## Hands-On Exercises 10

# %% [markdown]
# ![images](images/handson10.png)

# %%
# hands on exercises 10

grid <- daily %>% 
  data_grid(wday, term) %>% 
  add_predictions(mod2, "n")

ggplot(daily, aes(wday, n)) +
  geom_boxplot() + 
  geom_point(data = grid, colour = "red") + 
  facet_wrap(~ term)
# Out:
# plot without title

# %% [markdown]
# ## Fitting A Robust Linear Regression

# %%
mod3 <- MASS::rlm(n ~ wday * term, data = daily)

daily %>% 
  add_residuals(mod3, "resid") %>% 
  ggplot(aes(date, resid)) + 
  geom_hline(yintercept = 0, size = 2, colour = "white") + 
  geom_line()
# Out:
# plot without title

# %% [markdown]
# Now it is easier to see the long-term trend, and the outliers.

# %% [markdown]
# ## Identifying The Outliers

# %% [markdown]
# Can we explain the remaining large residuals?

# %%
daily %>% add_residuals(mod3, "resid") %>%
  filter(abs(resid) > 100)
# Out:
#    date       n   wday resid     term
# 1  2013-01-01 842 Tue  -110.8388 spring
# 2  2013-01-20 786 Sun  -107.4956 spring
# 3  2013-05-26 729 Sun  -164.4956 spring
# 4  2013-07-04 737 Thu  -257.0321 summer
# 5  2013-07-05 822 Fri  -170.0321 summer
# 6  2013-09-01 718 Sun  -182.0845 fall
# 7  2013-11-28 634 Thu  -347.5372 fall
# 8  2013-11-29 661 Fri  -321.4326 fall
# 9  2013-11-30 857 Sat   160.1007 fall
# 10 2013-12-21 811 Sat   114.1007 fall
# 11 2013-12-24 761 Tue  -200.1470 fall
# 12 2013-12-25 719 Wed  -248.5625 fall
# 13 2013-12-28 814 Sat   117.1007 fall
# 14 2013-12-31 776 Tue  -185.1470 fall

# %% [markdown]
# Many correspond to US public holidays.

# %% [markdown]
# ## Long Term Trend

# %% [markdown]
# We can still see some smooth long term trend.

# %%
daily %>%
  add_residuals(mod3, "resid") %>% filter(abs(resid) < 100) %>%
  ggplot(aes(date, resid)) + geom_ref_line(h = 0) +
  geom_line(color = "grey50") + geom_smooth(se = FALSE, span = 0.20)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# Can't do much with this as we only have one year of data.

# %%
library(IRdisplay)

  display_html("<iframe width='560' height='315' src='https://www.youtube.com/embed/LPptRkGoYMg?rel=0&amp;controls=0&amp;showinfo=0'</iframe>")
# Out:
# <iframe width='560' height='315' src='https://www.youtube.com/embed/LPptRkGoYMg?rel=0&amp;controls=0&amp;showinfo=0'</iframe>

# %% [markdown]
# ### [John Hopkins University R Exploratory Data Analysis Course](https://www.coursera.org/learn/exploratory-data-analysis?specialization=jhu-data-science)
