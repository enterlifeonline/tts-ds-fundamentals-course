# %% [markdown]
# Data Science Fundamentals: R |
# [Table of Contents](../index.ipynb)
# - - -
# <!--NAVIGATION-->
# Module 14. [Introduction](./00.ipynb) | [Basic Syntax](./01.ipynb)  | [Data Types](./02.ipynb) | [Variables](./03.ipynb) | [Operators](./04.ipynb) | [Decision Making](./05.ipynb)  | [Functions](./06.ipynb) | [Strings](./07.ipynb) | [Vectors](./08.ipynb) | [Lists](./09.ipynb) | [Matrices](./10.ipynb) | [Arrays](./11.ipynb) | [Factors](./12.ipynb) | [Data Frames](./13.ipynb) | [Data Reshaping](./14.ipynb) | [Exercises](./15.ipynb)

# %% [markdown]
# # Introduction of R

# %% [markdown]
# ![slide1](images/slide1.png)

# %% [markdown]
# ![image](images/slide2.png)

# %% [markdown]
# ![images](images/slide3.png)

# %% [markdown]
# ![image](images/slide4.png)

# %% [markdown]
# ![image](images/slide5.png)

# %% [markdown]
# # Installation of R

# %% [markdown]
# ## Starting R

# %%
When using Mac OS, submit the following from any terminal session -

# %% [raw]
# open -a /Applications/R.app

# %% [markdown]
# ## Packages

# %% [markdown]
# R packages are a collection of R functions, complied code and sample data. They are stored under a directory called "library" in the R environment. By default, R installs a set of packages during installation. More packages are added later, when they are needed for some specific purpose. When we start the R console, only the default packages are available by default. Other packages which are already installed have to be loaded explicitly to be used by the R program that is going to use them.
#
# All the packages available in R language are listed at R Packages.
#
# ![packages](images/slide6.png)
#
# Below is a list of commands to be used to check, verify and use the R packages.

# %%
installed.packages()
# Out:
#             Package
# askpass     askpass
# base        base
# base64enc   base64enc
# boot        boot
# brew        brew
# brio        brio
# cachem      cachem
# callr       callr
# class       class
# cli         cli
# clipr       clipr
# cluster     cluster
# codetools   codetools
# commonmark  commonmark
# compiler    compiler
# crayon      crayon
# credentials credentials
# curl        curl
# datasets    datasets
# desc        desc
# devtools    devtools
# diffobj     diffobj
# digest      digest
# ellipsis    ellipsis
# evaluate    evaluate
# fansi       fansi
# fastmap     fastmap
# foreign     foreign
# fs          fs
# gert        gert
# ⋮           ⋮
# rpart       rpart
# rprojroot   rprojroot
# rstudioapi  rstudioapi
# rversions   rversions
# sessioninfo sessioninfo
# spatial     spatial
# splines     splines
# stats       stats
# stats4      stats4
# stringi     stringi
# stringr     stringr
# survival    survival
# sys         sys
# tcltk       tcltk
# testthat    testthat
# tibble      tibble
# tools       tools
# usethis     usethis
# utf8        utf8
# utils       utils
# uuid        uuid
# vctrs       vctrs
# waldo       waldo
# whisker     whisker
# withr       withr
# xfun        xfun
# xml2        xml2
# xopen       xopen
# yaml        yaml
# zip         zip
#             LibPath
# askpass     /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# base        /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# base64enc   /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# boot        /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# brew        /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# brio        /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# cachem      /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# callr       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# class       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# cli         /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# clipr       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# cluster     /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# codetools   /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# commonmark  /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# compiler    /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# crayon      /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# credentials /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# curl        /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# datasets    /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# desc        /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# devtools    /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# diffobj     /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# digest      /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# ellipsis    /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# evaluate    /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# fansi       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# fastmap     /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# foreign     /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# fs          /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# gert        /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# ⋮           ⋮
# rpart       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# rprojroot   /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# rstudioapi  /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# rversions   /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# sessioninfo /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# spatial     /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# splines     /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# stats       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# stats4      /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# stringi     /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# stringr     /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# survival    /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# sys         /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# tcltk       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# testthat    /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# tibble      /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# tools       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# usethis     /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# utf8        /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# utils       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# uuid        /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# vctrs       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# waldo       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# whisker     /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# withr       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# xfun        /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# xml2        /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# xopen       /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# yaml        /Library/Frameworks/R.framework/Versions/4.1/Resources/library
# zip         /Library/Frameworks/R.framework/Versions/4.1/Resources/library
#             Version Priority    Depends
# askpass     1.1     NA          NA
# base        4.1.0   base        NA
# base64enc   0.1-3   NA          R (>= 2.9.0)
# boot        1.3-28  recommended R (>= 3.0.0), graphics, stats
# brew        1.0-6   NA          NA
# brio        1.1.2   NA          NA
# cachem      1.0.5   NA          NA
# callr       3.7.0   NA          NA
# class       7.3-19  recommended R (>= 3.0.0), stats, utils
# cli         3.0.1   NA          R (>= 2.10)
# clipr       0.7.1   NA          NA
# cluster     2.1.2   recommended R (>= 3.4.0)
# codetools   0.2-18  recommended R (>= 2.1)
# commonmark  1.7     NA          NA
# compiler    4.1.0   base        NA
# crayon      1.4.1   NA          NA
# credentials 1.3.1   NA          NA
# curl        4.3.2   NA          R (>= 3.0.0)
# datasets    4.1.0   base        NA
# desc        1.3.0   NA          R (>= 3.1.0)
# devtools    2.4.2   NA          R (>= 3.0.2), usethis (>= 2.0.1)
# diffobj     0.3.4   NA          R (>= 3.1.0)
# digest      0.6.27  NA          R (>= 3.3.0)
# ellipsis    0.3.2   NA          R (>= 3.2)
# evaluate    0.14    NA          R (>= 3.0.2)
# fansi       0.5.0   NA          R (>= 3.1.0)
# fastmap     1.1.0   NA          NA
# foreign     0.8-81  recommended R (>= 4.0.0)
# fs          1.5.0   NA          R (>= 3.1)
# gert        1.3.1   NA          NA
# ⋮           ⋮       ⋮           ⋮
# rpart       4.1-15  recommended R (>= 2.15.0), graphics, stats, grDevices
# rprojroot   2.0.2   NA          R (>= 3.0.0)
# rstudioapi  0.13    NA          NA
# rversions   2.1.1   NA          NA
# sessioninfo 1.1.1   NA          NA
# spatial     7.3-14  recommended R (>= 3.0.0), graphics, stats, utils
# splines     4.1.0   base        NA
# stats       4.1.0   base        NA
# stats4      4.1.0   base        NA
# stringi     1.7.3   NA          R (>= 3.1)
# stringr     1.4.0   NA          R (>= 3.1)
# survival    3.2-11  recommended R (>= 3.5.0)
# sys         3.4     NA          NA
# tcltk       4.1.0   base        NA
# testthat    3.0.4   NA          R (>= 3.1)
# tibble      3.1.3   NA          R (>= 3.1.0)
# tools       4.1.0   base        NA
# usethis     2.0.1   NA          R (>= 3.2)
# utf8        1.2.2   NA          R (>= 2.10)
# utils       4.1.0   base        NA
# uuid        0.1-4   NA          R (>= 2.9.0)
# vctrs       0.3.8   NA          R (>= 3.3)
# waldo       0.2.5   NA          NA
# whisker     0.4     NA          NA
# withr       2.4.2   NA          R (>= 3.2.0)
# xfun        0.24    NA          NA
# xml2        1.3.2   NA          R (>= 3.1.0)
# xopen       1.0.0   NA          R (>= 3.1)
# yaml        2.2.1   NA          NA
# zip         2.2.0   NA          NA
#             Imports
# askpass     sys (>= 2.1)
# base        NA
# base64enc   NA
# boot        NA
# brew        NA
# brio        NA
# cachem      rlang, fastmap
# callr       processx (>= 3.5.0), R6, utils
# class       MASS
# cli         glue, utils
# clipr       utils
# cluster     graphics, grDevices, stats, utils
# codetools   NA
# commonmark  NA
# compiler    NA
# crayon      grDevices, methods, utils
# credentials openssl (>= 1.3), sys (>= 2.1), curl, jsonlite, askpass
# curl        NA
# datasets    NA
# desc        utils, R6, crayon, rprojroot
# devtools    callr (>= 3.6.0), cli (>= 2.4.0), desc (>= 1.3.0), ellipsis\n(>= 0.3.1), fs (>= 1.5.0), httr (>= 1.4.2), lifecycle (>=\n1.0.0), memoise (>= 2.0.0), pkgbuild (>= 1.2.0), pkgload (>=\n1.2.1), rcmdcheck (>= 1.3.3), remotes (>= 2.3.0), rlang (>=\n0.4.10), roxygen2 (>= 7.1.1), rstudioapi (>= 0.13), rversions\n(>= 2.0.2), sessioninfo (>= 1.1.1), stats, testthat (>= 3.0.2),\ntools, utils, withr (>= 2.4.1)
# diffobj     crayon (>= 1.3.2), tools, methods, utils, stats
# digest      utils
# ellipsis    rlang (>= 0.3.0)
# evaluate    methods
# fansi       grDevices, utils
# fastmap     NA
# foreign     methods, utils, stats
# fs          methods
# gert        askpass, credentials (>= 1.2.1), openssl (>= 1.4.1),\nrstudioapi (>= 0.11), sys, zip (>= 2.1.0)
# ⋮           ⋮
# rpart       NA
# rprojroot   NA
# rstudioapi  NA
# rversions   curl, utils, xml2 (>= 1.0.0)
# sessioninfo cli, tools, utils, withr
# spatial     NA
# splines     graphics, stats
# stats       utils, grDevices, graphics
# stats4      graphics, methods, stats
# stringi     tools, utils, stats
# stringr     glue (>= 1.2.0), magrittr, stringi (>= 1.1.7)
# survival    graphics, Matrix, methods, splines, stats, utils
# sys         NA
# tcltk       utils
# testthat    brio, callr (>= 3.5.1), cli (>= 2.2.0), crayon (>= 1.3.4),\ndesc, digest, ellipsis (>= 0.2.0), evaluate, jsonlite,\nlifecycle, magrittr, methods, pkgload, praise, processx, ps (>=\n1.3.4), R6 (>= 2.2.0), rlang (>= 0.4.9), utils, waldo (>=\n0.2.4), withr (>= 2.3.0)
# tibble      ellipsis (>= 0.3.2), fansi (>= 0.4.0), lifecycle (>= 0.2.0),\nmagrittr, methods, pillar (>= 1.6.0), pkgconfig, rlang (>=\n0.4.3), utils, vctrs (>= 0.3.8)
# tools       NA
# usethis     cli, clipr (>= 0.3.0), crayon, curl (>= 2.7), desc, fs (>=\n1.3.0), gert (>= 1.0.2), gh (>= 1.2.0), glue (>= 1.3.0),\njsonlite, lifecycle, purrr, rappdirs, rlang (>= 0.4.10),\nrprojroot (>= 1.2), rstudioapi, stats, utils, whisker, withr\n(>= 2.3.0), yaml
# utf8        NA
# utils       NA
# uuid        NA
# vctrs       ellipsis (>= 0.2.0), glue, rlang (>= 0.4.10)
# waldo       cli, diffobj, fansi, glue, methods, rematch2, rlang (>=\n0.4.10), tibble
# whisker     NA
# withr       graphics, grDevices, stats
# xfun        stats, tools
# xml2        methods
# xopen       processx
# yaml        NA
# zip         NA
#             LinkingTo
# askpass     NA
# base        NA
# base64enc   NA
# boot        NA
# brew        NA
# brio        NA
# cachem      NA
# callr       NA
# class       NA
# cli         NA
# clipr       NA
# cluster     NA
# codetools   NA
# commonmark  NA
# compiler    NA
# crayon      NA
# credentials NA
# curl        NA
# datasets    NA
# desc        NA
# devtools    NA
# diffobj     NA
# digest      NA
# ellipsis    NA
# evaluate    NA
# fansi       NA
# fastmap     NA
# foreign     NA
# fs          NA
# gert        NA
# ⋮           ⋮
# rpart       NA
# rprojroot   NA
# rstudioapi  NA
# rversions   NA
# sessioninfo NA
# spatial     NA
# splines     NA
# stats       NA
# stats4      NA
# stringi     NA
# stringr     NA
# survival    NA
# sys         NA
# tcltk       NA
# testthat    NA
# tibble      NA
# tools       NA
# usethis     NA
# utf8        NA
# utils       NA
# uuid        NA
# vctrs       NA
# waldo       NA
# whisker     NA
# withr       NA
# xfun        NA
# xml2        NA
# xopen       NA
# yaml        NA
# zip         NA
#             Suggests
# askpass     testthat
# base        methods
# base64enc   NA
# boot        MASS, survival
# brew        NA
# brio        testthat (>= 2.1.0), covr
# cachem      testthat
# callr       cli, covr, ps, rprojroot, spelling, testthat, withr (>=\n2.3.0)
# class       NA
# cli         callr, covr, grDevices, htmlwidgets, knitr, methods, mockery,\nprettycode (>= 1.1.0), processx, ps (>= 1.3.4.9000), rlang,\nrmarkdown, rstudioapi, shiny, testthat, tibble, withr
# clipr       covr, knitr, rmarkdown, rstudioapi (>= 0.5), testthat (>=\n2.0.0)
# cluster     MASS, Matrix
# codetools   NA
# commonmark  curl, testthat, xml2
# compiler    NA
# crayon      mockery, rstudioapi, testthat, withr
# credentials testthat, knitr, rmarkdown
# curl        spelling, testthat (>= 1.0.0), knitr, jsonlite, rmarkdown,\nmagrittr, httpuv (>= 1.4.4), webutils
# datasets    NA
# desc        covr, testthat, whoami, withr, spelling, gh
# devtools    BiocManager (>= 1.30.12), covr (>= 3.5.1), curl (>= 4.3),\ndigest (>= 0.6.27), DT (>= 0.17), foghorn (>= 1.3.2), gh (>=\n1.2.1), gmailr (>= 1.0.0), knitr (>= 1.31), lintr (>= 2.0.1),\nMASS, mockery (>= 0.4.2), pingr (>= 2.0.1), pkgdown (>= 1.6.1),\nrhub (>= 1.1.1), rmarkdown (>= 2.7), spelling (>= 2.2)
# diffobj     knitr, rmarkdown
# digest      tinytest, knitr, rmarkdown, minidown
# ellipsis    covr, testthat
# evaluate    testthat, lattice, ggplot2
# fansi       unitizer, knitr, rmarkdown
# fastmap     testthat (>= 2.1.1)
# foreign     NA
# fs          testthat, covr, pillar (>= 1.0.0), tibble (>= 1.1.0), crayon,\nrmarkdown, knitr, withr, spelling, vctrs (>= 0.3.0)
# gert        spelling, knitr, rmarkdown, testthat
# ⋮           ⋮
# ...
# stringi     NA
# stringr     covr, htmltools, htmlwidgets, knitr, rmarkdown, testthat
# survival    NA
# sys         unix (>= 1.4), spelling, testthat
# tcltk       NA
# testthat    covr, curl (>= 0.9.5), diffviewer (>= 0.1.0), knitr, mockery,\nrmarkdown, rstudioapi, shiny, usethis, vctrs (>= 0.1.0), xml2
# tibble      bench, bit64, blob, cli, covr, crayon (>= 1.3.4), DiagrammeR,\ndplyr, evaluate, formattable, ggplot2, hms, htmltools, knitr,\nlubridate, mockr, nycflights13, purrr, rmarkdown, testthat (>=\n3.0.2), tidyr, withr
# tools       codetools, methods, xml2, curl, commonmark
# usethis     covr, knitr, magick, mockr, rmarkdown, roxygen2, spelling (>=\n1.2), styler (>= 1.2.0), testthat (>= 3.0.0)
# utf8        cli, covr, knitr, rlang, rmarkdown, testthat (>= 3.0.0),\nwithr
# utils       methods, xml2, commonmark
# uuid        NA
# vctrs       bit64, covr, crayon, dplyr (>= 0.8.5), generics, knitr,\npillar (>= 1.4.4), pkgdown, rmarkdown, testthat (>= 2.3.0),\ntibble, withr, xml2, waldo (>= 0.2.0), zeallot
# waldo       testthat (>= 3.0.0), covr, R6
# whisker     markdown
# withr       covr, DBI, knitr, lattice, methods, rmarkdown, RSQLite,\ntestthat (>= 2.1.0)
# xfun        testit, parallel, codetools, rstudioapi, tinytex (>= 0.30),\nmime, markdown, knitr, htmltools, remotes, pak, renv, curl,\njsonlite, rmarkdown
# xml2        covr, curl, httr, knitr, magrittr, mockery, rmarkdown,\ntestthat (>= 2.1.0)
# xopen       ps, testthat
# yaml        RUnit
# zip         covr, processx, R6, testthat, withr
#             Enhances License                                License_is_FOSS
# askpass     NA       MIT + file LICENSE                     NA
# base        NA       Part of R 4.1.0                        NA
# base64enc   png      GPL-2 | GPL-3                          NA
# boot        NA       Unlimited                              NA
# brew        NA       GPL-2                                  NA
# brio        NA       MIT + file LICENSE                     NA
# cachem      NA       MIT + file LICENSE                     NA
# callr       NA       MIT + file LICENSE                     NA
# class       NA       GPL-2 | GPL-3                          NA
# cli         NA       MIT + file LICENSE                     NA
# clipr       NA       GPL-3                                  NA
# cluster     NA       GPL (>= 2)                             NA
# codetools   NA       GPL                                    NA
# commonmark  NA       BSD_2_clause + file LICENSE            NA
# compiler    NA       Part of R 4.1.0                        NA
# crayon      NA       MIT + file LICENSE                     NA
# credentials NA       MIT + file LICENSE                     NA
# curl        NA       MIT + file LICENSE                     NA
# datasets    NA       Part of R 4.1.0                        NA
# desc        NA       MIT + file LICENSE                     NA
# devtools    NA       MIT + file LICENSE                     NA
# diffobj     NA       GPL (>= 2)                             NA
# digest      NA       GPL (>= 2)                             NA
# ellipsis    NA       MIT + file LICENSE                     NA
# evaluate    NA       MIT + file LICENSE                     NA
# fansi       NA       GPL (>= 2)                             NA
# fastmap     NA       MIT + file LICENSE                     NA
# foreign     NA       GPL (>= 2)                             NA
# fs          NA       GPL-3                                  NA
# gert        NA       MIT + file LICENSE                     NA
# ⋮           ⋮        ⋮                                      ⋮
# rpart       NA       GPL-2 | GPL-3                          NA
# rprojroot   NA       MIT + file LICENSE                     NA
# rstudioapi  NA       MIT + file LICENSE                     NA
# rversions   NA       MIT + file LICENSE                     NA
# sessioninfo NA       GPL-2                                  NA
# spatial     NA       GPL-2 | GPL-3                          NA
# splines     NA       Part of R 4.1.0                        NA
# stats       NA       Part of R 4.1.0                        NA
# stats4      NA       Part of R 4.1.0                        NA
# stringi     NA       file LICENSE                           yes
# stringr     NA       GPL-2 | file LICENSE                   NA
# survival    NA       LGPL (>= 2)                            NA
# sys         NA       MIT + file LICENSE                     NA
# tcltk       NA       Part of R 4.1.0                        NA
# testthat    NA       MIT + file LICENSE                     NA
# tibble      NA       MIT + file LICENSE                     NA
# tools       NA       Part of R 4.1.0                        NA
# usethis     NA       MIT + file LICENSE                     NA
# utf8        NA       Apache License (== 2.0) | file LICENSE NA
# utils       NA       Part of R 4.1.0                        NA
# uuid        NA       MIT + file LICENSE                     NA
# vctrs       NA       MIT + file LICENSE                     NA
# waldo       NA       MIT + file LICENSE                     NA
# whisker     NA       GPL-3                                  NA
# withr       NA       MIT + file LICENSE                     NA
# xfun        NA       MIT + file LICENSE                     NA
# xml2        NA       GPL (>= 2)                             NA
# xopen       NA       MIT + file LICENSE                     NA
# yaml        NA       BSD_3_clause + file LICENSE            NA
# zip         NA       MIT + file LICENSE                     NA
#             License_restricts_use OS_type MD5sum NeedsCompilation Built
# askpass     NA                    NA      NA     yes              4.1.0
# base        NA                    NA      NA     NA               4.1.0
# base64enc   NA                    NA      NA     yes              4.1.0
# boot        NA                    NA      NA     no               4.1.0
# brew        NA                    NA      NA     NA               4.1.0
# brio        NA                    NA      NA     yes              4.1.0
# cachem      NA                    NA      NA     yes              4.1.0
# callr       NA                    NA      NA     no               4.1.0
# class       NA                    NA      NA     yes              4.1.0
# cli         NA                    NA      NA     yes              4.1.0
# clipr       NA                    NA      NA     no               4.1.0
# cluster     NA                    NA      NA     yes              4.1.0
# codetools   NA                    NA      NA     no               4.1.0
# commonmark  NA                    NA      NA     yes              4.1.0
# compiler    NA                    NA      NA     NA               4.1.0
# crayon      NA                    NA      NA     no               4.1.0
# credentials NA                    NA      NA     no               4.1.0
# curl        NA                    NA      NA     yes              4.1.0
# datasets    NA                    NA      NA     NA               4.1.0
# desc        NA                    NA      NA     no               4.1.0
# devtools    NA                    NA      NA     no               4.1.0
# diffobj     NA                    NA      NA     yes              4.1.0
# digest      NA                    NA      NA     yes              4.1.0
# ellipsis    NA                    NA      NA     yes              4.1.0
# evaluate    NA                    NA      NA     no               4.1.0
# fansi       NA                    NA      NA     yes              4.1.0
# fastmap     NA                    NA      NA     yes              4.1.0
# foreign     NA                    NA      NA     yes              4.1.0
# fs          NA                    NA      NA     yes              4.1.0
# gert        NA                    NA      NA     yes              4.1.0
# ⋮           ⋮                     ⋮       ⋮      ⋮                ⋮
# rpart       NA                    NA      NA     yes              4.1.0
# rprojroot   NA                    NA      NA     no               4.1.0
# rstudioapi  NA                    NA      NA     no               4.1.0
# rversions   NA                    NA      NA     no               4.1.0
# sessioninfo NA                    NA      NA     no               4.1.0
# spatial     NA                    NA      NA     yes              4.1.0
# splines     NA                    NA      NA     yes              4.1.0
# stats       NA                    NA      NA     yes              4.1.0
# stats4      NA                    NA      NA     NA               4.1.0
# stringi     NA                    NA      NA     yes              4.1.0
# stringr     NA                    NA      NA     no               4.1.0
# survival    NA                    NA      NA     yes              4.1.0
# sys         NA                    NA      NA     yes              4.1.0
# tcltk       NA                    NA      NA     yes              4.1.0
# testthat    NA                    NA      NA     yes              4.1.0
# tibble      NA                    NA      NA     yes              4.1.0
# tools       NA                    NA      NA     yes              4.1.0
# usethis     NA                    NA      NA     no               4.1.0
# utf8        NA                    NA      NA     yes              4.1.0
# utils       NA                    NA      NA     yes              4.1.0
# uuid        NA                    NA      NA     yes              4.1.0
# vctrs       NA                    NA      NA     yes              4.1.0
# waldo       NA                    NA      NA     no               4.1.0
# whisker     NA                    NA      NA     no               4.1.0
# withr       NA                    NA      NA     no               4.1.0
# xfun        NA                    NA      NA     yes              4.1.0
# xml2        NA                    NA      NA     yes              4.1.0
# xopen       NA                    NA      NA     no               4.1.0
# yaml        NA                    NA      NA     yes              4.1.0
# zip         NA                    NA      NA     yes              4.1.0

# %% [markdown]
# Check Available R Packages
# ---
#
# Get library locations containing R packages

# %%
.libPaths()
# Out:
# [1] "/Library/Frameworks/R.framework/Versions/4.1/Resources/library"

# %% [markdown]
# Get the list of all the packages installed
# ---

# %%
library()

# %% [markdown]
# Get all packages currently loaded in the R environment
# ---

# %%
search()
# Out:
#  [1] ".GlobalEnv"        "jupyter:irkernel"  "package:stats"
#  [4] "package:graphics"  "package:grDevices" "package:utils"
#  [7] "package:datasets"  "package:methods"   "Autoloads"
# [10] "package:base"

# %% [markdown]
# Install a New Package
# ---
#
# There are two ways to add new R packages. One is installing directly from the CRAN directory and another is downloading the package to your local system and installing it manually.
#
# <b>Install Packages Directly from Cran</b>
#
# The following command gets the packages directly from CRAN webpage and installs the package in the R environment. You may be prompted to choose a nearest mirror. Choose the one appropriate to your location.

# %%
# install.packages("Package Name")

# Install the package named "XML".

install.packages("xml2")
# Out:
# The downloaded binary packages are in
# 	/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T//RtmpmnTmx9/downloaded_packages

# %%
library("xml2")

# %% [markdown]
# <b>Install Packages Manually</b>

# %% [markdown]
# [View Packages](https://cran.r-project.org/web/packages/available_packages_by_name.html)
#
# [View Documentation](https://cran.r-project.org/doc/manuals/r-release/R-admin.html)

# %% [markdown]
# Save the package as a .zip file in a suitable location in the local system.
#
# Now you can run the following command to install this package in the R environment.

# %% [raw]
# install.packages(file_name_with_path, repos = NULL, type = "source")
#
# # Install the package named "XML"
#
# install.packages("E:/XML_3.98-1.3.zip", repos = NULL, type = "source")

# %% [markdown]
# Load Package to Library
# ---
#
# Before a package can be used in the code, it must be loaded to the current R environment. You also need to load a package that is already installed previously but not available in the current environment.
#
# A package is loaded using the following command −

# %% [raw]
# library("package Name", lib.loc = "path to library")
#
# # Load the package named "XML"
#
# install.packages("E:/XML_3.98-1.3.zip", repos = NULL, type = "source")

# %% [markdown]
# Troubleshooting
# ---
#
# When you install packages in R with Mac OS X (10.9), if you get this warning:

# %% [raw]
# tar: Failed to set default locale

# %% [markdown]
# In shell you have LANG set to en_US and LC_ALL set to en_US.UTF-8.

# %% [markdown]
# This command seems to fix it:

# %% [raw]
# defaults write org.R-project.R force.LANG en_US.UTF-8

# %% [markdown]
# ![caption](files/fix.png)

# %% [markdown]
# After restarting R, no more warnings about the default locale.

# %% [markdown]
# Most Common R Packages
# ---

# %% [markdown]
# ![caption](files/packages.jpg)

# %% [markdown]
# Submit the following code / function to install load multiple packages at once

# %% [raw]
# # ipak function: install and load multiple R packages.
# # check to see if packages are installed. Install them if they are not, then load them into the R session.
# LSMeans, Comparision, RegTest, ACD, Bison
# ipak <- function(pkg){
#     new.pkg <- pkg[!(pkg %in% installed.packages()[, "Package"])]
#     if (length(new.pkg))
#         install.packages(new.pkg, dependencies = TRUE)
#     sapply(pkg, require, character.only = TRUE)
# }
#
# # usage
# packages <- c("ggplot2", "plyr", "reshape2", "RColorBrewer", "scales", "grid")
#
# #pre-modeling stage
# #packages
#
# #modeling stage
# #packages
#
# #post modeling stage
# #packages
#
# # other libraries
# # packages <- c("rcpp", "parallel", "XML", "jasonlite", "httr", "shiny", "RMarkdown", "tm", "twitterR", "sqldf" "ROBDC", RMongo", "swirl", "reshape2", "qcc")
#
# ipak(packages)

# %% [markdown]
# ## R Programming Tutorial - Learn the Basics of Statistical Computing

# %%
library(IRdisplay)

  display_html("<iframe width='560' height='315' src='https://www.youtube.com/embed/_V8eKsto3Ug?rel=0&amp;controls=0&amp;showinfo=0'</iframe>")h
# Out:
# <iframe width='560' height='315' src='https://www.youtube.com/embed/_V8eKsto3Ug?rel=0&amp;controls=0&amp;showinfo=0'</iframe>

# %% [markdown]
# - - -
# <!--NAVIGATION-->
# Module 14. [Introduction](./00.ipynb) | [Basic Syntax](./01.ipynb)  | [Data Types](./02.ipynb) | [Variables](./03.ipynb) | [Operators](./04.ipynb) | [Decision Making](./05.ipynb)  | [Functions](./06.ipynb) | [Strings](./07.ipynb) | [Vectors](./08.ipynb) | [Lists](./09.ipynb) | [Matrices](./10.ipynb) | [Arrays](./11.ipynb) | [Factors](./12.ipynb) | [Data Frames](./13.ipynb) | [Data Reshaping](./14.ipynb) | [Exercises](./15.ipynb)
